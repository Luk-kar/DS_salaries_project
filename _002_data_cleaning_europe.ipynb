# %% [markdown]
# ## Clean data

# %% [markdown]
# ### 1. Importing all packages

# %%
# External
import os
import re
import numpy as np
import pandas as pd
from typing import Callable

# %% [markdown]
# ### 2. Importing  a CSV file

# %%
def get_dfs_from_CSVs_in_folder(directory: str) -> dict[str, pd.DataFrame]:

    dfs = {}

    # https://regex101.com/r/QYuVDf/1
    pattern = r"Data_Engineer_([a-zA-Z_]+)_\d{2}-\d{2}-\d{4}_\d{2}-\d{2}.csv"

    for __, _, files in os.walk(directory):

        for file in files:
            if file.endswith('.csv'):
                match = re.search(pattern, file)
                if match:
                    country = match.group(1)
                    file_path = os.path.join(directory, file)
                    dfs[country] = pd.read_csv(file_path)

    return dfs

# %%
CSVs_folder = "data/RAW/Data Engineer"
dfs = get_dfs_from_CSVs_in_folder(CSVs_folder)
dfs
# Out:
# {'Austria':                          Company_name  Rating            Location  \
#  0               Riverty Services GmbH     3.9              Vienna
#  1            Infineon Technologies AG     4.2             Villach
#  2            Infineon Technologies AG     4.2             Villach
#  3            Infineon Technologies AG     4.2             Villach
#  4            Infineon Technologies AG     4.2             Villach
#  ..                                ...     ...                 ...
#  865             Infineon Technologies     4.2             Villach
#  866                 Wien Energie GmbH     4.3  Gerasdorf bei Wien
#  867  Trenkwalder Personaldienste GmbH     3.9             Austria
#  868              Silicon Austria Labs     3.6             Villach
#  869                   Noir Consulting     5.0              Vienna
#
#                                               Job_title  \
#  0               Process Manager (m/f/d) 80% Homeoffice
#  1    Senior Staff Engineer Digital Verification (f/...
#  2    Senior Staff Engineer Product Development for ...
#  3    Component Verification and Product Characteriz...
#  4              Product Application Engineer (f/m/div)*
#  ..                                                 ...
#  865  International Graduate Program: Senior Enginee...
#  866           Business Intelligence Specialist (w/m/d)
#  867  C++ Entwickler (m/w/d) mit Schwerpunkt Machine...
#  868  Cleanroom Process Engineer - Wet Processing (f...
#  869           .NET Software Engineer – Vienna, Austria
#
#                                             Description  Salary Job_age  \
#  0    Everything we do, starts with you.\r\nTogether...     NaN    30d+
#  1    You are looking for a new challenge to bring i...     NaN     25d
#  2    Do you want to get to know the development of ...     NaN     18d
#  3    You are looking for a new challenge to bring i...     NaN     25d
#  4    You enjoy working in an international team, in...     NaN     26d
#  ..                                                 ...     ...     ...
#  865  Are you ready to start your career in a fast-m...     NaN     30d
#  866  Business Intelligence Specialist (w/m/d)\r\n==...     NaN     25d
#  867  Unser Kunde (KV EMG) ist ein international tät...     NaN     11d
#  868  Your future responsibilities\r\nThe process en...     NaN    30d+
#  869  .NET Software Engineer - Vienna, Austria\r\n(T...     NaN      6d
#
#       Easy_apply      Employees  Type_of_ownership  ... CEO_approval  \
#  0         False  5001 to 10000  Company - Private  ...         1.00
#  1         False         10000+   Company - Public  ...         0.95
#  2         False         10000+   Company - Public  ...         0.95
#  3         False         10000+   Company - Public  ...         0.95
#  4         False         10000+   Company - Public  ...         0.95
#  ..          ...            ...                ...  ...          ...
#  865       False         10000+   Company - Public  ...         0.95
#  866       False            NaN                NaN  ...         1.00
#  867       False         10000+  Company - Private  ...         1.00
#  868       False        1 to 50      Self-employed  ...          NaN
#  869       False      51 to 200  Company - Private  ...         1.00
#
#       Career_opportunities Comp_&_benefits Culture_&_values  Senior_management  \
#  0                     3.7             3.2              3.9                3.5
#  1                     3.9             3.8              4.1                3.7
#  2                     3.9             3.8              4.1                3.7
#  3                     3.9             3.8              4.1                3.7
#  4                     3.9             3.8              4.1                3.7
#  ..                    ...             ...              ...                ...
#  865                   3.9             3.8              4.1                3.7
#  866                   3.9             3.8              3.7                3.5
#  867                   3.5             3.1              3.8                3.5
#  868                   3.2             3.2              3.5                3.4
#  869                   4.2             4.7              4.2                4.5
#
#       Work/Life_balance                                               Pros  \
#  0                  4.0  ['"Good colleagues and overall atmosphere" (in...
#  1                  4.1  ['"Good work life balance and ambitious" (in 1...
#  2                  4.1  ['"Good work life balance and ambitious" (in 1...
#  3                  4.1  ['"Good work life balance and ambitious" (in 1...
#  4                  4.1  ['"Good work life balance and ambitious" (in 1...
#  ..                 ...                                                ...
#  865                4.1  ['"Good work life balance and ambitious" (in 1...
#  866                4.4  ['No Pros have been reported by the Glassdoor ...
#  867                3.7  ['"ilfe balance and career growth" (in 3 revie...
#  868                3.9  ['"Good work environment." (in 4 reviews)', '"...
#  869                4.5  ['"Relaxed environment and tallented team" (in...
#
#                                                    Cons  Benefits_rating  \
#  0    ['"New strategy process is taking ages and peo...              4.0
#  1    ['"Descent pay, work life balance" (in 152 rev...              3.9
#  2    ['"Descent pay, work life balance" (in 152 rev...              3.9
#  3    ['"Descent pay, work life balance" (in 152 rev...              3.9
#  4    ['"Descent pay, work life balance" (in 152 rev...              3.9
#  ..                                                 ...              ...
#  865  ['"Descent pay, work life balance" (in 152 rev...              3.9
#  866  ['"Zu viele low performer, welche in die Pensi...              NaN
#  867  ['"Horrible communication between departments,...              NaN
#  868  ['"Poor management." (in 3 reviews)', '"there ...              NaN
#  869  ['No Cons have been reported by the Glassdoor ...              NaN
#
#                                        Benefits_reviews
#  0                                                  NaN
#  1    ['Health Insurance (22 comments)\n"Great cover...
#  2    ['Health Insurance (22 comments)\n"Great cover...
#  3    ['Health Insurance (22 comments)\n"Great cover...
#  4    ['Health Insurance (22 comments)\n"Great cover...
#  ..                                                 ...
#  865  ['Health Insurance (22 comments)\n"Great cover...
#  866                                                NaN
#  867                                                NaN
#  868                                                NaN
#  869                                                NaN
#
#  [870 rows x 25 columns],
#  'Belgium':                  Company_name  Rating             Location  \
#  0                       Torfs     3.8         Sint-Niklaas
#  1                   Datalumen     NaN              Kontich
#  2                Mind The Gap     4.6              Kontich
#  3                     NewBrix     NaN              Kontich
#  4    Stichting Kankerregister     NaN  Sint-Joost-Ten-Node
#  ..                        ...     ...                  ...
#  805                       P4P     NaN             Brussels
#  806                       P4P     NaN             Brussels
#  807                    Sander     5.0             Brussels
#  808       Mitsubishi Chemical     NaN                Tielt
#  809                    Ordina     3.8             Mechelen
#
#                                              Job_title  \
#  0    Data Engineer (met affiniteit voor Data Science)
#  1                                       Data Engineer
#  2                      Data engineer / ETL consultant
#  3                     Medior Data Protection Engineer
#  4                                        data manager
#  ..                                                ...
#  805               Onderzoeker Smart Buildings Brussel
#  806           Onderzoeker Innovatie Renovatie Brussel
#  807         Security Engineer | Last step before CISO
#  808                   Continuous Improvement Engineer
#  809                       Network & security engineer
#
#                                             Description  Salary Job_age  \
#  0    Wie zijn wij?\r\nVoor het continu verbeteren v...     NaN    30d+
#  1    Wat hebben wij te bieden\r\nYou can join a div...     NaN    30d+
#  2    Wat hebben wij te bieden\r\nWe offer you a ful...     NaN    30d+
#  3    Wat hebben wij te bieden\r\nOf het nu gaat ove...     NaN    30d+
#  4    De Stichting Kankerregister, gelegen in het ha...     NaN     19d
#  ..                                                 ...     ...     ...
#  805  P4P zoekt een Onderzoeker Smart Buildings (ook...     NaN    30d+
#  806  P4P zoekt een Onderzoeker Innovatie Renovatie ...     NaN    30d+
#  807  Our FinTech client is seeking an experienced S...     NaN    30d+
#  808  Location:\r\nTielt, Galgenveldstraat\r\nDivisi...     NaN    30d+
#  809  Your Impact\r\nAs network and security enginee...     NaN      5d
#
#       Easy_apply     Employees               Type_of_ownership  ...  \
#  0         False           NaN                             NaN  ...
#  1         False           NaN                             NaN  ...
#  2         False     51 to 200               Company - Private  ...
#  3         False           NaN                Company - Public  ...
#  4          True           NaN                             NaN  ...
#  ..          ...           ...                             ...  ...
#  805        True       1 to 50               Company - Private  ...
#  806        True       1 to 50               Company - Private  ...
#  807        True       1 to 50         Private Practice / Firm  ...
#  808       False  1001 to 5000  Subsidiary or Business Segment  ...
#  809       False  1001 to 5000                Company - Public  ...
#
#      CEO_approval  Career_opportunities Comp_&_benefits Culture_&_values  \
#  0           0.87                   3.5             4.0              4.1
#  1            NaN                   NaN             NaN              NaN
#  2            NaN                   4.4             3.4              5.0
#  3            NaN                   NaN             NaN              NaN
#  4            NaN                   NaN             NaN              NaN
#  ..           ...                   ...             ...              ...
#  805          NaN                   NaN             NaN              NaN
#  806          NaN                   NaN             NaN              NaN
#  807          NaN                   4.8             4.6              4.6
#  808          NaN                   NaN             NaN              NaN
#  809         0.84                   3.6             3.4              3.9
#
#       Senior_management  Work/Life_balance  \
#  0                  3.6                3.1
#  1                  NaN                NaN
#  2                  4.6                4.2
#  3                  NaN                NaN
#  4                  NaN                NaN
#  ..                 ...                ...
#  805                NaN                NaN
#  806                NaN                NaN
#  807                5.0                4.2
#  808                NaN                NaN
#  809                3.4                4.0
#
#                                                    Pros  \
#  0    ['"Veel appreciatie van je manager" (in 2 revi...
#  1                                                  NaN
#  2    ['"Great work environment, solid work team." (...
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  805                                                NaN
#  806                                                NaN
#  807                                                NaN
#  808                                                NaN
#  809  ['"Very cool company, everyone is friendly and...
#
#                                                    Cons  Benefits_rating  \
#  0    ['No Cons have been reported by the Glassdoor ...              NaN
#  1                                                  NaN              NaN
#  2    ['No Cons have been reported by the Glassdoor ...              NaN
#  3                                                  NaN              NaN
#  4                                                  NaN              NaN
#  ..                                                 ...              ...
#  805                                                NaN              NaN
#  806                                                NaN              NaN
#  807                                                NaN              NaN
#  808                                                NaN              3.4
#  809  ['"Salaries can be a bit low" (in 4 reviews)',...              NaN
#
#       Benefits_reviews
#  0                 NaN
#  1                 NaN
#  2                 NaN
#  3                 NaN
#  4                 NaN
#  ..                ...
#  805               NaN
#  806               NaN
#  807               NaN
#  808               NaN
#  809               NaN
#
#  [810 rows x 25 columns],
#  'Canada':          Company_name  Rating   Location  \
#  0           MOZ Group     3.4     Remote
#  1                Wave     3.6    Toronto
#  2             Trolley     5.0   Montreal
#  3         GlossGenius     4.0    Toronto
#  4              ALLUDO     3.8  Vancouver
#  5             Wave HQ     3.6    Toronto
#  6   War Room Holdings     4.4  Vancouver
#  7                SS&C     3.2    Toronto
#  8     York University     4.1    Toronto
#  9            Deloitte     4.0    Toronto
#  10           Best Buy     3.7  Vancouver
#  11      Toronto Hydro     3.8    Toronto
#  12         Bombardier     3.8     Dorval
#  13           Rec Room     3.4  Vancouver
#  14         Scotiabank     3.9    Toronto
#
#                                              Job_title  \
#  0                                         BI Engineer
#  1                                  Analytics Engineer
#  2                                  Analytics Engineer
#  3                           Senior Analytics Engineer
#  4                                         BI Engineer
#  5                                  Analytics Engineer
#  6                   Analytics Implementation Engineer
#  7             Financial Engineer/ACM Business Analyst
#  8                 Business Analyst & Process Engineer
#  9   Analyst/Senior Associate, AML - Financial Engi...
#  10                  Analytics Implementation Engineer
#  11              Capital & Maintenance Program Analyst
#  12       Business Analyst Engineering Budget Planning
#  13                      Analytics Engineering Manager
#  14  Senior Manager, Project Delivery Business Anal...
#
#                                            Description  Salary    Job_age  \
#  0   Moz is looking for a natural problem solver wi...     NaN        25d
#  1   We believe small businesses are at the heart o...     NaN       30d+
#  2   Trolley is the payouts platform for the intern...     NaN       30d+
#  3   About GlossGenius\r\nGlossGenius is building a...     NaN       30d+
#  4   BI Engineer\r\nPush the boundaries of tech. In...     NaN        24d
#  5   We believe small businesses are at the heart o...     NaN       30d+
#  6   Vancouver, BC\r\nFull Time, Hybrid\r\n\r\nWho ...     NaN        23d
#  7   SS&C is a global provider of investment and fi...     NaN  1 day ago
#  8   Purpose:\r\nAccountable to the Manager, Operat...     NaN       30d+
#  9   Job Type: Permanent\r\nReference code: 122995\...     NaN       30d+
#  10  Analytics Implementation Engineer\r\nDo you ha...     NaN       30d+
#  11  The Capital and Maintenance Program Analyst is...     NaN       30d+
#  12  Business Analyst Engineering Budget Planning -...     NaN       30d+
#  13  (This role is fully remote for candidates loca...     NaN       30d+
#  14  Requisition ID: 176293\r\n\r\nJoin a purpose d...     NaN         5d
#
#      Easy_apply      Employees     Type_of_ownership  ... CEO_approval  \
#  0        False      51 to 200     Company - Private  ...         0.67
#  1        False     201 to 500     Company - Private  ...         0.39
#  2         True      51 to 200     Company - Private  ...         1.00
#  3        False        1 to 50     Company - Private  ...          NaN
#  4         True    501 to 1000     Company - Private  ...         0.80
#  5         True     201 to 500     Company - Private  ...         0.39
#  6        False        1 to 50     Company - Private  ...         0.83
#  7        False         10000+      Company - Public  ...         0.51
#  8        False  5001 to 10000  College / University  ...         0.77
#  9        False         10000+     Company - Private  ...         0.93
#  10       False         10000+      Company - Public  ...         0.46
#  11       False   1001 to 5000            Government  ...         0.71
#  12       False         10000+      Company - Public  ...         0.88
#  13        True    501 to 1000      Company - Public  ...          NaN
#  14       False         10000+      Company - Public  ...         0.86
#
#      Career_opportunities Comp_&_benefits Culture_&_values  Senior_management  \
#  0                    2.9             3.6              3.6                2.7
#  1                    3.6             3.4              3.8                3.3
#  2                    4.8             4.5              5.0                5.0
#  3                    3.7             3.9              3.7                3.5
#  4                    3.5             3.5              3.9                3.7
#  5                    3.6             3.4              3.8                3.3
#  6                    4.3             4.3              4.3                4.3
#  7                    2.8             2.8              2.7                2.6
#  8                    3.7             3.8              3.8                3.6
#  9                    4.3             3.8              4.0                3.8
#  10                   3.3             3.4              3.6                3.2
#  11                   3.7             3.9              3.7                3.5
#  12                   3.5             3.6              3.4                3.1
#  13                   3.0             3.0              3.1                3.3
#  14                   3.8             3.7              3.9                3.5
#
#      Work/Life_balance                                               Pros  \
#  0                 4.1  ['"The culture is amazing." (in 9 reviews)', '...
#  1                 4.2  ['"First and foremost, Wave is full of kind, d...
#  2                 5.0  ['"They have invested in the right tools, trai...
#  3                 3.0  ['"Love the team members that I work with." (i...
#  4                 3.9  ['"Good Team to work with" (in 1 reviews)', '"...
#  5                 4.2  ['"First and foremost, Wave is full of kind, d...
#  6                 4.2  ['"The people here are amazing" (in 12 reviews...
#  7                 3.1  ['"Great people in all the levels" (in 32 revi...
#  8                 3.9  ['"Benefits are great!" (in 4 reviews)', '"Gre...
#  9                 3.3  ['"A good work life balance when you compare w...
#  10                3.4  ['"good pay compared to other places" (in 135 ...
#  11                3.6  ['"Good pay and benefit." (in 2 reviews)', '"S...
#  12                3.6  ['"Good work life balance" (in 14 reviews)', '...
#  13                3.3  ['"great management" (in 27 reviews)', '"Good ...
#  14                3.7  ['"Good for work life balance" (in 107 reviews...
#
#                                                   Cons  Benefits_rating  \
#  0   ['"The company was purchased in 2021 by Ziff D...              4.4
#  1   ['No Cons have been reported by the Glassdoor ...              NaN
#  2   ['No Cons have been reported by the Glassdoor ...              NaN
#  3   ['"The team became very micro" (in 6 reviews)'...              5.0
#  4   ['"Pay is very low compared to similiar sized ...              3.0
#  5   ['No Cons have been reported by the Glassdoor ...              NaN
#  6   ['"working out operational processes and build...              NaN
#  7   ['"Shareholder driven so no investments in dev...              3.7
#  8   ['"boring, low compensation, and uncertainty" ...              4.0
#  9   ['"No work/life balance and not easy to grow i...              4.2
#  10  ['"low pay not worth the stress" (in 135 revie...              3.7
#  11  ['"Sometime long hours and weekends." (in 3 re...              NaN
#  12  ['"Work life balance is awful you are expected...              3.6
#  13  ['"bad management, overpriced everything and n...              NaN
#  14  ['"no work life balance； heavy load" (in 107 r...              3.8
#
#                                       Benefits_reviews
#  0   ['Maternity & Paternity Leave (4 comments)\n"4...
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4   ['Work From Home (4 comments)\n"Overall positi...
#  5                                                 NaN
#  6                                                 NaN
#  7   ['401K Plan (69 comments)\n"It\'s Match and im...
#  8                                                 NaN
#  9   ['Health Insurance (764 comments)\n"But it is ...
#  10  ['Employee Discount (1347 comments)\n"No disto...
#  11                                                NaN
#  12  ['Health Insurance (25 comments)\n"excellent b...
#  13                                                NaN
#  14  ['Health Insurance (5 comments)\n"Mid medical ...
#
#  [15 rows x 25 columns],
#  'Czech_Republic':                     Company_name  Rating        Location  \
#  0       RSI Cycles & Motors Ltd.     NaN          Prague
#  1                       EUMETSAT     3.6          Prague
#  2           Hill's Pet Nutrition     4.0       Hustopeče
#  3      Porsche Engineering Group     3.8         Ostrava
#  4                        Groupon     3.3  Czech Republic
#  ..                           ...     ...             ...
#  865                 NOTIX s.r.o.     5.0          Prague
#  866                          ABB     4.0          Mošnov
#  867                       Rotork     3.5  Czech Republic
#  868     Thermo Fisher Scientific     3.8            Brno
#  869  Atlas Copco Services s.r.o.     4.2            Brno
#
#                                               Job_title  \
#  0               IT Desktop Support Engineer Technician
#  1           Cloud Services Engineer (Based in Germany)
#  2                            Technical Systems Manager
#  3                               Cloud Engineer (f/m/d)
#  4                                        Data Engineer
#  ..                                                 ...
#  865                                  Big data engineer
#  866                    Industrial and Systems Engineer
#  867  Field Service Engineer Austria & Hungary & Slo...
#  868                            Site Support Engineer |
#  869                                      Data Engineer
#
#                                             Description  Salary Job_age  \
#  0    We are looking for a Support Engineer to join ...     NaN     17d
#  1    Cloud Services Engineer\r\nEUMETSAT is Europe’...     NaN     11d
#  2    Relocation Assistance Offered Within Region\r\...     NaN      9d
#  3    You’re kind of a nerd. We’re kind of nerds.\r\...     NaN    30d+
#  4    Groupon’s mission is to become the daily habit...     NaN     19d
#  ..                                                 ...     ...     ...
#  865  Hledáme systémáka, který se nelekne objevovat ...     NaN    30d+
#  866  Industrial and Systems Engineer\r\nTake your n...     NaN      8d
#  867  Field Service Engineer Austria & Hungary & Slo...     NaN     12d
#  868  As the world leader in serving science, we sol...     NaN     11d
#  869  Who are we?\r\nThe Data Domain is responsible ...     NaN     16d
#
#       Easy_apply      Employees  Type_of_ownership  ... CEO_approval  \
#  0          True            NaN   Company - Public  ...          NaN
#  1         False     201 to 500      Self-employed  ...         0.49
#  2         False   1001 to 5000   Company - Public  ...         0.74
#  3         False   1001 to 5000  Company - Private  ...         0.62
#  4         False  5001 to 10000   Company - Public  ...         0.30
#  ..          ...            ...                ...  ...          ...
#  865       False            NaN   Company - Public  ...          NaN
#  866       False         10000+   Company - Public  ...         0.89
#  867       False   1001 to 5000   Company - Public  ...         0.87
#  868       False         10000+   Company - Public  ...         0.90
#  869       False         10000+   Company - Public  ...         0.94
#
#       Career_opportunities Comp_&_benefits Culture_&_values  Senior_management  \
#  0                     NaN             NaN              NaN                NaN
#  1                     2.6             3.9              3.2                2.9
#  2                     3.7             4.4              4.0                3.5
#  3                     3.6             3.1              3.7                3.1
#  4                     3.1             3.3              3.7                2.8
#  ..                    ...             ...              ...                ...
#  865                   5.0             5.0              5.0                5.0
#  866                   3.7             3.6              3.9                3.5
#  867                   3.3             3.3              3.3                3.1
#  868                   3.7             3.6              3.7                3.3
#  869                   4.0             3.8              4.2                3.6
#
#       Work/Life_balance                                               Pros  \
#  0                  NaN                                                NaN
#  1                  3.4  ['"this company can offer good salary, on the ...
#  2                  3.6  ['"Great benefits with the Colgate" (in 35 rev...
#  3                  3.9  ['"Good Management, Friendly and chilled out p...
#  4                  3.9  ['"Great people and very international" (in 29...
#  ..                 ...                                                ...
#  865                5.0  ['"Great people, friendly and reasonable owner...
#  866                3.8  ['"Good salary and experience to work" (in 821...
#  867                3.5  ['"Decent salary, good guys, management is nev...
#  868                3.5  ['"Benefits are good and ethos positive but yo...
#  869                3.9  ['"Good Work life balance so far" (in 110 revi...
#
#                                                    Cons  Benefits_rating  \
#  0                                                  NaN              NaN
#  1    ['"Some heads are creating a negative culture ...              NaN
#  2    ['"No work/ life balance" (in 18 reviews)', '"...              4.5
#  3    ['"Bad management" (in 12 reviews)', '"Small s...              NaN
#  4    ['"20% of the people to 80% of the work and ot...              3.9
#  ..                                                 ...              ...
#  865  ['No Cons have been reported by the Glassdoor ...              NaN
#  866  ['"Low salaries and less organized and no defi...              3.7
#  867  ['"Poor management" (in 27 reviews)', '"Lots o...              3.8
#  868  ['"benefit is mediocre, less than biotech/phar...              3.8
#  869  ['"work life balance difficult but thats the n...              4.2
#
#                                        Benefits_reviews
#  0                                                  NaN
#  1                                                  NaN
#  2    ['Maternity & Paternity Leave (6 comments)\n"T...
#  3                                                  NaN
#  4    ['Health Insurance (136 comments)\n"The insura...
#  ..                                                 ...
#  865                                                NaN
#  866  ['Health Insurance (86 comments)\n"you hvae a ...
#  867                                                NaN
#  868  ['Health Insurance (226 comments)\n"A bit expe...
#  869  ['Health Insurance (23 comments)\n"Best - good...
#
#  [870 rows x 25 columns],
#  'Denmark':            Company_name  Rating    Location  \
#  0               ViaBill     3.8  Copenhagen
#  1                Quanta     4.3  Copenhagen
#  2                Quanta     4.3  Copenhagen
#  3                  LEGO     4.5     Denmark
#  4                Quanta     4.3  Copenhagen
#  ..                  ...     ...         ...
#  595              Maersk     4.2  Copenhagen
#  596  Wunderman Thompson     3.7  Copenhagen
#  597                Nets     3.3    Ballerup
#  598              Maersk     4.2  Copenhagen
#  599     Pandora Jewelry     3.7  Copenhagen
#
#                                               Job_title  \
#  0    Data Scientist / Machine Learning Engineer, Fi...
#  1                             Lead Instrument Engineer
#  2                             Lead Structural Engineer
#  3                                        Data engineer
#  4                             Lead Electrical Engineer
#  ..                                                 ...
#  595                                  Software Engineer
#  596                             Data/Software Engineer
#  597                    Head of Data & Insights (m/f/d)
#  598    Senior Data & Automation Engineer HR Technology
#  599                                 Lead Data Engineer
#
#                                             Description  Salary    Job_age  \
#  0    ViaBill operates at the intersection of the eC...     NaN        14d
#  1    Lead Instrument Engineer – Renewable Energy – ...     NaN         7d
#  2    Lead Structural Engineer – Renewable Energy – ...     NaN         7d
#  3    Job Description\r\n#LI-EB1\r\nAre you excited ...     NaN         6d
#  4    Lead Electrical Engineer – Renewable Energy – ...     NaN         7d
#  ..                                                 ...     ...        ...
#  595  Maersk is going through times of unprecedented...     NaN         9d
#  596  Who we are:\r\nAt Wunderman Thompson we exist ...     NaN        21d
#  597  Date Posted: 30-03-2023\r\nIndustry: Financial...     NaN  1 day ago
#  598  Let’s reimagine how the world moves.\r\nAs an ...     NaN       30d+
#  599  Lead Data Engineer\r\n\r\nAre you passionate a...     NaN       30d+
#
#       Easy_apply     Employees               Type_of_ownership  ...  \
#  0          True     51 to 200                             NaN  ...
#  1         False     51 to 200               Company - Private  ...
#  2         False     51 to 200               Company - Private  ...
#  3         False        10000+               Company - Private  ...
#  4         False     51 to 200               Company - Private  ...
#  ..          ...           ...                             ...  ...
#  595       False        10000+  Subsidiary or Business Segment  ...
#  596       False        10000+                Company - Public  ...
#  597       False  1001 to 5000               Company - Private  ...
#  598       False        10000+  Subsidiary or Business Segment  ...
#  599       False        10000+                Company - Public  ...
#
#      CEO_approval  Career_opportunities Comp_&_benefits Culture_&_values  \
#  0            NaN                   3.5             3.1              3.2
#  1           0.98                   4.5             4.7              4.6
#  2           0.98                   4.5             4.7              4.6
#  3           0.95                   3.6             4.2              4.6
#  4           0.98                   4.5             4.7              4.6
#  ..           ...                   ...             ...              ...
#  595         0.94                   4.0             4.0              4.3
#  596         0.81                   3.5             3.2              3.8
#  597          NaN                   3.3             3.7              3.3
#  598         0.94                   4.0             4.0              4.3
#  599         0.75                   3.3             3.4              3.6
#
#       Senior_management  Work/Life_balance  \
#  0                  2.9                3.5
#  1                  4.5                4.3
#  2                  4.5                4.3
#  3                  4.1                4.3
#  4                  4.5                4.3
#  ..                 ...                ...
#  595                3.7                4.0
#  596                3.4                3.6
#  597                3.0                4.2
#  598                3.7                4.0
#  599                3.2                3.2
#
#                                                    Pros  \
#  0    ['"Great team and a friendly colleagues, alway...
#  1    ['"Fantastic culture, very forward thinking an...
#  2    ['"Fantastic culture, very forward thinking an...
#  3    ['"Good benefits for a retail shop" (in 146 re...
#  4    ['"Fantastic culture, very forward thinking an...
#  ..                                                 ...
#  595  ['"Pay good and work life balance" (in 475 rev...
#  596  ['"The people are great and extends beyond you...
#  597  ['"Great colleagues." (in 8 reviews)', '"Good ...
#  598  ['"Pay good and work life balance" (in 475 rev...
#  599  ['"management is good" (in 288 reviews)', '"go...
#
#                                                    Cons  Benefits_rating  \
#  0    ['"On the inside, it is an absolute mess with ...              NaN
#  1    ['No Cons have been reported by the Glassdoor ...              NaN
#  2    ['No Cons have been reported by the Glassdoor ...              NaN
#  3    ['"No Benefits (Unless you are ASM and M) Limi...              4.4
#  4    ['No Cons have been reported by the Glassdoor ...              NaN
#  ..                                                 ...              ...
#  595  ['"No work/life balance at all!!!" (in 475 rev...              4.0
#  596  ['"Awesome people and employees!" (in 299 revi...              3.8
#  597  ['"Bad management, High turnover, Branch Norwa...              NaN
#  598  ['"No work/life balance at all!!!" (in 475 rev...              4.0
#  599  ['"bad management and not really supportive" (...              3.0
#
#                                        Benefits_reviews
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3    ['Employee Discount (39 comments)\n"Discount o...
#  4                                                  NaN
#  ..                                                 ...
#  595  ['Health Insurance (17 comments)\n"Health insu...
#  596  ['Health Insurance (11 comments)\n"Covered Mos...
#  597                                                NaN
#  598  ['Health Insurance (17 comments)\n"Health insu...
#  599  ['Employee Discount (58 comments)\n"Nothing at...
#
#  [600 rows x 25 columns],
#  'Finland':                           Company_name  Rating  Location  \
#  0              Turck Vilant Systems Oy     NaN     Espoo
#  1           Topcon Positioning Systems     4.4     Espoo
#  2                            Elisa Oyj     4.3   Finland
#  3                               Solita     4.6   Finland
#  4                            Yousician     4.0  Helsinki
#  ..                                 ...     ...       ...
#  280                                Elo     3.4  Helsinki
#  281                        Anderson RH     NaN   Kouvola
#  282               Smartly.io Job Board     4.4  Helsinki
#  283                            Scandit     4.4   Tampere
#  284  Nigel Frank International Limited     3.0    Vantaa
#
#                                               Job_title  \
#  0                      Senior Software Engineer, React
#  1                                    SOFTWARE ENGINEER
#  2                                        Data Engineer
#  3    Grow as Data Engineer with us - Solita´s perso...
#  4                                        Data Engineer
#  ..                                                 ...
#  280                                   Product Designer
#  281  Metallurgist / Mineral Processing Sales Engine...
#  282          Senior DevOps Engineer (Site Reliability)
#  283  Full-stack Engineer - Usage Tracking (Rails / ...
#  284               Senior Azure/.NET Developer - Vantaa
#
#                                             Description  Salary Job_age  \
#  0    What to expect from this role?\r\nWe make sens...     NaN     20d
#  1    For our Product Development Center in Espoo, F...     NaN    30d+
#  2    Elisa Data & Analytics department is responsib...     NaN     12d
#  3    Growing as a Data Engineer onboarding program ...     NaN      4d
#  4    JOIN YOUSICIAN\r\nYousician impacts and enrich...     NaN    30d+
#  ..                                                 ...     ...     ...
#  280  Elo is looking for an experienced, full-time P...     NaN    30d+
#  281  Minimum 3 years of experience in mineral proce...     NaN    30d+
#  282  We're looking for a DevOps — Site Reliability ...     NaN    30d+
#  283  At Scandit, we develop smart data capture tech...     NaN    30d+
#  284  Due to the start of a new project, my client i...     NaN    30d+
#
#       Easy_apply      Employees  Type_of_ownership  ... CEO_approval  \
#  0          True            NaN                NaN  ...          NaN
#  1          True   1001 to 5000  Company - Private  ...         0.95
#  2         False  5001 to 10000   Company - Public  ...         0.87
#  3         False    501 to 1000  Company - Private  ...         0.98
#  4         False      51 to 200  Company - Private  ...         0.89
#  ..          ...            ...                ...  ...          ...
#  280        True            NaN  Company - Private  ...          NaN
#  281        True            NaN   Company - Public  ...          NaN
#  282        True    501 to 1000  Company - Private  ...         0.84
#  283        True    501 to 1000  Company - Private  ...         0.98
#  284       False   1001 to 5000                NaN  ...          NaN
#
#       Career_opportunities Comp_&_benefits Culture_&_values  Senior_management  \
#  0                     NaN             NaN              NaN                NaN
#  1                     4.1             4.1              4.3                4.2
#  2                     4.1             4.1              4.4                4.2
#  3                     4.3             4.2              4.8                4.6
#  4                     4.0             4.1              4.5                3.9
#  ..                    ...             ...              ...                ...
#  280                   3.4             2.6              3.2                3.1
#  281                   NaN             NaN              NaN                NaN
#  282                   4.2             4.2              4.6                3.9
#  283                   3.9             4.1              4.5                4.2
#  284                   3.2             2.4              2.8                2.7
#
#       Work/Life_balance                                               Pros  \
#  0                  NaN                                                NaN
#  1                  4.5  ['"Great people" (in 33 reviews)', '"Topcon pr...
#  2                  4.3  ['"Good community and good salary" (in 19 revi...
#  3                  4.9  ['"Incredibly talented and friendly colleagues...
#  4                  4.7  ['"Great people to work with" (in 12 reviews)'...
#  ..                 ...                                                ...
#  280                2.9                                                NaN
#  281                NaN                                                NaN
#  282                4.6  ['"Culture is great" (in 55 reviews)', '"The p...
#  283                4.4  ['"Great people and amazing team spirit" (in 3...
#  284                2.5  ['"Awesome management" (in 23 reviews)', '"Goo...
#
#                                                    Cons  Benefits_rating  \
#  0                                                  NaN              NaN
#  1    ['"Those people are really rude." (in 33 revie...              2.8
#  2    ['"low salary, hard to recruit to" (in 19 revi...              5.0
#  3                ['"Average salary." (in 16 reviews)']              NaN
#  4    ['"I guess the only con would be that during m...              NaN
#  ..                                                 ...              ...
#  280                                                NaN              NaN
#  281                                                NaN              NaN
#  282  ['"MT is working hard to keep the culture but ...              4.6
#  283  ['"People are constantly trying to get better ...              3.7
#  284  ['"Bad management, bad hours and wacky expecta...              5.0
#
#                                        Benefits_reviews
#  0                                                  NaN
#  1    ['401K Plan (3 comments)\n"They match 401k pla...
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  280                                                NaN
#  281                                                NaN
#  282                                                NaN
#  283                                                NaN
#  284                                                NaN
#
#  [285 rows x 25 columns],
#  'France':                         Company_name  Rating     Location  \
#  0                                NaN     NaN          NaN
#  1                             Matmut     3.5        Rouen
#  2                              Valeo     3.8        Paris
#  3                   Publicis Sapient     3.6        Paris
#  4                              DOUGS     3.7  Télétravail
#  ..                               ...     ...          ...
#  895                        La Relève     4.6        Paris
#  896  EURO-INFORMATION DEVELOPPEMENTS     4.2       Nantes
#  897                   SERVIER France     3.8     Suresnes
#  898                        La Relève     4.6        Paris
#  899                Applied Materials     4.1       Bernin
#
#                                               Job_title  \
#  0                                                  NaN
#  1                              CDD - DATA ENGINEER F/H
#  2                                Data Analytics Leader
#  3                    Manager QA Testing Automation H/F
#  4    Software engineer fullstack - Lancement nouvea...
#  ..                                                 ...
#  895                  CDI - Data Engineer (Média) (F/H)
#  896  Responsable d'Equipe Informatique - Data Facto...
#  897                       Head of Data Analytics (H/F)
#  898              CDI - Cloud Data Engineer (Média) F/H
#  899  International Trainee Program: Process Enginee...
#
#                                             Description  Salary Job_age  \
#  0                                                  NaN     NaN    30d+
#  1    On vous parle de nous ?\r\n\r\nDepuis 1961, la...     NaN    30d+
#  2    Valeo is a tech global company, designing brea...     NaN      2d
#  3    Description de l'entreprise\r\n\r\nPublicis Sa...     NaN    30d+
#  4    Accompagner les entrepreneurs pour qu’ils réus...     NaN      5d
#  ..                                                 ...     ...     ...
#  895  Nous recrutons pour l’un de nos clients, un Da...     NaN    30d+
#  896  Qui sommes nous\r\nEuro-Information, filiale t...     NaN    30d+
#  897  /\r\n\r\nLe programme data du Groupe Servier e...     NaN      2d
#  898  Nous recrutons pour l’un de nos clients, un Cl...     NaN    30d+
#  899  International Trainee Program: Process Enginee...     NaN     19d
#
#       Easy_apply     Employees  Type_of_ownership  ... CEO_approval  \
#  0          True           NaN                NaN  ...          NaN
#  1         False  1001 to 5000                NaN  ...         0.76
#  2         False        10000+  Company - Private  ...         0.73
#  3         False        10000+   Company - Public  ...         0.91
#  4          True       1 to 50  Company - Private  ...          NaN
#  ..          ...           ...                ...  ...          ...
#  895       False       1 to 50  Company - Private  ...         1.00
#  896       False        10000+   Company - Public  ...         0.94
#  897       False        10000+  Company - Private  ...         1.00
#  898       False       1 to 50  Company - Private  ...         1.00
#  899        True        10000+   Company - Public  ...         0.91
#
#       Career_opportunities Comp_&_benefits Culture_&_values  Senior_management  \
#  0                     NaN             NaN              NaN                NaN
#  1                     2.8             3.2              3.4                3.1
#  2                     3.7             3.6              3.6                3.3
#  3                     3.8             3.7              3.9                3.6
#  4                     3.8             3.8              3.9                3.6
#  ..                    ...             ...              ...                ...
#  895                   4.3             4.4              4.3                4.4
#  896                   3.4             3.7              4.1                3.7
#  897                   4.2             4.5              4.4                4.2
#  898                   4.3             4.4              4.3                4.4
#  899                   3.9             3.8              4.0                3.6
#
#       Work/Life_balance                                               Pros  \
#  0                  NaN                                                NaN
#  1                  3.8  ['No Pros have been reported by the Glassdoor ...
#  2                  3.3  ['"Innovation, leader, technologie, autonomie,...
#  3                  3.6  ['"good work life balance and learning curve i...
#  4                  3.8  ['"Good pay good peoole compared to others" (i...
#  ..                 ...                                                ...
#  895                4.5                                                NaN
#  896                4.1  ['"la relation avec les collègues et le manage...
#  897                4.1  ['"Good salary, a lot of interesting projects"...
#  898                4.5                                                NaN
#  899                3.6  ['"Good work life balance and able to work rem...
#
#                                                    Cons  Benefits_rating  \
# ...
#  899                   NaN             NaN              NaN                NaN
#
#       Work/Life_balance                                               Pros  \
#  0                  3.4  ['"Good salary no tax" (in 598 reviews)', '"Go...
#  1                  3.4  ['"Good salary no tax" (in 598 reviews)', '"Go...
#  2                  NaN                                                NaN
#  3                  NaN                                                NaN
#  4                  3.4  ['"Good salary no tax" (in 598 reviews)', '"Go...
#  ..                 ...                                                ...
#  895                NaN                                                NaN
#  896                NaN                                                NaN
#  897                NaN                                                NaN
#  898                NaN                                                NaN
#  899                NaN                                                NaN
#
#                                                    Cons  Benefits_rating  \
#  0    ['"Low Salary and No promotion" (in 598 review...              4.5
#  1    ['"Low Salary and No promotion" (in 598 review...              4.5
#  2                                                  NaN              NaN
#  3                                                  NaN              NaN
#  4    ['"Low Salary and No promotion" (in 598 review...              4.5
#  ..                                                 ...              ...
#  895                                                NaN              NaN
#  896                                                NaN              NaN
#  897                                                NaN              NaN
#  898                                                NaN              NaN
#  899                                                NaN              NaN
#
#                                        Benefits_reviews
#  0    ['Health Insurance (5 comments)\n"Usually work...
#  1    ['Health Insurance (5 comments)\n"Usually work...
#  2                                                  NaN
#  3                                                  NaN
#  4    ['Health Insurance (5 comments)\n"Usually work...
#  ..                                                 ...
#  895                                                NaN
#  896                                                NaN
#  897                                                NaN
#  898                                                NaN
#  899                                                NaN
#
#  [900 rows x 25 columns],
#  'United_Kingdom':                        Company_name  Rating                        Location  \
#  0                  Mercury Holidays     3.3                          Remote
#  1                           Travtus     NaN                 London, England
#  2                        Datasource     4.6                          Remote
#  3    Markerstudy Insurance Services     4.0                          Remote
#  4                       SearchPilot     5.0                          Remote
#  ..                              ...     ...                             ...
#  895             Play Sports Network     3.8                   Bath, England
#  896                  INFINITY GROUP     4.4  Royal Tunbridge Wells, England
#  897                         Synapri     5.0                          Remote
#  898             Metrica Recruitment     1.0                 London, England
#  899                   BeZero Carbon     4.4                 London, England
#
#                                  Job_title  \
#  0                           Data Engineer
#  1                  Data Engineer (Junior)
#  2                Junior Power BI Engineer
#  3                    Senior Data Engineer
#  4                           Data Engineer
#  ..                                    ...
#  895                         Data Engineer
#  896  Data Specialist - Power BI Developer
#  897                    Power BI Developer
#  898                         Data Engineer
#  899                         Data Engineer
#
#                                             Description  Salary    Job_age  \
#  0    Mercury Holidays is a travel company based in ...     NaN         2d
#  1    Data Engineer (Junior)\r\nOur technology\r\nAd...     NaN        24h
#  2    Introduction\r\nThis role is within the Consul...     NaN        24h
#  3    Job Title: Data Engineer/Senior Data Engineer\...     NaN  1 day ago
#  4    Data Engineer UK/Europe/Remote\r\n£50k-70k\r\n...     NaN       30d+
#  ..                                                 ...     ...        ...
#  895  If you are a Data Engineer looking for a role ...     NaN         7d
#  896  Data Specialist – Power BI Developer – Remote ...     NaN         4d
#  897  I am currently recruiting for a Power BI devel...     NaN        21d
#  898  The Company:\r\nA boutique data consultancy th...     NaN         6d
#  899  Data Engineer\r\nFull time, London or remote (...     NaN       30d+
#
#       Easy_apply      Employees  Type_of_ownership  ... CEO_approval  \
#  0          True      51 to 200  Company - Private  ...         1.00
#  1          True            NaN                NaN  ...          NaN
#  2         False        1 to 50  Company - Private  ...         1.00
#  3          True  5001 to 10000  Company - Private  ...         0.79
#  4          True        1 to 50  Company - Private  ...         1.00
#  ..          ...            ...                ...  ...          ...
#  895        True     201 to 500  Company - Private  ...         0.72
#  896        True      51 to 200  Company - Private  ...         0.98
#  897       False        1 to 50  Company - Private  ...         1.00
#  898       False        1 to 50  Company - Private  ...          NaN
#  899       False      51 to 200  Company - Private  ...         1.00
#
#       Career_opportunities Comp_&_benefits Culture_&_values  Senior_management  \
#  0                     2.6             2.4              1.9                2.2
#  1                     NaN             NaN              NaN                NaN
#  2                     4.2             4.3              4.5                4.3
#  3                     4.0             3.9              4.0                4.0
#  4                     4.6             5.0              5.0                5.0
#  ..                    ...             ...              ...                ...
#  895                   3.5             3.4              4.1                3.5
#  896                   4.2             4.0              4.5                4.3
#  897                   5.0             4.9              5.0                5.0
#  898                   2.0             3.0              1.0                NaN
#  899                   5.0             4.6              4.7                4.4
#
#       Work/Life_balance                                               Pros  \
#  0                  2.3  ['"Nice people, pizza Fridays, free holidays" ...
#  1                  NaN                                                NaN
#  2                  4.4  ['"Friendly environment, great people." (in 1 ...
#  3                  3.8  ['"Great colleagues to work with" (in 3 review...
#  4                  5.0  ['"The business offers an alternative approach...
#  ..                 ...                                                ...
#  895                4.3  ['"Greatly talented and friendly people amongs...
#  896                4.2  ['"Management are also extremely friendly and ...
#  897                4.7  ['"Excellent training, support and guidance fr...
#  898                NaN                                                NaN
#  899                4.6  ['"There is scope for learning and development...
#
#                                                    Cons  Benefits_rating  \
#  0    ['"Lack of communication from mangers" (in 1 r...              NaN
#  1                                                  NaN              NaN
#  2    ['No Cons have been reported by the Glassdoor ...              1.0
#  3    ['"Need more influx of new talent." (in 1 revi...              NaN
#  4    ['"site and travel more which is brilliant!" (...              NaN
#  ..                                                 ...              ...
#  895  ['"No career advancement opportunities" (in 2 ...              4.0
#  896  ['"No Parking at the tonbridege wells office, ...              NaN
#  897  ['No Cons have been reported by the Glassdoor ...              NaN
#  898                                                NaN              NaN
#  899  ['No Cons have been reported by the Glassdoor ...              NaN
#
#       Benefits_reviews
#  0                 NaN
#  1                 NaN
#  2                 NaN
#  3                 NaN
#  4                 NaN
#  ..                ...
#  895               NaN
#  896               NaN
#  897               NaN
#  898               NaN
#  899               NaN
#
#  [900 rows x 25 columns],
#  'United_States':                     Company_name  Rating         Location  \
#  0          Infoway solutions LLC     3.9  Santa Clara, CA
#  1                   Optimal Inc.     3.6     Dearborn, MI
#  2    Strivernet RPO Services Ltd     NaN  Santa Clara, CA
#  3     Futuretech Consultants LLC     NaN       Newton, MS
#  4                    Clairvoyant     4.4           Remote
#  ..                           ...     ...              ...
#  895                 Angle Health     4.0           Remote
#  896                WCF Insurance     3.9        Sandy, UT
#  897                     Nimsvish     NaN       Reston, VA
#  898        ServIT Consulting LLC     NaN    Baltimore, MD
#  899                73rd Solution     NaN      Fremont, CA
#
#                       Job_title  \
#  0                Data Engineer
#  1    Data Engineer - Terraform
#  2                Data Engineer
#  3      Snowflake Data Engineer
#  4          Data Engineer (MDM)
#  ..                         ...
#  895              Data Engineer
#  896              Data Engineer
#  897          AWS Data Engineer
#  898              Data Engineer
#  899              Data Engineer
#
#                                             Description  \
#  0    Need min 10+ Years exp\nData Engineer\nBay Are...
#  1    Position Description:\nThe GDIA Data Factory P...
#  2    (W2 CANDIDATES ONLY) (SANTA CLARA, CA)\nPLEASE...
#  3    My name is Dileep and I am a recruiter at Futu...
#  4    Required Skills:\nMust have 5-8+ Years of expe...
#  ..                                                 ...
#  895  Changing Healthcare For Good\nAt Angle Health,...
#  896  Do you love researching data and applying your...
#  897  Title: AWS Data Engineer with SAS\nLocation: R...
#  898  Data Engineer\nBaltimore, MD\n6+ Months\nRespo...
#  899  Responsibilities:\nDevelop and maintain data m...
#
#                                                  Salary Job_age  Easy_apply  \
#  0             Employer Provided Salary:$68.00 Per Hour      3d        True
#  1                         $63K - $90K (Glassdoor est.)     12d        True
#  2    Employer Provided Salary:$90.00 - $95.00 Per Hour      5d        True
#  3    Employer Provided Salary:$40.00 - $45.00 Per Hour    30d+        True
#  4    Employer Provided Salary:$65.00 - $70.00 Per Hour     12d        True
#  ..                                                 ...     ...         ...
#  895                                                NaN     19d        True
#  896                      $77K - $111K (Glassdoor est.)     24h        True
#  897  Employer Provided Salary:$60.00 - $65.00 Per Hour    30d+        True
#  898  Employer Provided Salary:$50.50 - $75.00 Per Hour     10d        True
#  899           Employer Provided Salary:$70.00 Per Hour      4d        True
#
#         Employees       Type_of_ownership  ... CEO_approval  \
#  0            NaN       Company - Private  ...         0.84
#  1        1 to 50  Nonprofit Organization  ...         0.78
#  2            NaN        Company - Public  ...          NaN
#  3            NaN                     NaN  ...          NaN
#  4      51 to 200       Company - Private  ...         0.87
#  ..           ...                     ...  ...          ...
#  895      1 to 50       Company - Private  ...          NaN
#  896  501 to 1000           Self-employed  ...         1.00
#  897          NaN        Company - Public  ...          NaN
#  898          NaN                     NaN  ...          NaN
#  899      1 to 50        Company - Public  ...          NaN
#
#       Career_opportunities Comp_&_benefits Culture_&_values  Senior_management  \
#  0                     4.0             3.9              4.0                3.7
#  1                     3.2             3.7              3.3                2.6
#  2                     NaN             NaN              NaN                NaN
#  3                     NaN             NaN              NaN                NaN
#  4                     4.1             4.2              3.9                4.1
#  ..                    ...             ...              ...                ...
#  895                   4.0             4.5              4.1                3.8
#  896                   3.5             3.6              3.7                3.7
#  897                   NaN             NaN              NaN                NaN
#  898                   NaN             NaN              NaN                NaN
#  899                   NaN             NaN              NaN                NaN
#
#       Work/Life_balance                                               Pros  \
#  0                  3.9  ['"Nice and friendly work environment" (in 1 r...
#  1                  4.5  ['No Pros have been reported by the Glassdoor ...
#  2                  NaN                                                NaN
#  3                  NaN                                                NaN
#  4                  4.0  ['"Benefits, compensation, clean work environm...
#  ..                 ...                                                ...
#  895                3.4  ['"Unlimited PTO, and people do make use of it...
#  896                4.0  ['"Great work life balance and friendly manage...
#  897                NaN                                                NaN
#  898                NaN                                                NaN
#  899                NaN                                                NaN
#
#                                                    Cons  Benefits_rating  \
#  0    ['No Cons have been reported by the Glassdoor ...              2.2
#  1    ['"Antisocial and downright rude CEO, callous ...              5.0
#  2                                                  NaN              NaN
#  3                                                  NaN              NaN
#  4    ['No Cons have been reported by the Glassdoor ...              NaN
#  ..                                                 ...              ...
#  895  ['No Cons have been reported by the Glassdoor ...              5.0
#  896  ['"Below average pay for position" (in 1 revie...              4.0
#  897                                                NaN              NaN
#  898                                                NaN              NaN
#  899                                                NaN              NaN
#
#       Benefits_reviews
#  0                 NaN
#  1                 NaN
#  2                 NaN
#  3                 NaN
#  4                 NaN
#  ..                ...
#  895               NaN
#  896               NaN
#  897               NaN
#  898               NaN
#  899               NaN
#
#  [900 rows x 25 columns]}

# %%
dfs['Austria']
# Out:
#                          Company_name  Rating            Location  \
# 0               Riverty Services GmbH     3.9              Vienna
# 1            Infineon Technologies AG     4.2             Villach
# 2            Infineon Technologies AG     4.2             Villach
# 3            Infineon Technologies AG     4.2             Villach
# 4            Infineon Technologies AG     4.2             Villach
# ..                                ...     ...                 ...
# 865             Infineon Technologies     4.2             Villach
# 866                 Wien Energie GmbH     4.3  Gerasdorf bei Wien
# 867  Trenkwalder Personaldienste GmbH     3.9             Austria
# 868              Silicon Austria Labs     3.6             Villach
# 869                   Noir Consulting     5.0              Vienna
#
#                                              Job_title  \
# 0               Process Manager (m/f/d) 80% Homeoffice
# 1    Senior Staff Engineer Digital Verification (f/...
# 2    Senior Staff Engineer Product Development for ...
# 3    Component Verification and Product Characteriz...
# 4              Product Application Engineer (f/m/div)*
# ..                                                 ...
# 865  International Graduate Program: Senior Enginee...
# 866           Business Intelligence Specialist (w/m/d)
# 867  C++ Entwickler (m/w/d) mit Schwerpunkt Machine...
# 868  Cleanroom Process Engineer - Wet Processing (f...
# 869           .NET Software Engineer – Vienna, Austria
#
#                                            Description  Salary Job_age  \
# 0    Everything we do, starts with you.\r\nTogether...     NaN    30d+
# 1    You are looking for a new challenge to bring i...     NaN     25d
# 2    Do you want to get to know the development of ...     NaN     18d
# 3    You are looking for a new challenge to bring i...     NaN     25d
# 4    You enjoy working in an international team, in...     NaN     26d
# ..                                                 ...     ...     ...
# 865  Are you ready to start your career in a fast-m...     NaN     30d
# 866  Business Intelligence Specialist (w/m/d)\r\n==...     NaN     25d
# 867  Unser Kunde (KV EMG) ist ein international tät...     NaN     11d
# 868  Your future responsibilities\r\nThe process en...     NaN    30d+
# 869  .NET Software Engineer - Vienna, Austria\r\n(T...     NaN      6d
#
#      Easy_apply      Employees  Type_of_ownership  ... CEO_approval  \
# 0         False  5001 to 10000  Company - Private  ...         1.00
# 1         False         10000+   Company - Public  ...         0.95
# 2         False         10000+   Company - Public  ...         0.95
# 3         False         10000+   Company - Public  ...         0.95
# 4         False         10000+   Company - Public  ...         0.95
# ..          ...            ...                ...  ...          ...
# 865       False         10000+   Company - Public  ...         0.95
# 866       False            NaN                NaN  ...         1.00
# 867       False         10000+  Company - Private  ...         1.00
# 868       False        1 to 50      Self-employed  ...          NaN
# 869       False      51 to 200  Company - Private  ...         1.00
#
#      Career_opportunities Comp_&_benefits Culture_&_values  Senior_management  \
# 0                     3.7             3.2              3.9                3.5
# 1                     3.9             3.8              4.1                3.7
# 2                     3.9             3.8              4.1                3.7
# 3                     3.9             3.8              4.1                3.7
# 4                     3.9             3.8              4.1                3.7
# ..                    ...             ...              ...                ...
# 865                   3.9             3.8              4.1                3.7
# 866                   3.9             3.8              3.7                3.5
# 867                   3.5             3.1              3.8                3.5
# 868                   3.2             3.2              3.5                3.4
# 869                   4.2             4.7              4.2                4.5
#
#      Work/Life_balance                                               Pros  \
# 0                  4.0  ['"Good colleagues and overall atmosphere" (in...
# 1                  4.1  ['"Good work life balance and ambitious" (in 1...
# 2                  4.1  ['"Good work life balance and ambitious" (in 1...
# 3                  4.1  ['"Good work life balance and ambitious" (in 1...
# 4                  4.1  ['"Good work life balance and ambitious" (in 1...
# ..                 ...                                                ...
# 865                4.1  ['"Good work life balance and ambitious" (in 1...
# 866                4.4  ['No Pros have been reported by the Glassdoor ...
# 867                3.7  ['"ilfe balance and career growth" (in 3 revie...
# 868                3.9  ['"Good work environment." (in 4 reviews)', '"...
# 869                4.5  ['"Relaxed environment and tallented team" (in...
#
#                                                   Cons  Benefits_rating  \
# 0    ['"New strategy process is taking ages and peo...              4.0
# 1    ['"Descent pay, work life balance" (in 152 rev...              3.9
# 2    ['"Descent pay, work life balance" (in 152 rev...              3.9
# 3    ['"Descent pay, work life balance" (in 152 rev...              3.9
# 4    ['"Descent pay, work life balance" (in 152 rev...              3.9
# ..                                                 ...              ...
# 865  ['"Descent pay, work life balance" (in 152 rev...              3.9
# 866  ['"Zu viele low performer, welche in die Pensi...              NaN
# 867  ['"Horrible communication between departments,...              NaN
# 868  ['"Poor management." (in 3 reviews)', '"there ...              NaN
# 869  ['No Cons have been reported by the Glassdoor ...              NaN
#
#                                       Benefits_reviews
# 0                                                  NaN
# 1    ['Health Insurance (22 comments)\n"Great cover...
# 2    ['Health Insurance (22 comments)\n"Great cover...
# 3    ['Health Insurance (22 comments)\n"Great cover...
# 4    ['Health Insurance (22 comments)\n"Great cover...
# ..                                                 ...
# 865  ['Health Insurance (22 comments)\n"Great cover...
# 866                                                NaN
# 867                                                NaN
# 868                                                NaN
# 869                                                NaN
#
# [870 rows x 25 columns]

# %%
del CSVs_folder

# %% [markdown]
# ### 3. Remove rows only with NaNs

# %%
def process_dfs(dfs: dict[str, pd.DataFrame], method: Callable):
    differences = {}

    for country_name, country_df in dfs.items():

        country_df_before = country_df
        country_df: pd.DataFrame = method(country_df)

        is_difference = country_df_before.shape[0] != country_df.shape[0]

        if is_difference:
            differences[country_name] = (
                country_df_before.shape[0], 
                country_df.shape[0]
                )


    return differences

# %%
process_dfs(dfs=dfs, method = lambda x: x.dropna(how='all'))
# Out:
# {}

# %% [markdown]
# ### 4. Remove duplicates

# %%
process_dfs(dfs=dfs, method = lambda x: x.drop_duplicates())
# Out:
# {'Austria': (870, 93),
#  'Belgium': (810, 165),
#  'Czech_Republic': (870, 121),
#  'Denmark': (600, 119),
#  'Finland': (285, 230),
#  'France': (900, 137),
#  'Germany': (900, 286),
#  'Greece': (720, 119),
#  'Hungary': (900, 140),
#  'Ireland': (900, 364),
#  'Israel': (900, 120),
#  'Italy': (600, 143),
#  'Luxembourg': (390, 126),
#  'Netherlands': (900, 193),
#  'Norway': (391, 317),
#  'Poland': (420, 131),
#  'Portugal': (900, 209),
#  'Romania': (900, 131),
#  'Spain': (690, 198),
#  'Sweden': (900, 135),
#  'Switzerland': (900, 159),
#  'Turkey': (900, 136),
#  'United_Kingdom': (900, 130),
#  'United_States': (900, 220)}

# %% [markdown]
# There is huge amount of duplicates.

# %% [markdown]
# ### 5. Remove empty columns

# %%
process_dfs(dfs=dfs, method = lambda x: x.dropna(axis=1, how='all'))
# Out:
# {}

# %% [markdown]
# #### 6. Split `Location` column into `Region`, `Country`, `State` and `City`.

# %% [markdown]
# ##### 6.1 Add columns

# %%
# todo difference languages

def apply_locations(df, country, region):

    # All those fancy, pansy names for the remote
    remote = [
        "Home office",
        "Telecommute",
        "Virtual office",
        "Off-site",
        "Work from anywhere",
        "Distributed team",
        "Location-independent",
        "Mobile workforce",
        "Cloud office",
        "Online workspace",
        "Digital nomad",
        "Flexible location",
        "Anywhere office",
        "Distance work",
        "Virtual workplace",
        "Mobile office",
        "Roaming job",
        "Borderless office",
        "Satellite office",
        "Remote-enabled",
        "Work from afar"
    ]

    df = dfs[country]

    df['Location'] = df['Location'].apply(lambda location: np.nan if location is not np.nan and location.strip() == "" else location)
    df['Location'] = df['Location'].apply(lambda location: "Remote" if location is not np.nan and location.lower() in remote else location)

    df['City'] = df['Location'].apply(lambda location: location.split(',')[0] if location is not np.nan and "," in location else location)
    df['State'] = df['Location'].apply(lambda location: location.split(',')[1] if location is not np.nan and "," in location else np.nan)

    df['Country'] = country
    df['Region'] = region

    return df

for country_name, country_df in dfs.items():

    region = "Europe"
    if country_name in ["United_States", "Canada"]:
        region = "North America"

    dfs[country_name] = apply_locations(country_df, country_name, region)

# %%
dfs['Austria'].iloc[: , -4:30].head()
# Out:
#       City  State  Country  Region
# 0   Vienna    NaN  Austria  Europe
# 1  Villach    NaN  Austria  Europe
# 2  Villach    NaN  Austria  Europe
# 3  Villach    NaN  Austria  Europe
# 4  Villach    NaN  Austria  Europe

# %%
dfs['United_States'].iloc[: , -4:30].head()
# Out:
#           City State        Country         Region
# 0  Santa Clara    CA  United_States  North America
# 1     Dearborn    MI  United_States  North America
# 2  Santa Clara    CA  United_States  North America
# 3       Newton    MS  United_States  North America
# 4       Remote   NaN  United_States  North America

# %% [markdown]
# ##### 6.2 Remove `Location` column

# %%
for df in dfs.values():
    del df['Location']

# %%
dfs['Austria'].columns
# Out:
# Index(['Company_name', 'Rating', 'Job_title', 'Description', 'Salary',
#        'Job_age', 'Easy_apply', 'Employees', 'Type_of_ownership', 'Sector',
#        'Founded', 'Industry', 'Revenue_USD', 'Friend_recommend',
#        'CEO_approval', 'Career_opportunities', 'Comp_&_benefits',
#        'Culture_&_values', 'Senior_management', 'Work/Life_balance', 'Pros',
#        'Cons', 'Benefits_rating', 'Benefits_reviews', 'City', 'State',
#        'Country', 'Region'],
#       dtype='object')

# %%
dfs['United_States'].columns == dfs['Austria'].columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %% [markdown]
# ### 7. Clean jobs to only revenant ones

# %%
def is_data_engineering_job(job_title: str, specs_variants: list[str] | list[list[str]] = [], terms_variants: list[str] | list[list[str]]= []):

    def flatten(_list):
        """
        Flatten a list of any dimension to a one dimensional list.
        """
        result = []
        for item in _list:
            if isinstance(item, list):
                result.extend(flatten(item))
            else:
                result.append(item)
        return result
    
    specs_variants = flatten(specs_variants)
    terms_variants = flatten(terms_variants)

    specializations = ["Engineer", "Engineering", "Consultant", "architect", "SPECIALIST", "Manager", "Developer", "Architecture", "Administrator", "Head of", "Lead"] + specs_variants

    # We try to not take into account back-end, fullstack, they are somehow different domain, but sometimes in some companies they are data engineers
    data_terms = ["Data", "ETL", "Cloud", "Analytical", "Analytics", "BI", "Buisness Intelligence", "Buisness Analytics", "Database", "Pipeline", "Metadata", "Monitoring", "Datacenter"] + terms_variants

    any_in_specs = isinstance(job_title, str) and any(isinstance(spec, str) and spec.lower() in job_title.lower() for spec in specializations)

    any_in_terms = isinstance(job_title, str) and any(isinstance(term, str) and term.lower() in job_title.lower() for term in data_terms)

    invalid = ["Mobile engineer", "Biomedical Engineer", "Engineering Geologist", "Geotechnical Engineer", "Electrical Engineer", "Project Manager", "Quality Engineer", "Mechanical Engineer", "Mechanical-Design Engineer"]
    
    is_valid = isinstance(job_title, str) and not any(isinstance(term, str) and term.lower() in job_title.lower() for term in invalid)

    return any_in_specs and any_in_terms and is_valid

# %%
def show_unique_and_its_len(df: pd.Series):
    print(f"{len(df.unique())} :\n{df.unique()}")

# %% [markdown]
# ##### 7.1 Austria

# %%
selector = 'Austria'

# German Belgian, German Austrian, German Swiss, German Luxembourgian, German Alsatian
specializations_DE = ["Ingenieur", "Berater", "Architekt", "SPEZIALIST", "Manager", "Entwickler", "Architektur", "Architecture", "Administrator"]
data_terms_DE = ["Daten", "ETL", "Cloud", "Analytisch", "Analytics", "BI", "Business Intelligence", "Business Analytics", "Datenbank", "Pipeline", "Metadaten", "Überwachung", "Rechenzentrum", "Datenzentrum"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 91 :
# ['Process Manager (m/f/d) 80% Homeoffice'
#  'Senior Staff Engineer Digital Verification (f/m/div)*'
#  'Senior Staff Engineer Product Development for GaN-based ICs (f/m/div)*'
#  'Component Verification and Product Characterization Engineer (f/m/div)*'
#  'Product Application Engineer (f/m/div)*'
#  'Freelance Hardware/ Data Centre Field Engineer'
#  'IT Solution Engineer (m/w/d)' 'Data Analyst & -Engineer (m/w/d)'
#  'Android Mobile Developer' 'Sr. Software Development Engineer – C++'
#  'Data Engineer, Analytics (m/f/x)' 'Data Engineer (m/w/d)'
#  'Data Engineer im Bereich Data Integration (m/w/d)'
#  'Data Platform Engineer (m/f/x)'
#  'Head of Formulation Development (m/f/d)' 'Full Stack Engineer (m/f/x)'
#  'Data Engineer' 'Data Engineer (m/f/d) - maternity cover 1yr.'
#  'Data Engineer, CRM (m/f/x)' 'Data Engineer*'
#  'Maschinenbautechniker (m/w/d) / Data Engineer (m/w/d)'
#  'Backend Engineer (m/f/x)' 'DATABASE ADMINISTRATOR / DATA ENGINEER'
#  'System Engineer (m/w/d)' 'DevOps Engineer'
#  'Data Warehouse DevOps Engineer (f/m/x)'
#  'Data Scientist / Machine Learning Engineer (m/w/d)'
#  'Data Virtualization (Denodo) Engineer (f/m/x)'
#  '(Senior) Data Engineer (m/w/d) (Remote innerhalb von...'
#  'Senior Data Engineer (m/f/x)'
#  'International Graduate Program: Senior Engineer Technology Development (f/m/div)*'
#  'Geoinformation System Engineer (f/m/d)'
#  'Research Engineer - Optoelectronics and Laser Engineer for Photonics System Technologies (f/m/d)'
#  'internship: Improvement Engineer (f/m/d)' 'Mechanical Engineer (F/M/D)'
#  'C++ Entwickler (m/w/d) mit Schwerpunkt Machine Learning'
#  'CAMO Engineer (Avionics) (m/f/d)'
#  'Internship: Lab Verification Engineer in the AMS Lab of the Development Center Villach (f/m/div)*'
#  'Senior Staff Product Definition Engineer (f/m/div)*'
#  'Staff Engineer Wafer Technology & Device Development (f/m/div)*'
#  'IT Support Engineer' 'Software Development Engineer (f/m/d)'
#  'Internship: Software/ Mechatronics Engineer (f/m/d)'
#  'Process Integration/Product Engineer (f/m/div)* for High Voltage Power MOSFET'
#  '(Senior) Full-Stack Software Engineer (m/f/d)'
#  'Cleanroom Process Engineer - Plasma Etch (f/m/d)'
#  'Cleanroom Process Engineer - Wet Processing (f/m/d)'
#  'IT Operations Engineer (f/m/d)' 'Senior Data Engineer | Europe | Remote'
#  'QA Engineer ( Manual)'
#  'Advanced Engineering eDrive Control Systems and Software Engineer (m/f/d)'
#  'Staff Engineer Wafer Test (f/m/div)*'
#  'IT Support Engineer (m/f/x) for internal Employee Support'
#  'QA Engineer (M/F/T)' 'Junior - Data Engineer (m/f/x)'
#  'Integration Solution Engineer (f/m/div)*' 'QA Automation Engineer'
#  'Cleanroom Process Engineer - E-beam Photolithography (f/m/d)'
#  'Internship: High Speed and RF LAB Validation Engineer in Development Center Villach (f/m/div)*'
#  'Development Engineer and Data Analyst (w/m/d)'
#  'Development Engineer in the field of powertrain system development (f/m/d)'
#  'Senior Automation QA Engineer'
#  'Optical Engineer - Technology Development' 'EV Delivery Engineer'
#  'Machine Learning & AI Engineer (m/f/d)' 'Software Engineer (m/f/d)'
#  'Full Stack Engineer - Maritime' 'Vibration Measurement Engineer (m/f/d)'
#  'Junior System Engineer (Ultra-Wide-Band) (m/f/d)'
#  'Automotive Product Owner (m/f/d)'
#  'Business Intelligence Specialist (w/m/d)'
#  'Expert Device Technology (m/w/d)'
#  'Flight Test Engineer and UAV Pilot (m/f/d)'
#  'Regulatory Affairs Associate (m/w/d)' 'Aeroacoustics Engineer (m/f/d)'
#  'Data Engineer – Python and SQL Specialist (m/f/d)'
#  'Lab Engineer for Failure Analysis Laboratory (m/f/d)'
#  'Graduate Secondary Technical College (HTL) Development Engineer Commercial Vehicles f/m/d'
#  'Senior Cost Engineer'
#  'Global Product Manager E-Motor Test Systems & Drives f/m/d'
#  'Process Engineer for Work Preparation - FP-HMI'
#  'Calibration Engineer for Transmission, Hybrid, BEV & E-Axle (f/m/d)'
#  'System Administrator (m/f/d) - hybrid'
#  'System Engineer – Monitoring & Analytics (m/f/d)'
#  'Senior Data Engineer (f/m/div)*' 'Senior Mobile App Developer (f/m/x)'
#  'Research Engineer (m/w/d) – Backend Developer:in for Data-Centric Services Klimawandelfolgen und Gefahrenschutz'
#  'Senior Research Engineer (m/f/d) for Integrated Mobility Planning'
#  'Software Engineer (f/m/d)*'
#  'IT Support Engineers für die Bereiche Azure Data Analytics, eCommerce oder Business Applications (m/w/d)'
#  '.NET Software Engineer – Vienna, Austria']

# %%
df = dfs[selector]
filtered_df = df[df.apply(lambda row: is_data_engineering_job(row['Job_title'], specializations_DE, data_terms_DE), axis=1)]

# %%
show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 29 :
# ['Freelance Hardware/ Data Centre Field Engineer'
#  'Data Analyst & -Engineer (m/w/d)' 'Android Mobile Developer'
#  'Data Engineer, Analytics (m/f/x)' 'Data Engineer (m/w/d)'
#  'Data Engineer im Bereich Data Integration (m/w/d)'
#  'Data Platform Engineer (m/f/x)' 'Data Engineer'
#  'Data Engineer (m/f/d) - maternity cover 1yr.'
#  'Data Engineer, CRM (m/f/x)' 'Data Engineer*'
#  'Maschinenbautechniker (m/w/d) / Data Engineer (m/w/d)'
#  'DATABASE ADMINISTRATOR / DATA ENGINEER'
#  'Data Warehouse DevOps Engineer (f/m/x)'
#  'Data Scientist / Machine Learning Engineer (m/w/d)'
#  'Data Virtualization (Denodo) Engineer (f/m/x)'
#  '(Senior) Data Engineer (m/w/d) (Remote innerhalb von...'
#  'Senior Data Engineer (m/f/x)' 'Senior Data Engineer | Europe | Remote'
#  'Junior - Data Engineer (m/f/x)'
#  'Development Engineer and Data Analyst (w/m/d)'
#  'Business Intelligence Specialist (w/m/d)'
#  'Data Engineer – Python and SQL Specialist (m/f/d)'
#  'System Engineer – Monitoring & Analytics (m/f/d)'
#  'Senior Data Engineer (f/m/div)*' 'Senior Mobile App Developer (f/m/x)'
#  'Research Engineer (m/w/d) – Backend Developer:in for Data-Centric Services Klimawandelfolgen und Gefahrenschutz'
#  'Senior Research Engineer (m/f/d) for Integrated Mobility Planning'
#  'IT Support Engineers für die Bereiche Azure Data Analytics, eCommerce oder Business Applications (m/w/d)']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.2 Belgium

# %%
selector = 'Belgium'

# Dutch NL, Dutch BE
specializations_NL = ["SPECIALIST", "Engineering", "Manager", "architect", "Beheerder", "Ingenieur", "Adviseur", "Ontwikkelaar", "Architect", "Techniek", "Architectuur"]
data_terms_NL = ["Business Analytics", "Monitoring", "Leiding", "Metadata", "Cloud", "Business Intelligence", "Data", "Analytisch", "BI", "Database", "Datacenter", "Pipeline", "Analytics", "Bedrijfsanalyse", "Bedrijfsinformatie", "ETL"]

# French, Canadian French, Swiss French, Belgian French
specializations_FR = ["Architecte", "Développeur", "architecte", "SPECIALISTE", "SPÉCIALISTE", "Consultant", "Conseiller", "Ingénieur", "Administrateur", "Architecture", "Manager", "Ingénierie"]
data_terms_FR = ["Analyse", "Cloud", "Business Intelligence", "Analytique", "BI", "Analytique d'affaires", "Analyse de données", "Surveillance", "Métadonnées", "Données", "Pipeline", "Base de données", "Business Analytics", "Analytics", "Centre de données", "ETL", "Data", "Analyse d'affaires", "Intelligence d'affaires"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 136 :
# ['Data Engineer (met affiniteit voor Data Science)' 'Data Engineer'
#  'Data engineer / ETL consultant' 'Medior Data Protection Engineer'
#  'data manager' 'AWS Data Engineer' 'Azure Data Engineer'
#  'Project controls engineer' 'DevOps Engineer (Data)'
#  'Mechanical Design Engineer (Hudson Sharp)'
#  'Maintenance Reliability Engineer' 'Junior Integration Engineer'
#  'Datacenter Engineer' 'District Engineer' 'Azure Data Platform Engineer'
#  'Computer vision and image recognition data scientist' 'data analist'
#  'Regional Product Engineer' 'Security Engineer | Last step before CISO'
#  'Security Engineer | GreenTech Company'
#  'Field and solutions engineer IOT'
#  'Data Engineer | Digital Manufacturing Platform' 'Senior data engineer'
#  'Application Controls Engineer' 'Expert Talent Advisor'
#  'Reliability Engineer' 'Developer' 'Signalling Design Engineer'
#  'Data Migration Consultant' 'Production Engineer' 'DataOps Engineer'
#  'DevOps engineer' 'Quality & Compliance Engineer'
#  'Engineer Elektriciteit' 'Lab Qualification Engineer'
#  'Robotics Automation Consultant' 'Network & security engineer'
#  'Supply Chain Engineer' 'B2B Data Engineer' 'Cloud system engineer'
#  'Continuous Improvement Engineer' 'Software engineer Supply Chain'
#  'Traineeship Quality & Compliance' 'Linux system engineer'
#  'Computer System Validation Engineer' 'CYBERSECURITY ENGINEER (M/F/X)'
#  'Field Service Engineer Turbochargers' 'CALIBRATION ENGINEER (F/M/X)'
#  'Mobile engineer' 'R&D Professional – Power Systems / Data Engineer'
#  'ICT Traineeship - Data & Data Analytics'
#  'Onderzoeker Innovatie Renovatie Brussel'
#  'Onderzoeker Smart Buildings Brussel' 'Business Applications Developer'
#  'Photonics Design Engineer' 'Technical Analyst Financial Crime'
#  'System Administrator' 'B2B Voice Testing & Automation Engineer'
#  'Project Ingenieur Quality Management Systems'
#  'Project Engineer Sustainability' 'Data Platform Integration Engineer'
#  'PRODUCTION DATA ENGINEER' 'DATA ENGINEER'
#  'Projectingenieur sterilisatie/validatie' 'System Engineer Datacenter'
#  'Cloud solution architect' 'Audit and Compliance Specialist'
#  'DATA ENGINEER VOOR SOFWAREBEDRIJF BINNEN LOGISTIEKE SECTOR'
#  'quality system engineer' 'Entry Level CRA'
#  'Alcatel OXE Support Engineer' 'Plant Engineer automotive industrie'
#  'System Engineer - Safety & Security'
#  'Full-stack Developer | Digital Manufacturing Platform'
#  'Technical Coordinator – Industriële Motoren'
#  'ICT Traineeship - Networks, Telecom & Cybersecurity'
#  'Data Integrations Engineer' 'Process Engineer | Doorgroeimogelijkheden'
#  'DATA & APPLICATION SPECIALIST' 'Industrial Data Engineer'
#  'Analytical Maintenance Engineer' 'Software Engineer'
#  'ICT Service Engineer' 'Backend Java Developer | Spring Expert'
#  'DATA ENGINEER & MODELER' 'Process Engineer' 'Data analyst'
#  'production supervisor' 'SYSTEM ENGINEER' 'E2E DATABASE ENGINEER'
#  'Process Engineer Automotive Industry' 'Proces Ingenieur | Groeitraject'
#  'QA Complaint specialist' 'CONTROL ENGINEER (H/F/X)'
#  'Ingenieur elektromechanica' 'Automation Engineer' 'Cloud Data Engineer'
#  'Data Engineer - First IT' 'Exellys - Data Engineer'
#  'SENIOR DATA ENGINEER' 'IT System Engineer' 'QA Support Engineer'
#  'GMP Support Engineer'
#  'Data Engineer - Behaal Extra Certificaten, End-To-End'
#  'Ervaren Software Engineer' 'AUTOMATION SYSTEM & DATA ENGINEER'
#  'System Engineer Azure' 'DevOps Engineer*'
#  'Open-source Database Reliability Engineer' 'Senior Data Engineer'
#  'Medical Advisor' 'Project Engineer' 'IT Infrastructure Engineer'
#  'Electrical Engineer | Gent | 32 verlofdagen'
#  'SOFTWARE ENGINEER AUTOMATION' 'Quality System Engineer'
#  'SOFTWARE DEVELOPER' 'Technical Support Engineer Infection Control'
#  'Allround IT Support Engineer' 'IT Allround - support engineer'
#  'DEVOPS ENGINEER' 'I-Series (IBM System-I, AS/400) software engineer'
#  'MAINTENANCE ENGINEER' 'Process ingenieur' 'Technical Support Engineer'
#  'SOFTWARE ENGINEER (JAVA)'
#  '5G Core Network Operations and Automation Engineer'
#  'Database Devops Engineer' 'BI Azure Analyst' 'Process engineer'
#  'IT Systeem- en Netwerkbeheerder' 'Lean Expert' 'IT Project Manager'
#  'ICT Traineeship - Development & Packages'
#  'ICT Traineeship - Infrastructure & Operations' nan]

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_FR, specializations_NL, specializations_DE],
        [data_terms_FR, data_terms_NL, data_terms_DE]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 41 :
# ['Data Engineer (met affiniteit voor Data Science)' 'Data Engineer'
#  'Data engineer / ETL consultant' 'Medior Data Protection Engineer'
#  'data manager' 'AWS Data Engineer' 'Azure Data Engineer'
#  'DevOps Engineer (Data)' 'Maintenance Reliability Engineer'
#  'Datacenter Engineer' 'Azure Data Platform Engineer'
#  'Data Engineer | Digital Manufacturing Platform' 'Senior data engineer'
#  'Reliability Engineer' 'Data Migration Consultant' 'DataOps Engineer'
#  'B2B Data Engineer' 'Cloud system engineer'
#  'R&D Professional – Power Systems / Data Engineer'
#  'Project Engineer Sustainability' 'Data Platform Integration Engineer'
#  'PRODUCTION DATA ENGINEER' 'DATA ENGINEER' 'System Engineer Datacenter'
#  'Cloud solution architect'
#  'DATA ENGINEER VOOR SOFWAREBEDRIJF BINNEN LOGISTIEKE SECTOR'
#  'Data Integrations Engineer' 'DATA & APPLICATION SPECIALIST'
#  'Industrial Data Engineer' 'Analytical Maintenance Engineer'
#  'DATA ENGINEER & MODELER' 'E2E DATABASE ENGINEER' 'Cloud Data Engineer'
#  'Data Engineer - First IT' 'Exellys - Data Engineer'
#  'SENIOR DATA ENGINEER'
#  'Data Engineer - Behaal Extra Certificaten, End-To-End'
#  'AUTOMATION SYSTEM & DATA ENGINEER'
#  'Open-source Database Reliability Engineer' 'Senior Data Engineer'
#  'Database Devops Engineer']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.3 Canada

# %%
selector = 'Canada'

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 11 :
# ['BI Engineer' 'Analytics Engineer' 'Senior Analytics Engineer'
#  'Analytics Implementation Engineer'
#  'Financial Engineer/ACM Business Analyst'
#  'Business Analyst & Process Engineer'
#  'Analyst/Senior Associate, AML - Financial Engineering & Modeling (FEM)'
#  'Capital & Maintenance Program Analyst'
#  'Business Analyst Engineering Budget Planning'
#  'Analytics Engineering Manager'
#  'Senior Manager, Project Delivery Business Analyst, Retail & Small Business (Contract)']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_FR],
        [data_terms_FR]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 5 :
# ['BI Engineer' 'Analytics Engineer' 'Senior Analytics Engineer'
#  'Analytics Implementation Engineer' 'Analytics Engineering Manager']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.4 Czech_Republic

# %%
selector = 'Czech_Republic'

specializations_CZ = ["Inženýr", "Konstruktér", "Architekt", "SPECIALISTA", "Manažer", "Vývojář", "Architektura", "Správce"]
data_terms_CZ = ["Data", "ETL", "Cloud", "Analytický", "Analytika", "BI", "Business Intelligence", "Business Analytics", "Databáze", "Pipeline", "Metadata", "Monitorování", "Datacentrum"]

specializations_SK = ["Inžinier", "Konzultant", "architekt", "SPECIALISTA", "Manažér", "Vývojár", "Architektúra", "Správca"]
data_terms_SK = ["Data", "ETL", "Cloud", "Analytický", "Analytika", "BI", "Business Intelligence", "Business Analytics", "Databáza", "Pipeline", "Metadata", "Monitorovanie", "Datacentrum"]

specializations_HU = ["Mérnök", "Mérnöki", "Tanácsadó", "építész", "SZAKÉRTŐ", "Menedzser", "Fejlesztő", "Architektúra", "Rendszergazda"]
data_terms_HU = ["Adat", "ETL", "Felhő", "Elemző", "Analitika", "BI", "Üzleti Intelligencia", "Üzleti Analitika", "Adatbázis", "Csővezeték", "Metadaták", "Monitoring", "Adatközpont"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 97 :
# ['IT Desktop Support Engineer Technician'
#  'Cloud Services Engineer (Based in Germany)' 'Technical Systems Manager'
#  'Cloud Engineer (f/m/d)' 'Data Engineer'
#  'Senior Data Engineer - Ingestion'
#  'Field Service Engineer Austria & Hungary & Slovakia & Czechia'
#  'Part-time - Junior Data Analytics Engineer'
#  'Junior Data Engineer - AI & Data tým'
#  'Data Processing and Automation-Development Engineer (f/m/d)'
#  'Data Engineer - Part time for a student' 'Technolog/Industrial Engineer'
#  'Design Engineer' 'DATA ENGINEER' 'Data QA Engineer'
#  'Catia V5 Design Engineer (m/ž) - projekt. řízení automotive'
#  'Senior Quality Engineer' 'Junior SAS Engineer' 'ML Engineer - peoly'
#  'Big data engineer' 'SWE - Full Stack Engineer - CoreOS'
#  'Staff Data Engineer' 'Junior Software Engineer'
#  'Strojní Engineer (procesy a technologie)'
#  'Test and application engineer' 'Sr Data Engineer' 'Application Engineer'
#  'L1 Support Engineer with English 24x7'
#  'Junior Machine Learning Engineer - Part time for a student'
#  'Data Analytics Engineer' 'Global Azure Data Architect (Engineer)'
#  'Automation Engineer' 'Senior Software Engineer'
#  'Lead Back-end & DevOps Engineer (Remote EU - fluent)'
#  'DATA ENGINEER (BIOTECH)' 'Data Engineer & Process Mining Architect'
#  'Automotive Application Support Engineer - Imaging EMEA M/F'
#  'Big Data Engineer Junior' 'IT NETWORK ENGINEER'
#  'Digital Prototype Development Engineer (f/m/d)'
#  'IT Specialist - Data Engineer' 'Senior AEM Engineer - Backend'
#  'DSS/ Field Services Engineer' 'Senior React Engineer'
#  'Global Support Engineer – Mobile Data Network Czechia'
#  'Big Data DevOps Engineer Junior' 'Senior Data Engineer'
#  'Technical Support Engineer'
#  'Data Engineer - Engineering & Manufacturing'
#  'Industrial and Systems Engineer'
#  'evergreen Public 360° Senior Cloud Data & AI Engineer'
#  'IT Support Engineer' 'Optics Engineer' 'QA Engineer'
#  'Data Analyst/ Machine Learning Engineer'
#  'Sr. Application Sales Engineer' 'Data Engineer/Scientist'
#  'Drive/Switchboard Project Engineer' 'Intern Front-End Engineer'
#  'Site Support Engineer |' 'Production and Process Quality Engineer'
#  'Senior Test Engineer' 'ML Ops Engineer' 'QUALITY ENGINEER'
#  'Data Engineer - ML Ops' 'Software Engineer - Data Platform'
#  'DPČ - Associate Offer Engineer' 'DPČ-Associate Steel Structure Engineer'
#  'Internship/SW Developer - part time' 'Application Support Engineer'
#  'Development Engineer in e-Drive – Test Automation (f/m/d)'
#  'HW/Communication Engineer (m/f/d) - Brno'
#  'Senior Engineer, Advanced Manufacturing Engineering - Screw, Clipping, Assembly'
#  'Junior Offer Engineer' 'Data Engineer - ETL Developer (SSIS)'
#  'Senior Data Engineer / ETL Developer (SSIS)' 'Localization Engineer'
#  'Data Analytics and PC&IS Dry Laundry GTO'
#  'Application Engineer - suitable for graduates'
#  'Sr. Malware Researcher - Windows Software Engineer' 'Inženýr kvality'
#  'Facility manažér' 'Windows Low Level Engineer - Fleet Engineering team'
#  'Test Engineer Structure' 'Manufacturing Engineer, Mikulov'
#  'Quality Engineer' 'AI Engineer'
#  'Technical Support Engineer I with German'
#  'Support Specialist / Engineer - Imaging Systems'
#  'Technical Sales Support Engineer in Electrical Engineering'
#  'Staff Software Engineer' 'Electronic Hardware Engineer'
#  'Fuel & Hydraulics Specialist Engineer' 'AWS Cloud Engineer'
#  'Lean Manufacturing Engineer VIE'
#  'SAP Labs iXp Intern - Software Engineer (DPC, part-time)'
#  'HUS Data Engineer']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_FR, specializations_NL, specializations_DE, specializations_HU],
        [data_terms_FR, data_terms_NL, data_terms_DE, data_terms_HU]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 32 :
# ['Cloud Services Engineer (Based in Germany)' 'Cloud Engineer (f/m/d)'
#  'Data Engineer' 'Senior Data Engineer - Ingestion'
#  'Part-time - Junior Data Analytics Engineer'
#  'Junior Data Engineer - AI & Data tým'
#  'Data Processing and Automation-Development Engineer (f/m/d)'
#  'Data Engineer - Part time for a student' 'DATA ENGINEER'
#  'Data QA Engineer' 'Big data engineer' 'Staff Data Engineer'
#  'Sr Data Engineer' 'Data Analytics Engineer'
#  'Global Azure Data Architect (Engineer)' 'DATA ENGINEER (BIOTECH)'
#  'Data Engineer & Process Mining Architect' 'Big Data Engineer Junior'
#  'IT Specialist - Data Engineer'
#  'Global Support Engineer – Mobile Data Network Czechia'
#  'Big Data DevOps Engineer Junior' 'Senior Data Engineer'
#  'Data Engineer - Engineering & Manufacturing'
#  'evergreen Public 360° Senior Cloud Data & AI Engineer'
#  'Data Analyst/ Machine Learning Engineer' 'Data Engineer/Scientist'
#  'Data Engineer - ML Ops' 'Software Engineer - Data Platform'
#  'Data Engineer - ETL Developer (SSIS)'
#  'Senior Data Engineer / ETL Developer (SSIS)' 'AWS Cloud Engineer'
#  'HUS Data Engineer']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.5 Denmark

# %%
selector = 'Denmark'

specializations_DK = ["Ingeniør", "Konsulent", "Arkitekt", "SPECIALIST", "Manager", "Udvikler", "Arkitektur", "Administrator"]

data_terms_DK = ["Data", "ETL", "Cloud", "Analytisk", "Analyse", "BI", "Forretningsanalyse", "Database", "Pipeline", "Metadata", "Overvågning", "Datacenter"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 89 :
# ['Data Scientist / Machine Learning Engineer, FinTech Remote'
#  'Lead Instrument Engineer' 'Lead Structural Engineer' 'Data engineer'
#  'Lead Electrical Engineer' 'Data Engineer' 'Associate Data Engineer'
#  'Data Platform Engineer' 'Operations Engineer til Big Data'
#  'Student Data Engineer' 'Data Engineer for Telia'
#  'Forward-deployed Data Engineer' 'Experienced Data Engineer'
#  'Junior Backend Engineer' 'Data Engineer - QuantumBlack'
#  'Data Center Engineer' 'Analytics Engineer'
#  'Senior Data & Automation Engineer HR Technology'
#  'Business Data Engineer'
#  'Integrated Logistics Support Engineer, Lystrup or Søborg'
#  'Software Engineer' 'Machine Learning Engineer'
#  'DATA ENGINEER, PROCESS DATA AND ANALYTICS, NOVOZYMES'
#  'Senior Data Engineer in SuperAI' 'Lead Machine Learning Engineer'
#  'Data/Software Engineer' 'Lead Data Engineer' 'QAQC Turnover Engineer'
#  'Sr Machine Learning Research Engineer @ Corti'
#  'Data Engineer til bekæmpelse af skatteunddragelse'
#  'Machine Learning Engineer Intern – for fast growing MedTech Start-Up'
#  'SAP Data Lifecycle Engineer'
#  'Cloud Engineer for our Computer Vision and MLOps area'
#  'Graduate Software Engineer' 'Data Solutions Engineer'
#  'Data Specialist, Snowflake Engineer - Copenhagen:'
#  'Data Engineers and Data Analysts for Copenhagen' 'Senior Data Engineer'
#  'Senior Software Engineer, Energy Transition Platform, Hybrid 2+ days on average in our fantastic office! (Full remote available in some cases)'
#  'Field Service Engineer - EMEA' 'Student Assistant Software Engineer'
#  '(Senior) Data Engineer, Data Engineering & Bioinformatics'
#  'Data Engineer with an interest in creating value from data'
#  'Data Engineer/Project Lead - Copenhagen'
#  'Automation Engineer with Data Historian' 'Test Engineer (student)'
#  'Senior Fullstack Software Engineer' 'Senior Frontend Software Engineer'
#  'Senior Software Engineer'
#  'Senior Frontend Software Engineer – Decarbonization'
#  'Senior C# Software Engineer for Data Warehouse Product Area'
#  'Senior Data Engineer (Azure)' 'Backend Software Engineer'
#  'Experienced ML Engineer to SuperAI' 'Software Engineer- Backend'
#  'Senior Software Engineer – PurpleSea Distributed Cache'
#  'MAC Engineer (Freelancer)' 'Lead Software Engineer'
#  'Senior Software Engineer (PHP) - Google Sheets'
#  'Experienced Cloud Engineer'
#  'Data engineer med øje for den tværgående arkitektur'
#  'Staff Frontend Engineer' 'Data Engineer Director'
#  'Data Engineer - Consulting'
#  'Software Engineer, Energy Transition Platform, Hybrid 2+ days on average in our fantastic office! (Full remote available in some cases)'
#  'Cloud Infrastructure Engineer - Scientific Data Platform at R&D IT'
#  'Lead Engineer, Energy Transition Platform, Hybrid 2+ days on average in our fantastic office! (Full remote available in some cases)'
#  'Cable Installation Engineer (freelancer)' 'Software Test Engineer'
#  'Senior Software Engineer (Backend)– Decarbonization'
#  'Engineering Director' 'VP Engineering (Network Design)'
#  'Principal Software Engineer' 'Senior Quantum Software Engineer'
#  'Senior Backend Engineer (Kotlin & Java) - Reporting & Insights'
#  'Experienced Business Intelligence Developer to join our exciting data journey'
#  'Clinical Evidence Lead (PDF)' 'Senior Data Engineer for Brøndby'
#  'Software Implementation Specialist' 'Senior Propulsion Engineer'
#  'Test Automation Engineer - Applications / Global world-leading audio and video technology group'
#  'IT Design Engineer - Traffic Management System'
#  'DevOps Engineer (Splunk)' 'Technical Support'
#  'Technical Product Owner – Edge (Warehouse & Vessels)'
#  'Senior R&D Scientist / Engineer in ALD Materials & Processes'
#  'Data Engineer (Nordic based)' 'Cloud Data Engineer'
#  'Head of Data & Insights (m/f/d)']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_DK],
        [data_terms_DK]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 42 :
# ['Data Scientist / Machine Learning Engineer, FinTech Remote'
#  'Data engineer' 'Data Engineer' 'Associate Data Engineer'
#  'Data Platform Engineer' 'Operations Engineer til Big Data'
#  'Student Data Engineer' 'Data Engineer for Telia'
#  'Forward-deployed Data Engineer' 'Experienced Data Engineer'
#  'Data Engineer - QuantumBlack' 'Data Center Engineer'
#  'Analytics Engineer' 'Senior Data & Automation Engineer HR Technology'
#  'Business Data Engineer'
#  'DATA ENGINEER, PROCESS DATA AND ANALYTICS, NOVOZYMES'
#  'Senior Data Engineer in SuperAI' 'Data/Software Engineer'
#  'Lead Data Engineer' 'Data Engineer til bekæmpelse af skatteunddragelse'
#  'SAP Data Lifecycle Engineer'
#  'Cloud Engineer for our Computer Vision and MLOps area'
#  'Data Solutions Engineer'
#  'Data Specialist, Snowflake Engineer - Copenhagen:'
#  'Data Engineers and Data Analysts for Copenhagen' 'Senior Data Engineer'
#  '(Senior) Data Engineer, Data Engineering & Bioinformatics'
#  'Data Engineer with an interest in creating value from data'
#  'Data Engineer/Project Lead - Copenhagen'
#  'Automation Engineer with Data Historian'
#  'Senior C# Software Engineer for Data Warehouse Product Area'
#  'Senior Data Engineer (Azure)' 'Experienced Cloud Engineer'
#  'Data engineer med øje for den tværgående arkitektur'
#  'Data Engineer Director' 'Data Engineer - Consulting'
#  'Cloud Infrastructure Engineer - Scientific Data Platform at R&D IT'
#  'Experienced Business Intelligence Developer to join our exciting data journey'
#  'Senior Data Engineer for Brøndby' 'Data Engineer (Nordic based)'
#  'Cloud Data Engineer' 'Head of Data & Insights (m/f/d)']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.6 Finland

# %%
selector = 'Finland'

specializations_FI = ["Insinööri", "Konsultti", "Arkkitehti", "ERITYISOSAAMINEN", "Johtaja", "Kehittäjä", "Arkkitehtuuri", "Ylläpitäjä"]

data_terms_FI = ["Data", "ETL", "Pilvi", "Analytiikka", "BI", "Liiketoiminta-analytiikka", "Tietokanta", "Putkisto", "Metatiedot", "Seuranta", "Tietokeskus"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 200 :
# ['Senior Software Engineer, React' 'SOFTWARE ENGINEER' 'Data Engineer'
#  'Grow as Data Engineer with us - Solita´s personalised onboarding program'
#  'Data Engineer (Azure)' 'Backend engineer (Data science interest)'
#  'DATA ENGINEER' 'Data Engineers' 'Forward-deployed Data Engineer'
#  'Data Engineer (Mid/Senior experience) - Fluent Finnish required'
#  'Sr Data Engineer' 'Data Engineer Helsinkiin' 'Data Integration Engineer'
#  'Consumer Data Specialist' 'Data Engineer - End-user Development'
#  'Data Center Critical facilities Engineer II' 'Desktop Engineer'
#  'Senior Data Engineer, Netvisor' 'Network Engineer'
#  'Software Engineer - Data Platform'
#  'Golang System Software Engineer - Containers / Virtualisation'
#  'Software Engineer - App Stores Backend (Remote)'
#  'Software Engineer - Launchpad' 'Field Applications Engineer'
#  'Senior Software Engineer (PHP) - Connectors Engineering' 'R&D Engineer'
#  'Junior Software Engineer' 'Senior Data Engineer'
#  'Software Engineer (node.js)' 'Remote Senior Software Engineer (Java)'
#  'Lead Data Engineer for K-Group' 'Core Network Engineer'
#  'Software Engineer' 'R&D Support Engineer' 'Lead Data Scientist/Engineer'
#  'Cloud Data Engineer' 'Software Developer' 'Test Engineer'
#  'Data and integration professionals for industrial domain'
#  'Cable Installation Engineer (freelancer)' 'Software Test Engineer'
#  'Data Scientist (Finland Office)' 'MAC Engineer (Freelancer)'
#  'IoT Senior Engineer / Embedded Systems' 'Optical System Engineer'
#  'Senior Computer Vision Engineer (Barcodes) - Remote, Europe'
#  'Sr. System Test Engineer' 'Azure Data Engineer'
#  'L2/L3 Firmware Engineer' 'Quality Technician Intern'
#  'Embedded Software Test Engineer – Finland' 'Machine Learning Engineer'
#  'Software Engineer (experience in computer security) Abu Dhabi'
#  'Radio Access Network Engineer' 'Senior Process Engineer'
#  'Senior Software Engineer, Services Team' 'Research Engineer'
#  'Data Integration Engineer Confluent & Kafka - Tietoevry Transform'
#  'Go Software Engineer, Commercial Systems' 'Full-stack Software Engineer'
#  'Senior Software Engineer (PHP) - DWH Team'
#  'Azure Data Platform Specialist / Azure Data Engineer'
#  'Data Engineer, Tietohallinto, Helsinki'
#  'Senior Embedded Software Engineer - Espoo'
#  '(Senior) Mechanical Design Engineer' 'Senior Test Automation Engineer'
#  'Senior Application Engineer (Platform)' 'Supplier Quality Engineer'
#  'Automotive Embedded Software Engineer'
#  'Senior Software Engineer - Telco' 'MACHINE LEARNING LOVER'
#  'Cloud Platform Engineer' 'Senior Search Engineer (Solr Platform)'
#  'Site Reliability Engineer' 'RAN Engineer'
#  'Senior Software Engineer (PHP) - Google Sheets'
#  'Senior Backend Engineer (Campaign Overview and Reporting)'
#  'Embedded Software Engineer – location free (in Finland)'
#  'Senior Observability Platform Developer - Python/Go'
#  'Senior Backend Engineer (Ad-lib Integrations)'
#  'Software Engineer - Micro/Private/Bare-Metal Cloud'
#  'Applications Engineering Intern' 'Senior Backend Engineer - Python'
#  'Senior Software Engineer (Demand)'
#  'Quantum Hardware Engineer, Munich, Germany'
#  'Metallurgist / Mineral Processing Sales Engineer - Mining flotation plants'
#  'Integration & API Developer - Tietoevry Transform'
#  'Sales Engineer, O&M Services' 'Sales Engineer'
#  'Senior Software Engineer - Internal Integrations' 'Senior iOS Engineer'
#  'Purchasing Engineer' 'Senior MES Engineer - Quality Data Management'
#  'Mechanical Engineer' 'Energy Transition Specialist'
#  'Mine Planning Technician' 'Senior Software Engineer (Feed Management)'
#  'Data Architect' 'Permanent position for Embedded Engineer(C/C++ with...'
#  'Agile Coach / Release Train Engineer' 'Platform Engineer'
#  'RF Engineer/Senior RF Engineer' 'Senior Python Backend Developer'
#  'FAST Rotation Program-Field Applications Engineer Track - FInland'
#  'AI Security Engineer' 'Staff Software Engineer - Search (Java)'
#  'Senior Software Engineer - Digital Workplace'
#  'Lead Data Engineer, Helsinki,Finland' 'Lead Engineer'
#  'Senior Software Developer (m/f/d)' 'Senior Backend Engineer (Go)'
#  'Lead Partner Technology Strategist - Finland'
#  'AI Scientist - Computer Vision' 'Mechanical Engineer, Metso Outotec'
#  'Senior MES Engineer – Quality Data Management, Pulp & Paper'
#  'Senior ML Engineer' 'Senior Azure Data Engineer'
#  'Algorithm Test Engineer'
#  'Development engineer / System Specialist to SSAB European Graduate Program'
#  'Manufacturing Engineer' 'Quality Engineer, Operational Quality'
#  'Logistics Development Engineer' 'Electric Engineer'
#  'IT Systems & Network Administrator'
#  'Mechanical Engineer, full-time, Metso Outotec, Espoo'
#  'RF Field Applications Engineer - Finland'
#  "Azure Data Engineer's & Architect's - Finland"
#  'Cloud Infrastructure Engineer' 'Senior Systems Integration Engineer'
#  'Embedded & Desktop Linux Software Engineer - Optimisation'
#  'Senior DevOps Engineer' 'Senior Machine Learning Engineer'
#  'AVIONICS ENGINEER' 'Reverse Engineer / Linux Security Engineer'
#  'Cloud DevOps Engineer' 'Senior Azure Data Engineer / Architect'
#  'Senior Salesforce Engineer, Commercial Systems'
#  'Linux System Engineer - QA, Tooling, Automation'
#  'Low-level Android Engineer' 'Type Approval Engineer'
#  'Software Service Engineers' 'Project Engineer'
#  'Project Engineer, Smart Ag'
#  'Senior Software Engineer - Embedded & Desktop Linux Optimisation'
#  'Azure Data Engineer (End Customer / Internal Role)'
#  'DevOps Engineer (Site Reliability)'
#  'Senior Data Engineer (Stock Options Included!)'
#  'Embedded Software Test Engineer - Finland'
#  'Senior Developers and Engineers'
#  'Data Engineer / Python, DataBricks and realtime streaming'
#  'Development engineer / System Specialist'
#  'Embedded Software Engineer - Finland'
#  'Software Engineer, Commercial Systems' 'Process Engineer'
#  "Azure Data Engineer's & Azure Data Architect's"
#  'Senior Software Engineer - MAAS' 'Warranty Engineer, ABB Marine & Ports'
#  'Staff Geospatial Software Engineer' 'Staff Software Engineer'
#  'After Sales Engineer' 'Senior Field Application Engineer'
#  'Senior Web Developer - Workplace Engineering' 'Scrum Master'
#  'Process Technology Engineer/Manager' 'Test Automation Specialist'
#  'Embedded Software Engineer (Virtualization)'
#  'Embedded Machine Learning Engineer (C++)'
#  'Full-stack Engineer - Usage Tracking (Python)' 'Lead Piping Engineer'
#  'Embedded Linux Software Engineer'
#  'Automation Engineer / C++ Developer to ABB oy Marine & Ports'
#  'Embedded OS Engineer' 'Senior Staff Real-time Embedded SW Engineer'
#  'APU VPS Engineer' 'Senior High Precision GNSS Software Developer'
#  'Technical Architect BI-Cloud'
#  'Antenna Network Engineer (Satellite Communications Network)'
#  'Senior Security Engineer - SecOps (Threat Hunting, Vuln Mgmt, IAM, Incident)'
#  'Systems Engineer - SASE Specialist'
#  'Senior Full-stack Engineer - Usage Tracking (Rails / Python)'
#  'Lead Quality Software Engineer - Finland'
#  'Principal Ruby on Rails developer'
#  'Embedded SW Engineer (Infotainment Systems)'
#  'Senior Electronics Test Engineer'
#  'Senior Aircraft Structures Engineer - Finland or Spain'
#  'Senior Sales Engineer - Finland'
#  'Postdoc Position for Anyon Particles and Topological Phenomena in Designer Platform'
#  'Physical IC Design Engineer - Oulu' 'Senior Devops Game Engineer'
#  'Senior Remote Sensing Engineer' 'Global Head of Finance Services Sales'
#  'Senior Catastrophe Modeler' 'GSI Partner Sales Director'
#  'OEM Partner Sales Director' 'Cloud / DevOps Engineer' 'Product Designer'
#  'Metallurgist / Mineral Processing Sales Engineer - Mining flotation plants H/F Finlande'
#  'Senior DevOps Engineer (Site Reliability)'
#  'Full-stack Engineer - Usage Tracking (Rails / Python)'
#  'Senior Azure/.NET Developer - Vantaa']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_FI],
        [data_terms_FI]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 46 :
# ['Data Engineer'
#  'Grow as Data Engineer with us - Solita´s personalised onboarding program'
#  'Data Engineer (Azure)' 'Backend engineer (Data science interest)'
#  'DATA ENGINEER' 'Data Engineers' 'Forward-deployed Data Engineer'
#  'Data Engineer (Mid/Senior experience) - Fluent Finnish required'
#  'Sr Data Engineer' 'Data Engineer Helsinkiin' 'Data Integration Engineer'
#  'Consumer Data Specialist' 'Data Engineer - End-user Development'
#  'Data Center Critical facilities Engineer II'
#  'Senior Data Engineer, Netvisor' 'Software Engineer - Data Platform'
#  'Senior Data Engineer' 'Lead Data Engineer for K-Group'
#  'Lead Data Scientist/Engineer' 'Cloud Data Engineer'
#  'Azure Data Engineer'
#  'Software Engineer (experience in computer security) Abu Dhabi'
#  'Data Integration Engineer Confluent & Kafka - Tietoevry Transform'
#  'Azure Data Platform Specialist / Azure Data Engineer'
#  'Data Engineer, Tietohallinto, Helsinki' 'Cloud Platform Engineer'
#  'Site Reliability Engineer'
#  'Senior Observability Platform Developer - Python/Go'
#  'Software Engineer - Micro/Private/Bare-Metal Cloud'
#  'Senior MES Engineer - Quality Data Management' 'Data Architect'
#  'Lead Data Engineer, Helsinki,Finland'
#  'Senior MES Engineer – Quality Data Management, Pulp & Paper'
#  'Senior Azure Data Engineer'
#  "Azure Data Engineer's & Architect's - Finland"
#  'Cloud Infrastructure Engineer' 'Cloud DevOps Engineer'
#  'Senior Azure Data Engineer / Architect'
#  'Azure Data Engineer (End Customer / Internal Role)'
#  'DevOps Engineer (Site Reliability)'
#  'Senior Data Engineer (Stock Options Included!)'
#  'Data Engineer / Python, DataBricks and realtime streaming'
#  "Azure Data Engineer's & Azure Data Architect's"
#  'Technical Architect BI-Cloud' 'Cloud / DevOps Engineer'
#  'Senior DevOps Engineer (Site Reliability)']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.7 France

# %%
selector = 'France'

specializations_CA = ["Enginyer", "Enginyeria", "Consultor", "arquitecte", "ESPECIALISTA", "Gerent", "Desenvolupador", "Arquitectura", "Administrador"]

data_terms_CA = ["Dades", "ETL", "Núvol", "Analític", "Anàlisi de dades", "BI", "Intel·ligència de negocis", "Anàlisi de negocis", "Base de dades", "Pipeline", "Metadades", "Monitorització", "Centre de dades"]

specializations_IT = ["Ingegnere", "Consulente", "architetto", "SPECIALISTA", "Manager", "Sviluppatore", "Architettura", "Amministratore"]

data_terms_IT = ["Dati", "ETL", "Cloud", "Analitico", "Analytics", "BI", "Business Intelligence", "Business Analytics", "Database", "Pipeline", "Metadati", "Monitoraggio", "Centro dati"]

specializations_BASQ = ["Ingeniaria", "Ingeniaritza", "Konsultore", "arkitektoa", "ESPECIALISTA", "Kudeatzailea", "Garatzailea", "Arkitektura", "Administratzailea"]

data_terms_BASQ = ["Datuak", "ETL", "Cloud", "Analitikoa", "Analitika", "BI", "Negozioaren Inteligentzia", "Negozioaren Analitika", "Datubasea", "Pipeline-a", "Metadatuak", "Monitoreo", "Datuen zentroa"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 116 :
# [nan 'CDD - DATA ENGINEER F/H' 'Data Analytics Leader'
#  'Manager QA Testing Automation H/F'
#  'Software engineer fullstack - Lancement nouveau produit H/F'
#  'DATA ENGINEER (H/F)' 'Data Engineer (H/F)' 'Data Engineer H/F'
#  'Cybersecurity Auditor'
#  'International Trainee Program: Process Engineer - Semiconductor Industry'
#  'Application Engineer' 'System Engineer for advanced projects'
#  'Fullstack Java/JS Developer w/m'
#  'Junior Process Engineer in Semiconductor Industry - Grenoble (F) / Dresden (D) / Austin (USA)'
#  'Tech lead | CDI | H/F' 'Ingénieur Support niveau 2' 'Data scientist'
#  'Data engineer - data factory (H/F)'
#  'PROJECT MECHANICAL ENGINEER M/F - INGENIEUR CHEF DE PROJET H/F'
#  'Data Scientist / Data Engineer confirmé - F/H'
#  'Packaging Implementation Project Leader (H/F)'
#  'Développeur Full Stack Senior | CDI | H/F' 'Field Service Engineer H/F'
#  'Cloud Data Engineer (H/F) - POEI'
#  "Project QA/QC Engineer / Ingénieur(e) qualité d'études et travaux"
#  'Chef de projet Digital dans contexte Data & Aerospace F/H'
#  'Product Owner (F/H)' 'Global Software Department Manager- Above RTE'
#  'Data Engineer (F/H)'
#  "Responsable d'Equipe Informatique - Data Factory (H/F)"
#  'Data architect - data factory (H/F)' 'Head of Data Analytics (H/F)'
#  'Senior C++ Software Developer - Network Diagram'
#  'Chef de projet Data - data factory h/f (H/F)'
#  'Lead Data Analyst (H / F)' 'IT ENGINEER SHINE VISION H/F'
#  'CDI - Data Engineer (Média) (F/H)'
#  'CDI - Développeur PYTHON / Data engineer (Media) H/F'
#  'CDI - Cloud Data Engineer (Média) F/H' 'Data engineer - H/F'
#  'Data Engineer - H/F' 'CDI - Data Engineer (Industry) (F/H)'
#  'Machine Learning Engineer - H/F' 'Senior Solution Engineer IoT'
#  'Data Engineer Snowflake F/H' 'DATA ENGINEER (F/H)' 'Data Scientist H/F'
#  'Responsable Data engineer' 'Data Engineer confirmé (H/F)'
#  'Internship- Engineer Account Manager UK (Based in Paris) | DASSAULT SYSTEMS'
#  'Alternant - 1 an - Developer Data Engineer - Sensitivities F/H'
#  'Gestionnaire base de données' 'Data engineer manufacturing (H/F)'
#  'Alternance - 24 mois - Data Engineer F/H - Paris'
#  'DATA ENGINEER JUNIOR (F/H)'
#  'Alternance Software Engineer C/C++ Data structure - Lyon (F/H)'
#  'Chef de Projet Data / Data Steward - Lyon' 'Développeur Big Data (F/H)'
#  'DATA SCIENTIST ML ENGINEER H/F' 'Architecte Google Cloud (F/H)'
#  'Développeur Logiciel Data (H/F)' 'DATA ARCHITECT CLOUD'
#  'Data Engineer H/F (Freelance)' 'Field Scientist F/H'
#  'Software engineer Cybersécurité R&D H/F' 'Stagiaire Data Engineer'
#  'Data engineer python sql'
#  'Contrôleur de gestion Business Analyst - Projets et Systèmes'
#  'DevOps Engineer (H/F)' 'Data Engineer - ALTERNANCE F/H'
#  'Data Engineer (IT) / Freelance'
#  'Data Engineer - Paris - Contrat de 6 mois renouvelable (IT) / Freelance'
#  'Data Engineer / Scientist - Énergies Vertes Télétravail'
#  'Data Engineer - Alternance - Issy Les Moulineaux - H/F'
#  'Responsable business intelligence (domaine SD)'
#  'R&D Test Development Engineer (H/F)'
#  'LEARNING MANAGEMENT SYSTEM ENGINEER' 'Data engineer'
#  'Data Engineer - JAVA/Python (IT) / Freelance' 'Data Engineer F/H'
#  'Junior Data Engineer' 'Data engineer ELK F/H - CDI'
#  'Sr Vice President R&D Food Safety & Quality Control Technology F/H'
#  'data engineer . H/F' 'Data Engineer SPARK / JAVA (F/H)'
#  'Alternance - Data Engineer F/H' 'ASIC Verification Lead Engineer (H/F)'
#  'ALTERNANCE – DATA ENGINEER - (H/F) - Gif-sur-Yvette– Septembre 2023'
#  'ALTERNANCE - Data Engineer/ML Engineer H/F'
#  'RESEARCH ENGINEER IN PHYSICS OF INDUSTRIAL PROCESSES F/M'
#  'Apprenti(e) Data engineer on Helicopter flights (H/F)'
#  'Data Engineer - Banque H/F' 'Data & Software Engineer'
#  'Engineering internship - Data engineer' 'Stage - DATA Scientist H/F'
#  'Stagiaire Consultant(e) Data Engineer - H/F' 'CDI - Data Engineer - F/H'
#  'Assistant Data Engineer h/f - Alternance' 'Data Engineer / SRE - H/F'
#  'Python / AWS Software Engineer (m/f)' 'CLOUD DATA ENGINEER F/H F/H'
#  'Data Engineer Confirmé (H/F)'
#  'Data Engineer (full time, all seniority levels) - QuantumBlack'
#  'Data Engineer - Adot' 'Cloud Data Engineer H/F' 'DATA engineer STAGE'
#  'Data Engineer – Projets Digital Factory H/F'
#  'ALTERNANCE - Data Engineer H/F'
#  'Responsable technique Data Engineer - Issy les Moulineaux - H/F'
#  'STAGE - Assistant(e) Data Engineer– traitement du langage naturel H/F'
#  'Senior Data Engineer'
#  'ALTERNANCE - Data Analyst - Power BI Engineer H/F'
#  'Customer Engineer Apprenticeship, Cloud Sales, September 2023 Start'
#  'Data Engineer - Big Data - Santé Social Emploi - Nantes'
#  'Data Project Manager - CRM & Intelligence Client - H/F'
#  'Ingénieur Deep Learning - H/F']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_FR, specializations_DE, specializations_CA,specializations_IT, specializations_BASQ],
        [data_terms_FR,data_terms_DE, data_terms_CA, data_terms_IT, data_terms_BASQ]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 72 :
# ['CDD - DATA ENGINEER F/H' 'Data Analytics Leader' 'DATA ENGINEER (H/F)'
#  'Data Engineer (H/F)' 'Data Engineer H/F'
#  'Data engineer - data factory (H/F)'
#  'Data Scientist / Data Engineer confirmé - F/H'
#  'Cloud Data Engineer (H/F) - POEI' 'Data Engineer (F/H)'
#  'Data architect - data factory (H/F)' 'Head of Data Analytics (H/F)'
#  'Lead Data Analyst (H / F)' 'CDI - Data Engineer (Média) (F/H)'
#  'CDI - Développeur PYTHON / Data engineer (Media) H/F'
#  'CDI - Cloud Data Engineer (Média) F/H' 'Data engineer - H/F'
#  'Data Engineer - H/F' 'CDI - Data Engineer (Industry) (F/H)'
#  'Data Engineer Snowflake F/H' 'DATA ENGINEER (F/H)'
#  'Responsable Data engineer' 'Data Engineer confirmé (H/F)'
#  'Alternant - 1 an - Developer Data Engineer - Sensitivities F/H'
#  'Data engineer manufacturing (H/F)'
#  'Alternance - 24 mois - Data Engineer F/H - Paris'
#  'DATA ENGINEER JUNIOR (F/H)'
#  'Alternance Software Engineer C/C++ Data structure - Lyon (F/H)'
#  'Développeur Big Data (F/H)' 'DATA SCIENTIST ML ENGINEER H/F'
#  'Architecte Google Cloud (F/H)' 'Développeur Logiciel Data (H/F)'
#  'DATA ARCHITECT CLOUD' 'Data Engineer H/F (Freelance)'
#  'Stagiaire Data Engineer' 'Data engineer python sql'
#  'Data Engineer - ALTERNANCE F/H' 'Data Engineer (IT) / Freelance'
#  'Data Engineer - Paris - Contrat de 6 mois renouvelable (IT) / Freelance'
#  'Data Engineer / Scientist - Énergies Vertes Télétravail'
#  'Data Engineer - Alternance - Issy Les Moulineaux - H/F' 'Data engineer'
#  'Data Engineer - JAVA/Python (IT) / Freelance' 'Data Engineer F/H'
#  'Junior Data Engineer' 'Data engineer ELK F/H - CDI'
#  'data engineer . H/F' 'Data Engineer SPARK / JAVA (F/H)'
#  'Alternance - Data Engineer F/H'
#  'ALTERNANCE – DATA ENGINEER - (H/F) - Gif-sur-Yvette– Septembre 2023'
#  'ALTERNANCE - Data Engineer/ML Engineer H/F'
#  'Apprenti(e) Data engineer on Helicopter flights (H/F)'
#  'Data Engineer - Banque H/F' 'Data & Software Engineer'
#  'Engineering internship - Data engineer'
#  'Stagiaire Consultant(e) Data Engineer - H/F' 'CDI - Data Engineer - F/H'
#  'Assistant Data Engineer h/f - Alternance' 'Data Engineer / SRE - H/F'
#  'CLOUD DATA ENGINEER F/H F/H' 'Data Engineer Confirmé (H/F)'
#  'Data Engineer (full time, all seniority levels) - QuantumBlack'
#  'Data Engineer - Adot' 'Cloud Data Engineer H/F' 'DATA engineer STAGE'
#  'Data Engineer – Projets Digital Factory H/F'
#  'ALTERNANCE - Data Engineer H/F'
#  'Responsable technique Data Engineer - Issy les Moulineaux - H/F'
#  'STAGE - Assistant(e) Data Engineer– traitement du langage naturel H/F'
#  'Senior Data Engineer'
#  'ALTERNANCE - Data Analyst - Power BI Engineer H/F'
#  'Customer Engineer Apprenticeship, Cloud Sales, September 2023 Start'
#  'Data Engineer - Big Data - Santé Social Emploi - Nantes']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.8 Germany

# %%
selector = 'Germany'

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 248 :
# ['Data Engineer (w/m/d)' 'Senior Data Engineer (m/f/d)'
#  'RNA Data Engineer (w/m/d)'
#  'Full Stack Developer .NET Core / Angular (w/m/d)'
#  'Senior Data Analyst (w/m/d) - onsite or remote / home office'
#  'Senior Cloud - Data-Engineer (m/w/d)'
#  'Data Engineer (m/w) in der Schweiz'
#  'Lead Analytics Engineer / BI Engineer (m/f/d)'
#  'Senior DevOps Engineer (m/w/d) für Dortmund, Hannover oder remote'
#  'Site Reliability Engineer (f/m/d)'
#  'IT Data Center Infrastructure Engineer (m/f/d)'
#  'Data Engineer (w/m/d) Automotive Testing Unit'
#  '(Senior) Data Engineer (w/m/d) – Marketing & Communications'
#  'DevOps Engineer (m/w/d)'
#  'Data Warehouse Architekt / Entwickler / Data Engineer (m/w/d)'
#  'Senior Full Stack Developer .NET Core / Angular (w/m/d)'
#  'Technical Data Engineer Material (d/m/w) für Airbus'
#  'Research Software Engineer/Developer (f/m/d) for an HPC Particle in Cell Code'
#  'SENIOR DATA ENGINEER (M/W/D)' 'Senior ML/AI Engineer (m/w/d)'
#  'IT Data Center Support Engineer (m/w/d)'
#  'Avionics System Engineer (f/w/d)'
#  'Data Engineer (m/w/d) Big Data | Python | Azure in Ulm'
#  'DevOps Engineer (f/m/d)' 'Senior Software Engineer (m/w/d)'
#  'Manager Data Engineering'
#  'System Engineer Fahrerassistenzsysteme / Autonomes Fahren (m/w/d)'
#  'Senior Associate Data Engineering'
#  'Data Scientist / Feature Engineer (m/w/d)'
#  '(Senior) Data Engineer (m/f/d) 80% Homeoffice'
#  'Technical Data Engineer (d/m/w) für Airbus'
#  'Software Entwicklerin / Engineering (m/w/d) Python | Big Data in Ulm'
#  'CRM Engineer DevOps (m/w/d), mit Homeoffice-Option'
#  'Software Engineer / Python Software Entwickler (m/w/d)'
#  'Senior IoT Solution Engineer' 'Systems Engineer IT B2B (all genders)'
#  'Senior DevOps Engineer für BwXDev - Innovation (m/w/d)'
#  'Solution Architect Marketing (m/w/d)' 'Data Warehouse Engineer (m/w/d)'
#  'BI Engineer Cloud (m/w/d)'
#  'Engineer Data und Analytics Ticketautomaten (w/m/d)'
#  'DevOps Engineer / Site Reliability Engineer (m/w/d)'
#  'Senior Data Engineer:in (w/m/d)' 'Data Engineer (m/w/d)'
#  'Software Engineer (m/w/d) Systementwicklung'
#  'DevOps Architekt für BwXDev - Innovation (m/w/d)'
#  'Software Engineer (d/f/m)'
#  'System Engineer for Low Earth Orbit Data Management / Software & Avionics (d/f/m)'
#  'SAP ABAP Developer CO/PS (m/w/d) in Teilzeit/ Vollzeit'
#  'Cloud Data Engineer (w/m/d) – Eschborn'
#  'Cloud Engineer / Cloud Solution Architect (w/m/d)'
#  'Data Engineer:in Analyse Betrieb Fernverkehr (w/m/d)'
#  'Senior Cloud Engineer for Remote Application Streaming (m/w/d)'
#  'Data Engineer:in' 'Network Engineer Data Center / WAN (m/w/d)'
#  'Senior Big Data Engineer (w/m/d)' 'Software Ingenieur'
#  'IT System Engineer (m/w/d)' 'Data Engineer (m/w/d) B2B-Versandhandel'
#  'Software Engineer mobile app development (m/w/d)'
#  'Fullstack Software Engineer (all genders)' 'DevOps Cloud Engineer'
#  'Cloud Data Engineer (AWS) (m/w/d)'
#  'DevOps / Cloud Engineer Platform (m/w/d)' 'Cloud Data Engineer:in'
#  'IT System Engineer - Network Services (m/w/d) in Voll-/Teilzeit'
#  'Senior Backend / Full-Stack Software Engineer (m/f)'
#  'Senior DevOps Engineer (m/w/d)'
#  'Senior Software Engineer - Dispatching (m/f/d)'
#  'BI Data Engineer (m/w/d)' 'Data Analyst:in'
#  'Data Analyst / Analytics Engineer (m/w/x)'
#  'Senior DevOps/Data Engineer:in' 'Data Engineer'
#  'Public Cloud Engineer - Agile Methoden / ITIL / Azure / GitOps (m/w/d)'
#  'Data Engineer / Data Analyst (w/m/d)' '(Senior) Data Scientist (m/f/d)'
#  'IT Test Analyst Schwerpunkt Testautomatisierung im Backend-Bereich (m/w/d)'
#  '(Junior) System Engineer (w/m/d) Private & Hybrid Cloud'
#  'Senior Data Engineer (w/m/d)'
#  'IT System Engineer / Data Scientist (m/f/d) Java EE'
#  '(Senior) System Engineer (m/f/d) - Asset & Config. Mgt.'
#  'Backend Software Engineer (all genders)'
#  'Engineering Lead Analytics Platform (m/f/d)'
#  'Web Application Software Engineer (all genders)'
#  'IT-Consultant (m/w/d) Data Engineer'
#  'Senior Solution Engineer Cloud Data (m/w/d)'
#  '(Senior) Cloud Engineer (m/f/d) Security'
#  'Senior Cloud and Data Engineer (all genders)'
#  'Edge (Cloud) Computing Engineer:in'
#  'Systems Engineer Verfahrenstechnik - Elektronik / Prozessoptimierung (m/w/d)'
#  '(Junior) Data Engineer m/f/t'
#  'Master Data Engineer - 3D-CAD / SAP / Technische Redaktion (m/w/d)'
#  'Big Data Engineer - Data Warehouse / E-Commerce / Big Data Architektur (m/w/d)'
#  'Data Architect/Engineer (m/w/d) - Machine Learning and AI | Executive Search | Mercedes-Benz'
#  'Junior Data Engineer / Consultant (100%)'
#  'Data Engineer Produktion (m/w/d)' '(Senior-) Platform Engineer (w/m/d)'
#  'Consultant Data Engineer (m/w/d)'
#  'Cloud Architect im Big Data Umfeld (m/w/d) / Azure / Java Remote/Ulm'
#  'Senior QA Automation Software Engineer (m/f/d)'
#  'DevOps Engineer:in / Entwickler:in'
#  '(Senior) Consultant in Advanced Analytics & Artificial Intelligence (f/m/d), Munich/hybrid'
#  'Junior DevOps Engineer (m/w/d)'
#  'Solution Architect Successfactors & HR Systems (m/f/d)'
#  'Senior Cloud Engineer - Remote möglich (m/w/d)'
#  '(Senior) Solution Engineer (m/w/d) SAP Data Migration - Technology Center'
#  'Senior IT Projektleiter:in Data Engineering'
#  'Linux Softwareentwickler (m/w/d) Software Developer / Software Engineer'
#  'Anti-Abuse Software Engineer (m/f/d)'
#  'Senior Software Cloud Architect (f/m/d)'
#  'Data Engineer Marketing Intelligence (m/w/d)'
#  'Data Engineer – Machine Learning Schwerpunkt Biometrie (w/m/d)'
#  'Data Architect/Engineer (m/w/d)'
#  'Biologist, Computer Scientist - Analytic Device Integration (m/f/d)'
#  'Cloud Engineer - Datenmanagement / Business Intelligence / AWS / SQL (m/w/d)'
#  'SAP S/4 Hana Solution Architect (m/f/d)' 'Mircosoft BI Engineer (m/w/d)'
#  'Informatiker - Data Engineering, Business Intelligence (m/w/d)'
#  'Microscopy Software Engineer' 'Software Engineer (m/f/d) Aviation'
#  'Projekt DevOps Engineer (m/w/d) ab 120.000€ p.a.'
#  'Senior Software Engineer Medical Devices (m/f/x)'
#  'Software Development Engineer II - C++ (m/f/d) for 3D/Computer Vision'
#  'Wirtschaftsinformatiker - Data Engineering, Big Data (m/w/d)'
#  'Cloud Engineer (m/w/d)' 'Senior Data Engineer:in'
#  'Azure Cloud Engineer (m/w/d)' 'Cloud Data Engineer (w/m/d)- Paderborn'
#  nan 'Full Stack Developer Cloud (m/w/d) Remote/Ulm/Stuttgart'
#  'Firmware Embedded Engineer/Ingenieur (m/w/d)'
#  'Software Engineer- Embedded Systems (f/m/d)'
#  'Python - Data Engineer (m/w/d)'
#  'IT System Engineer Remote Operations & Support (w/m/d)'
#  'Computer Scientist - Frontend, Angular, UI, UX (m/f/d)'
#  'Java Backend Engineer (m/f/d)' 'Data Engineer (m/f/d)'
#  'Software Engineer m/w/d' 'Software Engineering Lead - Data (m/w/d)'
#  'Cloud System Engineer - Containerisierung / DevOps / Kubernetes / Ubuntu (m/w/d)'
#  'Software Engineer Python / C++ (w/m/d)'
#  'Artificial Intelligence Firmware Engineer (m/f/d) for AIRBUS'
#  'Azure Cloud Engineer (m/f/d)' 'System Engineer (m/w/d)'
#  'Automotive Software Architects & Engineers (m/f/d) - Different Direct Placements at Mercedes-Benz'
#  'Lead Mechanical Engineer - Data Center'
#  'Business Analyst Business Intelligence & Analytics (m/w/d)'
#  'MICROSOFT BI ENGINEER (m/w/d)' 'Senior Software Engineer-Kotlin (m/f/d)'
#  'DevOps Engineer (m/w/d) 100% Remote'
#  'Junior Java IT Engineer (m/w/d) – Köln'
#  'Software System Engineer (m/f/d) Aerospace'
#  'Software Engineer (m/f/d) AUTOSAR ADAS Platform at Mercedes-Benz - Exclusive Direct Placement'
#  'Data Engineer Druckmaschinen (m/w/d)'
#  'Solution Engineer Data Center Technologies (m/w/d) für AIRBUS'
#  'Cloud Software Engineer / Backend Engineer (m/f/d) // Remote'
#  'Developer- and Validation Engineer (m/f/d) Aeroacoustics'
#  'Cloud Engineer (gn)'
#  '(Senior) DevOps Engineer (m/f/t) - Cloud Security Operations'
#  'Computer Scientist - DevOps Engineering, Elastic Stack (m/f/d)'
#  'Systemtest Engineer Flight Test (m/f/d) for AIRBUS'
#  'System Engineer (m/f/d) Flight Test' 'Data Scientist/Engineer'
#  'Software Engineer Integration (m/f/d) at Mercedes-Benz - Exclusive Direct Placement'
#  'DevOps Engineer | Data Platform (f/m/d) - GER, UK, NL, PL or Remote'
#  'IT Infrastructure System Engineer (m/w/d)'
#  '(Senior) Software Engineer/Data Science (m/f/d) DSL'
#  'Senior Python Backend Engineer (w/m/d)'
#  '(Junior) Data Analyst - Campaigning (w/m/d)'
#  '(Senior) Data Scientist / Data Engineer (m/w/d)'
#  'Lead Electrical Engineer - Data Center'
#  'Lead Software Engineer / Architect Cloud / Data / DevOps (w/m/d)'
#  'IT Automation Engineer (m/w/d)'
#  'DevOps Engineer (m/f/d) - at Mercedes-Benz - Exclusive Direct Placement'
#  'Embedded Linux Software Engineer / Developer (m/f/d)'
#  'Frontend Engineer (m/f/d) // Remote'
#  '(Fach-) Informatiker - Systemingenieur, Cloud Storage (m/w/d)'
#  'Software Quality Assurance Engineer (m/f/d)'
#  'Senior Software Engineer (f/m/d) Event Stream Processing - Batteries'
#  'Sales Engineer - Customer Advocacy / SAAS / DevOps / Cloud / Remote (m/f/d)'
#  'Data Engineer Versicherungsumfeld (m/w/d)'
#  'Data Engineer (f/m/d) Language Data'
#  'Platform Services Engineer (m/f/d)'
#  'Software Engineer Advanced Process Control (m/w/d)'
#  'Senior Site Systems Engineer (m/w/d) Remote'
#  'Für Freelancer: Cloud Data Engineer (m/w/d) ? 100% remote'
#  'Junior Consultant SAP ERP / SAP S4HANA (m/w/d)'
#  'Lead SAP Service Manager (m/f/d)'
#  'Full-Stack Software Engineer (m/f/d) // Remote'
#  'Software Engineer in Test - Backend (m/f/d)'
#  'Senior Cloud Software Architect (m/f/d) // Remote'
#  'Data Scientist (f/m/x)' 'Data Engineer (m/w/d) 100 % Remote'
#  'Cloud Architect / Cloud Data Engineer / DevOps Engineer / Data Scientist (m/w/d)'
#  'Data Engineer (m/f/d) – Data & Analytics Platform'
#  'Data Architect/ Data Engineer (m/w/d)'
#  'Senior Android Engineer (Kotlin) (m/f/d)' 'Data Engineer (f/m/d)'
#  'Softwareentwickler - Identity Management, Access Management (m/w/d)'
#  'Data Engineer / Frontend Developer Tracking'
#  'Senior Test Engineer (m/w/d) Data Analytics Platform'
#  'Data Engineer (m/w/d) Business Intelligence'
#  'DevOps Engineer Cloud - Linux / Scrum / SQL / Container Architektur (m/w/d)'
#  'DevOps Engineer - Software Development / Git / Kubernetes / Home Office (m/f/d)'
#  'Avionic Equipment System-Engineer (m/f/d)'
#  'Flight Control System Engineer (m/w/d)' 'Software Engineer, Data'
#  'Machine Learning ENGINEER / Data SCIENTIST'
#  'Site Engineer Data Center Europe'
#  '2023 Software Development Engineer Internship'
#  '(Senior) DevOps Engineer (m/w/d) - Data Analytics Platform'
#  'Verification Automation Engineer (m/f/d)'
#  'Software Engineer - Data & Machine Learning (f/x/m)'
#  'Lead Software Development Engineer (f/m/d)'
#  'Artificial Intelligence Engineer /Data Scientist (m/w/d)'
#  'PagoNxt: Data Center Infrastructure Engineer'
#  'Data Engineer (Re-advertisement).'
#  'Data Scientist | Insights (f/m/d) - GER, UK, NL, PL'
#  'System Engineer / Linux (m/w/d)'
#  'Senior Software Engineer [Java/ Kotlin] - Article Master Data (all genders)'
#  'Junior Software Engineer in an AI-Startup (partially remote)'
#  'Solution Delivery Data Engineer - Social, Healthcare & Public Entities (SHaPE)'
#  'Junior Controller Business Intelligence Engineer - Controlling / Qualitätsmanagement / SQL (m/w/d)'
#  'IT System Engineer (m/f/d)' 'Senior Data Engineer (f/m/x)'
#  'Backend Data Engineer - Remote (f/m/d)' 'Data Engineer DWH / BI (m/f/d)'
#  'Data Engineer (m/f/x)'
#  'Regional Safety Engineer, Data Centre Health and Safety'
#  'Data Platform Engineer (m|f|x)'
#  'DATA PLATFORM ENGINEER:IN (W/D/M) - 100% REMOTE'
#  'Senior Software Engineer for ultrasound data processing (m/f/diverse)'
#  'Data Engineer, Business Intelligence' 'Software Engineer, Data Platform'
#  'Data Engineer Advanced Analytics (m/f/d) - relocation'
#  'Data Engineer - Data Products (f/m/x)'
#  'System Engineer or Consultant for the Data Center Team (w/m/d)'
#  'Praktikant / Werkstudent Data Engineer / Data Scientist (m/w/d)'
#  'Data Platform Engineer / Data Engineer (m/f/d)'
#  'Werkstudent:in Data Engineering (all genders)'
#  'Build Data Preparation System Engineer (m/f/d)' 'Data Platform Engineer'
#  'Data Engineer (*)' 'Reliability Engineer Data & Analytics (w/m/x)'
#  'Machine Learning Engineer / Data Scientist (gn)- 100% Remote'
#  'Azure Data Platform Engineer - Energy Markets (d/f/m)'
#  'Data/DevOps Engineer:in']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_DE, specializations_DK,specializations_NL],
        [data_terms_DE, data_terms_DK,data_terms_NL]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 146 :
# ['Data Engineer (w/m/d)' 'Senior Data Engineer (m/f/d)'
#  'RNA Data Engineer (w/m/d)' 'Senior Cloud - Data-Engineer (m/w/d)'
#  'Data Engineer (m/w) in der Schweiz'
#  'Lead Analytics Engineer / BI Engineer (m/f/d)'
#  'Site Reliability Engineer (f/m/d)'
#  'IT Data Center Infrastructure Engineer (m/f/d)'
#  'Data Engineer (w/m/d) Automotive Testing Unit'
#  '(Senior) Data Engineer (w/m/d) – Marketing & Communications'
#  'Data Warehouse Architekt / Entwickler / Data Engineer (m/w/d)'
#  'Technical Data Engineer Material (d/m/w) für Airbus'
#  'SENIOR DATA ENGINEER (M/W/D)' 'IT Data Center Support Engineer (m/w/d)'
#  'Data Engineer (m/w/d) Big Data | Python | Azure in Ulm'
#  'Manager Data Engineering' 'Senior Associate Data Engineering'
#  'Data Scientist / Feature Engineer (m/w/d)'
#  '(Senior) Data Engineer (m/f/d) 80% Homeoffice'
#  'Technical Data Engineer (d/m/w) für Airbus'
#  'Software Entwicklerin / Engineering (m/w/d) Python | Big Data in Ulm'
#  'Data Warehouse Engineer (m/w/d)' 'BI Engineer Cloud (m/w/d)'
#  'Engineer Data und Analytics Ticketautomaten (w/m/d)'
#  'DevOps Engineer / Site Reliability Engineer (m/w/d)'
#  'Senior Data Engineer:in (w/m/d)' 'Data Engineer (m/w/d)'
#  'System Engineer for Low Earth Orbit Data Management / Software & Avionics (d/f/m)'
#  'Cloud Data Engineer (w/m/d) – Eschborn'
#  'Cloud Engineer / Cloud Solution Architect (w/m/d)'
#  'Data Engineer:in Analyse Betrieb Fernverkehr (w/m/d)'
#  'Senior Cloud Engineer for Remote Application Streaming (m/w/d)'
#  'Data Engineer:in' 'Network Engineer Data Center / WAN (m/w/d)'
#  'Senior Big Data Engineer (w/m/d)'
#  'Data Engineer (m/w/d) B2B-Versandhandel'
#  'Software Engineer mobile app development (m/w/d)'
#  'DevOps Cloud Engineer' 'Cloud Data Engineer (AWS) (m/w/d)'
#  'DevOps / Cloud Engineer Platform (m/w/d)' 'Cloud Data Engineer:in'
#  'BI Data Engineer (m/w/d)' 'Data Analyst / Analytics Engineer (m/w/x)'
#  'Senior DevOps/Data Engineer:in' 'Data Engineer'
#  'Public Cloud Engineer - Agile Methoden / ITIL / Azure / GitOps (m/w/d)'
#  'Data Engineer / Data Analyst (w/m/d)'
#  '(Junior) System Engineer (w/m/d) Private & Hybrid Cloud'
#  'Senior Data Engineer (w/m/d)'
#  'IT System Engineer / Data Scientist (m/f/d) Java EE'
#  'Engineering Lead Analytics Platform (m/f/d)'
#  'IT-Consultant (m/w/d) Data Engineer'
#  'Senior Solution Engineer Cloud Data (m/w/d)'
#  '(Senior) Cloud Engineer (m/f/d) Security'
#  'Senior Cloud and Data Engineer (all genders)'
#  'Edge (Cloud) Computing Engineer:in' '(Junior) Data Engineer m/f/t'
#  'Master Data Engineer - 3D-CAD / SAP / Technische Redaktion (m/w/d)'
#  'Big Data Engineer - Data Warehouse / E-Commerce / Big Data Architektur (m/w/d)'
#  'Data Architect/Engineer (m/w/d) - Machine Learning and AI | Executive Search | Mercedes-Benz'
#  'Junior Data Engineer / Consultant (100%)'
#  'Data Engineer Produktion (m/w/d)' 'Consultant Data Engineer (m/w/d)'
#  'Cloud Architect im Big Data Umfeld (m/w/d) / Azure / Java Remote/Ulm'
#  '(Senior) Consultant in Advanced Analytics & Artificial Intelligence (f/m/d), Munich/hybrid'
#  'Senior Cloud Engineer - Remote möglich (m/w/d)'
#  '(Senior) Solution Engineer (m/w/d) SAP Data Migration - Technology Center'
#  'Senior IT Projektleiter:in Data Engineering'
#  'Senior Software Cloud Architect (f/m/d)'
#  'Data Engineer Marketing Intelligence (m/w/d)'
#  'Data Engineer – Machine Learning Schwerpunkt Biometrie (w/m/d)'
#  'Data Architect/Engineer (m/w/d)'
#  'Cloud Engineer - Datenmanagement / Business Intelligence / AWS / SQL (m/w/d)'
#  'Mircosoft BI Engineer (m/w/d)'
#  'Informatiker - Data Engineering, Business Intelligence (m/w/d)'
#  'Wirtschaftsinformatiker - Data Engineering, Big Data (m/w/d)'
#  'Cloud Engineer (m/w/d)' 'Senior Data Engineer:in'
#  'Azure Cloud Engineer (m/w/d)' 'Cloud Data Engineer (w/m/d)- Paderborn'
#  'Full Stack Developer Cloud (m/w/d) Remote/Ulm/Stuttgart'
#  'Python - Data Engineer (m/w/d)' 'Data Engineer (m/f/d)'
#  'Software Engineering Lead - Data (m/w/d)'
#  'Cloud System Engineer - Containerisierung / DevOps / Kubernetes / Ubuntu (m/w/d)'
#  'Azure Cloud Engineer (m/f/d)' 'MICROSOFT BI ENGINEER (m/w/d)'
#  'Data Engineer Druckmaschinen (m/w/d)'
#  'Solution Engineer Data Center Technologies (m/w/d) für AIRBUS'
#  'Cloud Software Engineer / Backend Engineer (m/f/d) // Remote'
#  'Cloud Engineer (gn)'
#  '(Senior) DevOps Engineer (m/f/t) - Cloud Security Operations'
#  'Data Scientist/Engineer'
#  'DevOps Engineer | Data Platform (f/m/d) - GER, UK, NL, PL or Remote'
#  '(Senior) Software Engineer/Data Science (m/f/d) DSL'
#  '(Senior) Data Scientist / Data Engineer (m/w/d)'
#  'Lead Software Engineer / Architect Cloud / Data / DevOps (w/m/d)'
#  '(Fach-) Informatiker - Systemingenieur, Cloud Storage (m/w/d)'
#  'Sales Engineer - Customer Advocacy / SAAS / DevOps / Cloud / Remote (m/f/d)'
#  'Data Engineer Versicherungsumfeld (m/w/d)'
#  'Data Engineer (f/m/d) Language Data'
#  'Für Freelancer: Cloud Data Engineer (m/w/d) ? 100% remote'
#  'Senior Cloud Software Architect (m/f/d) // Remote'
#  'Data Engineer (m/w/d) 100 % Remote'
#  'Cloud Architect / Cloud Data Engineer / DevOps Engineer / Data Scientist (m/w/d)'
#  'Data Engineer (m/f/d) – Data & Analytics Platform'
#  'Data Architect/ Data Engineer (m/w/d)' 'Data Engineer (f/m/d)'
#  'Data Engineer / Frontend Developer Tracking'
#  'Senior Test Engineer (m/w/d) Data Analytics Platform'
#  'Data Engineer (m/w/d) Business Intelligence'
#  'DevOps Engineer Cloud - Linux / Scrum / SQL / Container Architektur (m/w/d)'
#  'Software Engineer, Data' 'Machine Learning ENGINEER / Data SCIENTIST'
#  'Site Engineer Data Center Europe'
#  '(Senior) DevOps Engineer (m/w/d) - Data Analytics Platform'
#  'Software Engineer - Data & Machine Learning (f/x/m)'
#  'Artificial Intelligence Engineer /Data Scientist (m/w/d)'
#  'PagoNxt: Data Center Infrastructure Engineer'
#  'Data Engineer (Re-advertisement).'
#  'Senior Software Engineer [Java/ Kotlin] - Article Master Data (all genders)'
#  'Solution Delivery Data Engineer - Social, Healthcare & Public Entities (SHaPE)'
#  'Junior Controller Business Intelligence Engineer - Controlling / Qualitätsmanagement / SQL (m/w/d)'
#  'Senior Data Engineer (f/m/x)' 'Backend Data Engineer - Remote (f/m/d)'
#  'Data Engineer DWH / BI (m/f/d)' 'Data Engineer (m/f/x)'
#  'Regional Safety Engineer, Data Centre Health and Safety'
#  'Data Platform Engineer (m|f|x)'
#  'DATA PLATFORM ENGINEER:IN (W/D/M) - 100% REMOTE'
#  'Senior Software Engineer for ultrasound data processing (m/f/diverse)'
#  'Data Engineer, Business Intelligence' 'Software Engineer, Data Platform'
#  'Data Engineer Advanced Analytics (m/f/d) - relocation'
#  'Data Engineer - Data Products (f/m/x)'
#  'System Engineer or Consultant for the Data Center Team (w/m/d)'
#  'Praktikant / Werkstudent Data Engineer / Data Scientist (m/w/d)'
#  'Data Platform Engineer / Data Engineer (m/f/d)'
#  'Werkstudent:in Data Engineering (all genders)'
#  'Build Data Preparation System Engineer (m/f/d)' 'Data Platform Engineer'
#  'Data Engineer (*)' 'Reliability Engineer Data & Analytics (w/m/x)'
#  'Machine Learning Engineer / Data Scientist (gn)- 100% Remote'
#  'Azure Data Platform Engineer - Energy Markets (d/f/m)'
#  'Data/DevOps Engineer:in']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.9 Greece

# %%
selector = 'Greece'

specializations_GR = ["Μηχανικός", "Σύμβουλος", "Αρχιτέκτονας", "ΕΙΔΙΚΟΣ", "Διευθυντής", "Προγραμματιστής", "Αρχιτεκτονική", "Διαχειριστής"]

data_terms_GR = ["Δεδομένα", "ETL", "Νέφος", "Αναλυτική", "Ανάλυση", "BI", "Επιχειρηματική Νοημοσύνη", "Επιχειρηματική Αναλυτική", "Βάση δεδομένων", "Αγωγός", "Μεταδεδομένα", "Παρακολούθηση", "Κέντρο δεδομένων"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 98 :
# ['Data Engineer' 'Jr Data Engineer' 'Data Engineer - Cyprus based'
#  'Junior Telecom Data Analysis Engineer' 'Junior Network Engineer'
#  'Associate Data Engineer' 'Junior Analytics Software Engineer (remote)'
#  'Data Engineer Greece' 'Data Engineer / BI Engineer @Thessaloniki'
#  'Senior Data Engineer' 'Data Platform Engineer DWH'
#  'Data Engineer / BI Consultant in Thessaloniki'
#  'Technology Consulting - Big Data Engineer' 'Senior Data Engineer, Java'
#  'Data Engineer / BI Consultant in Athens' 'ML Ops and Data Engineer'
#  'Technical Data Engineer (Customer Excellence)' 'Big Data Engineer'
#  'Junior Data Engineer / Reporting Specialist' 'Senior Big Data Engineer'
#  'Senior Backend Engineer - Go'
#  'Lead Machine Learning Engineer (Remote Option)' 'NOC Engineer'
#  'Working Student/SW Engineer' 'Software Engineer - Data Platform'
#  'Data Analyst' 'Data Software Engineer' 'Sr. Big Data Engineer'
#  'AWS Cloud Data Engineer' 'Reporting Engineer Team Lead (Big Data)'
#  'Software Engineer - Data (Athens Office or Remote in Greece)'
#  'Senior Application Security Engineer - Cyprus based' 'Software Engineer'
#  'QA Engineer' 'Network Engineer' 'Data Engineer (Hybrid Workplace)'
#  'Software Engineer - Data Services'
#  'Data Engineer (Junior/Mid-level) – Athens' 'AWS Data Engineer'
#  'Azure Data Engineer' 'Technical Support Engineer (IT Helpdesk)'
#  'Technical Support Engineer' 'Azure Data Engineer in Thessaloniki'
#  'Data Warehouse Manager / Engineer' 'Full Stack Software Engineer'
#  'Oracle Data Warehouse Engineer' 'Lead Data Engineer'
#  'Head of Technical Support' 'Senior BI & Data Engineer'
#  'Trading Platform Support Engineer' 'Senior Data Analytics Engineer'
#  'BI & Data Engineer (Senior, Energy Sector)'
#  '(Mid/ Senior) Data Engineer' 'Senior Blockchain Software Engineer'
#  'Data Engineer on Azure' 'Azure Data Engineer in Athens'
#  'Data Integration Engineer' 'Senior Backend Software Engineer'
#  'Team Lead Frontend Engineer'
#  'Senior Machine Learning Engineer - Team Lead'
#  'SWE DATA / Robotics & AI: Senior MLOps Engineer'
#  'Azure Cloud Data Engineer' 'Senior Backend Engineer - Αθήνα'
#  'Senior Data Integration Engineer' 'Lead Frontend Engineer'
#  'Senior Data-Backend Engineer (Greece)'
#  'Senior Data Scientist - NLP Engineer' 'Test Analyst'
#  'Senior Data Warehouse Engineer (Hybrid)' 'Backend Software Engineer'
#  'Product Manager (Connections Community)'
#  'Application Support Engineer / Operations Engineer'
#  'Senior Frontend Software Engineer' 'SOFTWARE ENGINEERS'
#  'Python Software Engineer'
#  'Technical PreSales Engineer (m/f/d) - IT Infrastructure'
#  'Senior Software Engineer (Python)' 'Senior Software Engineer'
#  'Senior .NET Software Engineer' 'Remote Senior Software Engineer (Java)'
#  'Senior Software Engineer, Vessel Optimisation'
#  'Technical Manager, Scada (Remote or Hybrid in Greece)'
#  'Software Engineer (Python) – Data Scientist' 'IT Support Engineer'
#  'Frontend Software Engineer' 'Software Engineer - Launchpad'
#  'Mid - Senior Software Engineer (Remote Option)' 'ERP Software Engineer'
#  'Senior Software Engineer - Telco'
#  'Technical PreSales Engineer (m/f/d) – IT Infrastructure'
#  'Senior R&D Software Engineer' 'Software Engineer - MAAS'
#  'Front-end Software Engineer' 'Principal Frontend Engineer'
#  'Golang System Software Engineer - Containers / Virtualisation'
#  'C++ Software Engineer - Financial Technology Solutions & Payments'
#  'Senior Data Engineer (Machine Learning)'
#  'Senior Informatica Data Quality Engineer']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_DE, specializations_DK,specializations_NL],
        [data_terms_DE, data_terms_DK, data_terms_NL]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 49 :
# ['Data Engineer' 'Jr Data Engineer' 'Data Engineer - Cyprus based'
#  'Junior Telecom Data Analysis Engineer' 'Associate Data Engineer'
#  'Junior Analytics Software Engineer (remote)' 'Data Engineer Greece'
#  'Data Engineer / BI Engineer @Thessaloniki' 'Senior Data Engineer'
#  'Data Platform Engineer DWH'
#  'Data Engineer / BI Consultant in Thessaloniki'
#  'Technology Consulting - Big Data Engineer' 'Senior Data Engineer, Java'
#  'Data Engineer / BI Consultant in Athens' 'ML Ops and Data Engineer'
#  'Technical Data Engineer (Customer Excellence)' 'Big Data Engineer'
#  'Junior Data Engineer / Reporting Specialist' 'Senior Big Data Engineer'
#  'Software Engineer - Data Platform' 'Data Software Engineer'
#  'Sr. Big Data Engineer' 'AWS Cloud Data Engineer'
#  'Reporting Engineer Team Lead (Big Data)'
#  'Software Engineer - Data (Athens Office or Remote in Greece)'
#  'Data Engineer (Hybrid Workplace)' 'Software Engineer - Data Services'
#  'Data Engineer (Junior/Mid-level) – Athens' 'AWS Data Engineer'
#  'Azure Data Engineer' 'Azure Data Engineer in Thessaloniki'
#  'Data Warehouse Manager / Engineer' 'Oracle Data Warehouse Engineer'
#  'Lead Data Engineer' 'Senior BI & Data Engineer'
#  'Senior Data Analytics Engineer'
#  'BI & Data Engineer (Senior, Energy Sector)'
#  '(Mid/ Senior) Data Engineer' 'Data Engineer on Azure'
#  'Azure Data Engineer in Athens' 'Data Integration Engineer'
#  'SWE DATA / Robotics & AI: Senior MLOps Engineer'
#  'Azure Cloud Data Engineer' 'Senior Data Integration Engineer'
#  'Senior Data-Backend Engineer (Greece)'
#  'Senior Data Scientist - NLP Engineer'
#  'Senior Data Warehouse Engineer (Hybrid)'
#  'Software Engineer (Python) – Data Scientist'
#  'Senior Data Engineer (Machine Learning)']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.10 Hungary

# %%
selector = "Hungary"

specializations_ROM = ["Inginer", "Consultant", "Arhitect", "Specialist", "Manager", "Dezvoltator", "Arhitectura", "Administrator"]

data_terms_ROM = ["Date", "ETL", "Noroi", "Analitic", "Analize", "BI", "Business Intelligence", "Analiză de afaceri", "Bază de date", "Conductă", "Metadate", "Monitorizare", "Centru de date"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 109 :
# ['Soldering Technology (f/m/div)*'
#  'Factory Integration Engineer - Equipment Automation (f/m/div)*'
#  'Electrical Engineer / Physicist Electrical Development Power Semiconductors (f/m/div)'
#  'Electric Development Engineer (L&M ED) (f/m/div)*' 'Engineer'
#  'Site Reliability Engineer' 'Data Engineer' 'Data Analytics Engineer'
#  'AI Data Engineer Intern'
#  'SAP BW Engineer(s) with data engineering flair'
#  'Data Engineer (software/application)'
#  'Software Engineer (Backend) - Credit' 'Data DevOps Engineer'
#  'Cloud Data Engineer' 'Senior FrontEnd Engineer'
#  'Junior Data Engineer (REF1600P)' 'Data Engineer - OPJ állás Budapest'
#  'Machine Learning Engineer' 'Staff Data Engineer'
#  'BETSSON ACADEMY - FRONTEND ENGINEER (SPORTSBOOK)'
#  'Data Engineer for IoT (REF1449L)' 'Spark Data Engineer'
#  'Software engineer' 'Business Automation - Technology Engineer'
#  'Trainee Electrical Development Engineer Power Semiconductor Modules - International Graduate Program (f/m/div)*'
#  'Senior Engineer (Manufacturing Technology)'
#  'Resident Manufacturing Engineer - Mechanical/Electrical'
#  'Junior Workplace IT Engineer' 'Data Analyst' 'Big Data Engineer'
#  'Full-stack Engineer (m/f/x)' 'Intern Electrical Engineer'
#  'Quality Assurance Engineer' 'Data Scientist Intern - EEA'
#  'Junior Software Engineer'
#  'Field Service Engineer Apprentice Diagnostic Imaging'
#  'Mechanical Engineer Structural Analysis' 'Financial Engineer'
#  'IBM Kubenetes Services Engineer - IBM Budapest Lab'
#  'Recording Analysis Engineer'
#  'Software Engineer – „IDAM-EHL-SE” állás Budapest'
#  'Project Engineer (MES&PLC)' 'Junior Quality Engineer'
#  'Intern - Software Engineer' 'MLOps Engineer (m/f/x)'
#  'Linux Engineer III' 'Design Engineer' 'SMART Factory engineer'
#  'Software Engineer Intern - 8 months (Budapest, Hungary) - ET&I'
#  'Sustainability Quality Management System engineer'
#  'Data Platform Engineer'
#  'FEM Simulation Engineer (thermal) - SiC Semiconductor Modules'
#  'Business Automation - Technology Engineer for Client Engineering'
#  'Cisco Data 2nd line engineer'
#  'Software Engineer (mid or senior level) for Data Platform'
#  'Sr Data Engineer' 'Senior Data Engineer' 'Specialist design engineer'
#  'Power BI Platform Engineer'
#  'Software Development Engineer (Machine Learning)'
#  'Maintenance Project Engineer' 'SAN Storage Migration Engineer'
#  'Development Engineer Optics' 'Data Security Engineer'
#  'Software Engineer - "EHL-AW" állás Budapest'
#  'data scientist & ai engineer' 'Technical Support Engineer'
#  'Golang System Software Engineer - Containers / Virtualisation'
#  '(Remote, Hungary) Senior FullStack Engineer' 'Senior Software Engineer'
#  'Sales Application Engineer (Energy Efficiency & Sustainability)'
#  'System Engineer' 'Software Development Engineer' 'Junior IT Engineer'
#  'Infrastructure Engineer- IBM Budapest Lab' 'Data Integration Engineer'
#  'Senior Engineer' 'Front End Engineer - HU'
#  'Cloud Devops Engineer (m/f/x)' 'Backend Engineer (Platform)'
#  'Infrastructure Specialist Engineer'
#  'Senior Data Pipeline Engineer (Data Platform)'
#  'Network/Telecom Engineer - EMEA' 'Software Integration Engineer (Pega)'
#  'Design Engineer - Senior, FCD Engineering'
#  '(Remote, Hungary) Senior Analytics Engineer'
#  'Staff Engineer Technical Marketing (f/m/div)*' 'Integration Engineer'
#  'Quantitative Development- Senior Software Engineer'
#  'Solution Support Engineer - Business Technology Platform'
#  'Factory Integration Engineer - Equipment Automation (f/m/div)'
#  'Lead Software Engineer (Revolut Business)' 'Backend Engineer'
#  'Sales Engineer' 'Senior Software Development Engineer (API)'
#  'Automation Engineer for Professional Services' 'Validation Engineer'
#  'Senior Big Data Engineer'
#  'Reliability engineer - SiC Semiconductor Modules'
#  'Senior Verification Engineer - PC'
#  'Senior Golang/Go Software Engineer - Emerging Technologies & Incubation'
#  'Applied Machine Learning Engineer (medior/senior)'
#  'Quality Assurance / Test Engineer'
#  'Data Engineer for Data Pipeline Development in automotive standards'
#  'Data Engineer gyakornok' 'Lead Python Engineer (Data Enrichment)'
#  '(Remote, Hungary) Senior Data Engineer'
#  'evosoft - Data Engineer for Medical Domain' nan]

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_HU, specializations_SK,specializations_DE, specializations_ROM],
        [data_terms_DE, data_terms_SK, specializations_DE, data_terms_ROM]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 35 :
# ['Site Reliability Engineer' 'Data Engineer' 'Data Analytics Engineer'
#  'AI Data Engineer Intern'
#  'SAP BW Engineer(s) with data engineering flair'
#  'Data Engineer (software/application)' 'Data DevOps Engineer'
#  'Cloud Data Engineer' 'Junior Data Engineer (REF1600P)'
#  'Data Engineer - OPJ állás Budapest' 'Staff Data Engineer'
#  'Data Engineer for IoT (REF1449L)' 'Spark Data Engineer'
#  'Big Data Engineer' 'Sustainability Quality Management System engineer'
#  'Data Platform Engineer' 'Cisco Data 2nd line engineer'
#  'Software Engineer (mid or senior level) for Data Platform'
#  'Sr Data Engineer' 'Senior Data Engineer' 'Power BI Platform Engineer'
#  'Data Security Engineer' 'data scientist & ai engineer'
#  'Sales Application Engineer (Energy Efficiency & Sustainability)'
#  'Data Integration Engineer' 'Cloud Devops Engineer (m/f/x)'
#  'Senior Data Pipeline Engineer (Data Platform)'
#  '(Remote, Hungary) Senior Analytics Engineer' 'Senior Big Data Engineer'
#  'Reliability engineer - SiC Semiconductor Modules'
#  'Data Engineer for Data Pipeline Development in automotive standards'
#  'Data Engineer gyakornok' 'Lead Python Engineer (Data Enrichment)'
#  '(Remote, Hungary) Senior Data Engineer'
#  'evosoft - Data Engineer for Medical Domain']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.11 Ireland

# %%
selector = 'Ireland'

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 323 :
# ['Process Excellence Engineer'
#  'Process and applications engineer (f/m/d)-Automation Background'
#  'Developer Support Engineer - (Remote)'
#  'Senior Quality Engineer - Galway' 'Platform Security Engineer'
#  'Designer FTTH - NBI' 'Software Engineer in Test SDET'
#  'Mechanical Building Services Design Engineer'
#  'Senior Automation Engineer' 'Senior Quality Assurance Engineer'
#  'Cloud Engineer - Zero Trust' 'Cloud Developer'
#  'Graduate Geologist, Engineering Geologist, Geotechnical Engineer'
#  'VFX Systems Engineer - On site' 'Senior Architectural Technologist'
#  'BER Assessor / Energy Consultant'
#  'GreenLake Cloud Platform Zero Trust Security - Master Level Engineer'
#  'Senior Cloud Developer' 'ARCGIS Specialist - Kilkenny'
#  'Principal Engineer'
#  'Senior Geotechnical Engineer / Engineering Geologist' 'Splunk Engineer'
#  'Senior Electrical Engineer - Denmark' 'Product Engineer'
#  'Full Time BMS Engineer' 'Quality Engineer'
#  'HVAC Test & Balancing Commissioning Engineer' 'In-Die Engineer'
#  'Solution Architect' 'Senior Systems Engineer'
#  'Graduate Automation Engineer' 'Process Development Engineer II'
#  'Process and Quality Engineer' 'R&D Technician' 'Manufacturing Engineer'
#  'Mechanical Engineer' 'Google Cloud Platform - GCP Technical Architect'
#  'Engineering Manager' 'BIM Designers - Multiple Opportunities'
#  'Mechanical Engineer QS' 'Solutions Engineering Manager'
#  'Mechanical BIM Engineer' 'Cleanroom Certification Engineer'
#  'Data Cabling Engineer Data Cabling Engineer' 'R&D Engineer II'
#  'Production Engineer' 'IT Support Engineer - Italian Speaking'
#  'Air Conditioning Technician' 'IT Support Engineer - German Speaking'
#  'Software Developer' 'Senior Continuous Improvement Engineer'
#  'Project Engineer (2 year fixed term contract) - Wexford, Ireland'
#  'Senior Software Engineer - DevSec Ops' 'HVAC Engineer'
#  'Maintenance Engineer' 'Senior Software Engineer' 'Junior CSV Engineer'
#  'Senior AutoSAR Developer' 'Electrical QA/QC Engineer'
#  'Mechanical Design Engineer II' 'Senior Quality Systems Engineer'
#  'Data Center Technician' 'QA Engineer' 'Senior Quality Engineer'
#  'Senior Software Quality Engineer' 'Associate QA Engineer'
#  'Process Engineer' 'Senior Software Developer' 'System Test Engineer'
#  'System Admin team lead' 'Senior Quality Engineer- Design Assurance'
#  'Quality Control Supervisor' 'Electrical Design Engineer'
#  'IT Infrastructure Engineer' 'M&E Project Manager' 'Moulding Technician'
#  'Senior R&D Engineer' 'Maintenance Technician (Evenings)' 'R&D Manager'
#  'Quality Team Lead' 'Senior Pre Market Supplier Quality Engineer'
#  'Senior Design Quality Engineer' 'Lead Electrical Engineer'
#  'R&D Manager - Product Engineering / Sustaining Engineering'
#  'Field service Engineer'
#  'Mechanic / Automotive Diagnostics Test Technician - VCS' 'Site Engineer'
#  'Manufacturing Shift Engineer' 'Software Engineering Team Lead'
#  'Senior Software Engineer C#' 'Senior Linguistic Tester with French'
#  'Service Coordinator Limerick' 'Facilities Co-ordinator'
#  'Civil Engineer - Wexford' 'Site Service Engineer' 'Electrical Engineer'
#  'Electrical Service Engineer' 'Customer Service Team Lead'
#  'Embedded Software Engineer' 'Process Validation Engineer'
#  'Big Data Engineer' 'Site Project Manager' 'Data Engineer'
#  'Senior Electrical Service Engineer' 'Data Center Trainee Technician'
#  'Administrator - Aircraft Maintenance Department' 'Sr. Hardware Engineer'
#  'Civil Engineer - Drogheda' 'Sr. Software Engineer'
#  'Quality Technician Evening Shift - Shannon' 'Civil Engineer - Laois'
#  '2nd Line Data Engineer' 'Junior/Mid-Level Data Scientists'
#  'Application Engineer' 'Graduate Engineer'
#  'Customer Support Representative (English+German)'
#  'Senior QA Automation Engineer' 'Process Development Engineer 2'
#  'Data Centre Technician' 'Software Engineer II' 'Full Stack Engineer'
#  'Data Center Engineering Operation Technician (Shift)'
#  'Senior Civil Engineer' 'Test Automation Engineer' 'IT Support'
#  'Infrastructure Database Engineer - SQL Server Specialism'
#  'Project QA/QC Lead' 'Maintenance Apprentice'
#  'Quantitative Data Engineer'
#  'Data Analyst, Sports Game Insights (12mo Fixed Term Contract)'
#  'Data Analyst Engineer' 'Validations Technician'
#  'Technical Support Engineer' 'Senior Data Engineer (remote)'
#  'Software Engineer Intern' 'Data Engineer (Azure)'
#  'Electrical Engineer - Data Centre' 'Process Development Engineer'
#  'Process Design Engineer (Ireland)'
#  'Quality Technician / Graduate Quality Engineer'
#  'Application Support Engineer' 'Project Engineer- Holland'
#  'Site / Setting out Engineer - Tier 1 Construction Contractor'
#  'QA Automation Engineer - IRL Remote'
#  'Data Core technical authority engineer'
#  'Intermediate/Senior Civil Engineer' 'Researcher: Application Engineer 1'
#  'Member of Technical Staff II - Opportunity for Working Remotely , Dublin'
#  'QA/QC Engineer (Denmark)'
#  'Software Engineer, Data Pipelines - Opportunity for Working Remotely Cork,'
#  'Technical Support Engineer - IPS Personnel'
#  'Senior Software Engineer – CargoWise Customs, Ireland'
#  'Technical Design Lead - Data Centers'
#  'Junior Electrical Engineer | Tier 1 M&E Contractor | Dublin'
#  'NET software development engineer, Tanzu - Opportunity for Working Remotely Cork,'
#  'Systems/Software Engineer (Graduate)'
#  'Graduate Virtual Development Platform Software Engineer'
#  'Data Engineering Manager'
#  'Localisation QA Engineer with French - Canadian Market'
#  'Data Centre Specialist' 'Cloud Engineer ( Data Analytics) Hybrid'
#  'Junior BIM Engineer | Tier 1 M&E Contractor | Limerick'
#  'Senior Data Engineer- Hybrid' 'Automation Engineer'
#  'AV Support Engineer, IT Services'
#  'Project Manager (based in Dublin, Ireland) Dublin, Ireland'
#  'Engineering Manager - People Workflows Automation'
#  'Software Engineer - Foundations | Data Platform - Remote...'
#  'AWS Cloud Operations and Automation Engineer'
#  'Data Engineer - QuantumBlack' 'SQL Engineer (QA Background)'
#  'Controls/Automation Engineer' 'Automation Engineer, SNN4 RME Team'
#  'AWS Data Engineer (Hybrid)' 'Data Engineer - PySpark'
#  'WordPress Engineer' 'System Development Engineer, AWS DNS'
#  'Data engineer II' 'QA Tester with Finnish'
#  'Software Development Engineer' 'RDS Engineer' 'Software Engineer'
#  'Embedded Software Engineer (m/f/d)'
#  'Data Analyst - Associate Tools (Cork or Republic of Ireland remote)'
#  'Test Software Development Engineer'
#  'Site Reliability Engineer, Remote, 4 day week (Swing shift)'
#  'Manufacturing Engineering Apprentice' 'Applications Engineer'
#  'Assoc. Software Engineer' 'Data Center Site Representative'
#  'Design (Applications) Engineer' 'Data Scientist / ML Engineer'
#  'SIEM & Detection Engineer (Ireland Remote)' 'Data Engineer (AWS)'
#  'NLP Data Engineer' 'Software Engineer - App Stores Backend (Remote)'
#  'Cloud Operations Engineer (AWS) - Ireland (Remote)'
#  'Kingspan Graduate Programme - Operations / Engineering'
#  'Data Analytics & Insights Engineer– Firmwide Reference Data Quality'
#  'Data Warehouse Engineer - €55 - 70k - Part Remote - Ireland Based'
#  'AWS Cloud Platform Engineer' 'Data Warehouse Engineer'
#  'Security Engineer - Detection Engineering' 'Helpdesk Support Engineer'
#  'Platform Data Engineer' 'Sr Data Engineer' 'Data Engineer (Cloud)'
#  'Software Engineer II (Kargo Commerce)' 'Data Engineer, Mid to Staff'
#  'Senior QA Engineer' 'CSV Engineer - Remote'
#  'Data Analyst (Architecture and Engineering team)' 'Test Engineer-R&D'
#  'Field Service Technician'
#  'Engineer, Test Process Development Engineering'
#  'Graduate Program 2023 - Infrastructure Security Engineer'
#  'Software Engineer (Leadership) - Metaworks' 'Analytics Engineer'
#  'Applied Scientist - Ads (Remote)' 'Site Reliability Engineer'
#  'Sr Tech Support Engineer' 'Data Center Network Infrastructure Engineer'
#  'Automation Test Engineer' 'DevOps Engineer (Data)'
#  'Site Reliability Engineer, Galway' 'AI & ML Software Engineer'
#  'Senior Site Reliability Engineer - Dublin, Munich, Amsterdam (Remote from Ireland or Germany)'
#  'Injection Moulding Process Technician' 'Technical Development Engineer'
#  'Business Intelligence - €55 - 70k - Part Remote - Ireland Based'
#  'Supplier Quality Engineer'
#  'GreenLake Cloud Platform Zero Trust Security - Entry level engineer'
#  'L1 Data Center Engineer' 'Infrastructure Database Engineer'
#  'Storage Engineer,' 'ELECTRICAL TECHNICIAN' 'Field Service Engineer'
#  'Frontend Software Engineer' 'Mechanical Engineer - Summer Placement'
#  'Senior Data Engineer' 'Test Engineer' 'Quality Engineer - Mobile'
#  'Senior Engineer, Process Sustaining Engineering'
#  'SOFTWARE ENGINEER INTERN' 'Physical Security Architect Data Center'
#  '2K Games Dublin - Fast Track Engineering Graduate Programme'
#  'QC Product Analyst (Day Position) (TEMPORARY)' 'Operations Engineer'
#  'Operations Director- Ireland' 'Systems Engineer'
#  'Datacenter Operations Engineer' 'Technology Project Manager'
#  'Project Manager' 'Mid Level Software Development Security Engineer'
#  'Graduate Programme 2023 - Dublin and European locations'
#  'Business Intelligence Engineer'
#  'Intern Instrumentation Engineer 2023 Dublin'
#  'Graduate Programme - Mechanical Engineering Stream'
#  'Data Centre Shift Tech - Data Centre Solutions - Dublin'
#  'Cyber Security Analyst - Dublin - €80 - 100k + Benefits - Part Remote'
#  'Advisory and Digital Services Graduate - 2023 Graduate Programme'
#  'Data Warehouse Engineer 3+ years - SQL,SSIS,ETL,Azure - €55 - 70k - Dublin'
#  'Modelling and Simulation Engineer' 'Process Engineer - Waste Water'
#  'Cloud Data Engineer'
#  'PROCESS DESIGN ENGINEERS (Remote Work- Based across South America)'
#  'Security Engineer, Investigations & Response' 'Controls Engineer'
#  'Site Reliability Engineer - GreenLake Cloud Solutions'
#  'Infrastructure Market Data Engineer'
#  'Master Level Engineer - GreenLake Cloud Platform - Organizations'
#  '2023 Systems Development Engineer Intern' 'Software Engineer III'
#  'Chemical Process Engineer' 'QC Analyst – QC Bioassay' 'R&D Engineer'
#  'Electronics Test Engineer'
#  'Business Analyst/Project Manager - Supply Chain'
#  'R&D Test Development Engineer' 'Project Quality Engineer' 'Engineer'
#  'CyberArk (PAM) Engineer' 'Machine Learning Internship'
#  'Staff Engineer - Process Development, Advanced Operations'
#  'Software Development Engineer - Workforce Scheduling'
#  'Biomedical Engineer - Hybrid' 'Software Engineer (Managed Services)'
#  'Sr. Security Researcher - Ireland' 'Mid-Level Python Engineer'
#  'Service Engineer – Dublin Airport' 'Service Desk Engineer Level 3'
#  'Network Engineer' 'Desktop Engineer L1'
#  'Data Center Principal Electrical Engineer'
#  'Associate Engineer, Design Evaluation Engineering' 'Biomedical Engineer'
#  'European Business Development Manager' 'Maintenance Engineer II'
#  'Graduate Transport Planner – 2023 Graduate Programme'
#  'Graduate Piping Engineer Dublin 2023' 'Senior Software Engineer II'
#  'Graduate Maritime Engineer - 2023 Graduate Programme'
#  'R&D Test Engineer' 'SC Equipment Engineer'
#  'GreenLake Cloud Platform Zero Trust Security - Expert level engineer'
#  'Field Service Engineer (Cork and South East ROI)'
#  'R&D Incentives Senior Consultant - Electronic Engineer'
#  'Reliability Engineer' 'Environmental Engineer - 2023 Work Placement'
#  'Security Analyst - all locations'
#  'Senior Data Analyst, Business Intelligence (Mobile) - Fixed Term'
#  'Cloud Platform Engineer' 'Electrical Design Engineer – All Grades'
#  'Validation Engineer (based in Letterkenny, Ireland)'
#  'Fire & Security Engineer' 'Quality Engineer- Design Assurance'
#  'Autonomous Systems Software Engineer' 'Quality Engineer (NPI)'
#  'Principle R&D Engineer' 'Associate Quality Engineer'
#  'Manufacturing Engineer II' 'Labelling Engineer II'
#  'Junior Project Engineer']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_DE, specializations_DK,specializations_NL],
        [data_terms_DE, data_terms_DK, specializations_NL]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 82 :
# ['Cloud Engineer - Zero Trust' 'Cloud Developer'
#  'Senior Architectural Technologist'
#  'GreenLake Cloud Platform Zero Trust Security - Master Level Engineer'
#  'Senior Cloud Developer' 'ARCGIS Specialist - Kilkenny'
#  'Solution Architect' 'Google Cloud Platform - GCP Technical Architect'
#  'Engineering Manager' 'Solutions Engineering Manager'
#  'Mechanical BIM Engineer' 'Data Cabling Engineer Data Cabling Engineer'
#  'R&D Manager'
#  'R&D Manager - Product Engineering / Sustaining Engineering'
#  'Software Engineering Team Lead' 'Big Data Engineer' 'Data Engineer'
#  '2nd Line Data Engineer'
#  'Data Center Engineering Operation Technician (Shift)'
#  'Infrastructure Database Engineer - SQL Server Specialism'
#  'Quantitative Data Engineer' 'Data Analyst Engineer'
#  'Senior Data Engineer (remote)' 'Data Engineer (Azure)'
#  'Data Core technical authority engineer'
#  'Software Engineer, Data Pipelines - Opportunity for Working Remotely Cork,'
#  'Technical Design Lead - Data Centers' 'Data Engineering Manager'
#  'Data Centre Specialist' 'Cloud Engineer ( Data Analytics) Hybrid'
#  'Junior BIM Engineer | Tier 1 M&E Contractor | Limerick'
#  'Senior Data Engineer- Hybrid'
#  'Engineering Manager - People Workflows Automation'
#  'Software Engineer - Foundations | Data Platform - Remote...'
#  'AWS Cloud Operations and Automation Engineer'
#  'Data Engineer - QuantumBlack' 'AWS Data Engineer (Hybrid)'
#  'Data Engineer - PySpark' 'Data engineer II'
#  'Site Reliability Engineer, Remote, 4 day week (Swing shift)'
#  'Manufacturing Engineering Apprentice' 'Data Scientist / ML Engineer'
#  'Data Engineer (AWS)' 'NLP Data Engineer'
#  'Cloud Operations Engineer (AWS) - Ireland (Remote)'
#  'Kingspan Graduate Programme - Operations / Engineering'
#  'Data Analytics & Insights Engineer– Firmwide Reference Data Quality'
#  'Data Warehouse Engineer - €55 - 70k - Part Remote - Ireland Based'
#  'AWS Cloud Platform Engineer' 'Data Warehouse Engineer'
#  'Security Engineer - Detection Engineering' 'Platform Data Engineer'
#  'Sr Data Engineer' 'Data Engineer (Cloud)' 'Data Engineer, Mid to Staff'
#  'Data Analyst (Architecture and Engineering team)'
#  'Engineer, Test Process Development Engineering' 'Analytics Engineer'
#  'Site Reliability Engineer' 'Data Center Network Infrastructure Engineer'
#  'DevOps Engineer (Data)' 'Site Reliability Engineer, Galway'
#  'Senior Site Reliability Engineer - Dublin, Munich, Amsterdam (Remote from Ireland or Germany)'
#  'GreenLake Cloud Platform Zero Trust Security - Entry level engineer'
#  'L1 Data Center Engineer' 'Infrastructure Database Engineer'
#  'Senior Data Engineer' 'Senior Engineer, Process Sustaining Engineering'
#  'Physical Security Architect Data Center'
#  '2K Games Dublin - Fast Track Engineering Graduate Programme'
#  'Datacenter Operations Engineer' 'Business Intelligence Engineer'
#  'Data Warehouse Engineer 3+ years - SQL,SSIS,ETL,Azure - €55 - 70k - Dublin'
#  'Cloud Data Engineer'
#  'Site Reliability Engineer - GreenLake Cloud Solutions'
#  'Infrastructure Market Data Engineer'
#  'Master Level Engineer - GreenLake Cloud Platform - Organizations'
#  'Associate Engineer, Design Evaluation Engineering'
#  'European Business Development Manager'
#  'GreenLake Cloud Platform Zero Trust Security - Expert level engineer'
#  'Reliability Engineer' 'Cloud Platform Engineer']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.12 Israel

# %%
selector = "Israel"

specializations = ["מהנדס", "הנדסה", "יועץ", "אדריכל", "מומחה", "מנהל", "מפתח", "ארכיטקטורה", "מנהל מערכות"]

data_terms = ["נתונים", "ETL", "ענן", "ניתוח", "ניתוח נתונים", "BI", "בינה מעסיקתית", "אנליטיקה עסקית", "מסד נתונים", "צינורות נתונים", "מטא נתונים", "מעקב", "מרכז נתונים"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 83 :
# ['Data Engineer' 'Fullstack Engineer' 'Big Data Engineer'
#  'ML Engineer - Iguazio (Acquired by McKinsey)' 'Full-Stack Engineer'
#  'BI Data Engineer' 'Junior Windows Low Level Engineer - Engine team'
#  'Machine Learning Engineer Student' 'Data Tools Engineer'
#  'Software Dev Engineer Intern' 'Senior Data Engineer'
#  'Data Solutions Engineer' 'Senior/Junior Data Engineer'
#  'Data Engineer - Data Assets Group' 'Senior Frontend Engineer'
#  'Backend Engineer' 'DATA ENGINEER' '\uf4ccData Engineer\uf4cc(Hybrid'
#  'Machine Learning Engineer' 'Embedded Software Engineer- AWS Nitro'
#  'Cloud Data Engineer' 'Data Infra Engineer' 'Data Platform Engineer'
#  'Finout-Data Engineer' 'Data Engineer Lead' 'Experienced Data Engineer'
#  'Storage Analytics - Data Engineer' 'Data Engineer, Mobile Identity'
#  'Junior DevOps Engineer' 'Senior Software Engineer - Iguazio'
#  'Deep Learning Engineer' 'Back End Engineer'
#  'מעל שנתיים ניסיון | Data engineer'
#  'Data Engineer לארגון פיננסי מוביל בת"א!' 'Data Engineer לחברה פיננסית'
#  'Data Engineer לארגון מסווג' 'Software Engineer - Data Science Team'
#  'Data Engineer בחברת Online Gaming מצליחה!'
#  'Senior Software Engineer - Data Path'
#  'CPU Silicon Engineer, Design Verification, Google Cloud'
#  'Senior Data Infrastructure Engineer (Architecture Group)'
#  'Technical Support Engineer' 'Data Engineer בחברת הייטק ותיקה ורווחית'
#  'Data Engineer לחברת הייטק גלובלית בתחום הE-Commerce'
#  'QA Automation Engineer - Data Group' 'Senior Backend/ Data Engineer'
#  'לסטארט אפ מצליח הממוקם בתל אביב דרוש/ה Python Data Engineer'
#  'Application Engineer' 'Senior Back-End Engineer - Iguazio'
#  'Data Engineer בחברת סטארטאפ מרשימה!' 'MLOps Engineer'
#  'חברת Gaming מחפשת Data Engineer' 'Senior Data Engineer - Analytics'
#  'Senior SAS Data Engineer' 'Senior Fullstack Engineer' 'BI Tech Lead'
#  'Data & MLOps Engineer' 'Senior Software Engineer Tel Aviv, Israel'
#  'Cloud Operations Engineer' 'Data Engineer בחברה רווחית בתחום ה-Data'
#  'Windows Low Level Engineer - Platform team' 'Data Engineer Manager'
#  'Staff Support Engineer' 'Senior Software Engineer, Tenable One Team'
#  'Senior Software Engineer - OT' 'Data Infra Team Leader'
#  'Senior Software Engineer'
#  'Software Engineer (Leadership) - Infrastructure'
#  'Senior Staff Software Engineer' 'Senior Data Software Engineer'
#  'Production Services Engineer'
#  'Software Engineer - Agentless Team (Senior Level)'
#  'Data Scientist/Machine Learning Engineer בחברת סטארט-אפ'
#  'Python Data/Machine Learning Engineer לסטארטאפ ממומן ומצליח בתחום הריטייל'
#  'Data Science Engineer'
#  'Software Engineer Data Pipelines And Infrastructure - Tel Aviv'
#  'Software Engineer for Data Intelligence Group'
#  'Data Engineer לסטארטאפ בת"א' 'Radio Frequency Engineer(R&D Engineer)'
#  'Software Engineer Tel-Aviv' 'Software Engineer'
#  'Silicon Validation Engineer, Google Cloud'
#  'Backend/Machine Learning Software Engineer בחברת סטארט-אפ']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_DE, specializations_DK,specializations_NL],
        [data_terms_DE, data_terms_DK, specializations_NL]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 50 :
# ['Data Engineer' 'Big Data Engineer' 'BI Data Engineer'
#  'Data Tools Engineer' 'Senior Data Engineer' 'Data Solutions Engineer'
#  'Senior/Junior Data Engineer' 'Data Engineer - Data Assets Group'
#  'DATA ENGINEER' '\uf4ccData Engineer\uf4cc(Hybrid' 'Cloud Data Engineer'
#  'Data Infra Engineer' 'Data Platform Engineer' 'Finout-Data Engineer'
#  'Data Engineer Lead' 'Experienced Data Engineer'
#  'Storage Analytics - Data Engineer' 'Data Engineer, Mobile Identity'
#  'מעל שנתיים ניסיון | Data engineer'
#  'Data Engineer לארגון פיננסי מוביל בת"א!' 'Data Engineer לחברה פיננסית'
#  'Data Engineer לארגון מסווג' 'Software Engineer - Data Science Team'
#  'Data Engineer בחברת Online Gaming מצליחה!'
#  'Senior Software Engineer - Data Path'
#  'CPU Silicon Engineer, Design Verification, Google Cloud'
#  'Senior Data Infrastructure Engineer (Architecture Group)'
#  'Data Engineer בחברת הייטק ותיקה ורווחית'
#  'Data Engineer לחברת הייטק גלובלית בתחום הE-Commerce'
#  'QA Automation Engineer - Data Group' 'Senior Backend/ Data Engineer'
#  'לסטארט אפ מצליח הממוקם בתל אביב דרוש/ה Python Data Engineer'
#  'Data Engineer בחברת סטארטאפ מרשימה!' 'חברת Gaming מחפשת Data Engineer'
#  'Senior Data Engineer - Analytics' 'Senior SAS Data Engineer'
#  'BI Tech Lead' 'Data & MLOps Engineer' 'Cloud Operations Engineer'
#  'Data Engineer בחברה רווחית בתחום ה-Data' 'Data Engineer Manager'
#  'Data Infra Team Leader' 'Senior Data Software Engineer'
#  'Data Scientist/Machine Learning Engineer בחברת סטארט-אפ'
#  'Python Data/Machine Learning Engineer לסטארטאפ ממומן ומצליח בתחום הריטייל'
#  'Data Science Engineer'
#  'Software Engineer Data Pipelines And Infrastructure - Tel Aviv'
#  'Software Engineer for Data Intelligence Group'
#  'Data Engineer לסטארטאפ בת"א' 'Silicon Validation Engineer, Google Cloud']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.13 Italy

# %%
selector = 'Italy'

specializations_SL = ["Inženir", "Inženiring", "Svetovalec", "arhitekt", "SPECIALIST", "Vodja", "Razvijalec", "Arhitektura", "Administrator"]

data_terms_SL = ["Podatki", "ETL", "Oblak", "Analitični", "Analitika", "BI", "Poslovna Inteligenca", "Poslovna Analitika", "Podatkovna Baza", "Cevovod", "Metapodatki", "Spremljanje", "Podatkovni Center"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 131 :
# ['IT Data Engineer' 'ingegnere elettrico o perito di esperienza'
#  'Process Engineer (PED-05) Start-up Technician - Tecnico Avviamento Impianti'
#  'Direttore di cantiere' 'INGEGNERE ENERGETICO - PROGETTISTA TERMOTECNICO'
#  'supervisore di cantiere (elettromeccanico)'
#  'SENIOR ENGINEER - SVILUPPATORE WEB / E-COMMERCE'
#  'Embedded Software Engineer' 'SYSTEM ENGINEER' 'Data Engineer'
#  'Control System Engineer' 'Senior System Engineer Evangelist'
#  'Ingegnere progettista' 'Backend Engineer Ecommerce - Python (Odoo)'
#  'INGEGNERE CIVILE / EDILE' 'Software Developer Senior'
#  'Data Engineer / ETL Developer' 'Ingegnere Elettronico Programmatore PLC'
#  'Ingegnere elettrico / meccanico / edile'
#  'Senior Application Engineer M/F' 'Ingegnere meccanico/strutturista'
#  'INGEGNERE PER PIANIFICAZIONE TRASPORTO PERSONE' 'Progettista elettrico'
#  'Data Engineer (hybrid-remote)' 'Progettista fotovoltaico'
#  'DATA ARCHITECT/FULL STACK DEVELOPER' 'Project Engineer'
#  "CONSULENTE AZIENDALE con esperienza in SANITA'" 'Geometra / Ingegnere'
#  'INGEGNERE PROGETTISTA MECCANICO SENIOR'
#  'ingegnere o architetto per settore rinnovabili ed efficienza energetica'
#  'Process Control Engineering M/F'
#  'TECNICO BUILDING AUTOMATION, ENERGY MANAGEMENT E SISTEMI SUPERVISIONE'
#  'Consulente aziendale specialist sistemi di gestione'
#  'Sviluppatore software PLC, sviluppatore software C++' 'Responsabile IT'
#  'Comandate e/o Ingegnere Navale' 'RISORSA PER AREA TECNICA'
#  'SiC Process Engineering - Process Integration M/F' 'vehicle engineer.'
#  'Ing. Elettronico/Elettrotecnico' 'Field Service Engineer'
#  'Mechanical Engineer' 'QUALITA ISO'
#  'Ingegnere/Architetto - energie rinnovabili'
#  'Workforce Planner & Data Analyst' 'Stagista/Tirocinante'
#  'Stage progettista e consulente sistemi energetici' 'Project Manager'
#  'Full Stack Developer' 'Chemical Industrial Engineer' 'Data Analyst'
#  'Field Engineer Elettro Strumentale'
#  'Geometra o ingegnere o architetto di cantiere'
#  'Impiegato amministrativo contabile'
#  'Junior Data & Analytics Engineer - parzialmente remoto' 'DATA ENGINEER'
#  'Ingegnere Meccanico Disegnatore'
#  'Progettista elettrico nel settore delle costruzioni residenziali'
#  'SENIOR PROJECT MANAGER IMPIANTI ELETTRICI'
#  'Disegnatore CAD / Addetto ufficio tecnico' 'Software Developer Junior'
#  'Customer Service Specialist/Leader' 'Sistemista Microsoft e networking'
#  'laureati in scienze naturali, ingegneria meccanica, ingegneria elettronica,'
#  'Informatico - IT SUPPORT Sistemi & Networking' 'IMPIEGATO TECNICO'
#  'Responsabile Controllo e Project Manager'
#  'Addetto Junior Facility Management - geometra, ingegnere, archietto'
#  'Responsabile Acquisti e Programmazione' 'Junior Quality Engineer'
#  'Ingegnere Civile nel settore delle costruzioni residenziali'
#  'Customer Service Specialist' 'PHP web developer'
#  'Tecnico Automazione/meccatronico per installazione impianti Automatizzati'
#  'Junior Project Manager' 'Specialista IT Service Management'
#  'Sistemista informatico' 'Junior Data Engineer' 'Consultant ambito PMO'
#  'architetto bim specialist' 'Backend Developer | JEE'
#  'INGEGNERE CIVILE / ARCHITETTO' 'preventivista idraulico'
#  'Auditor Sicurezza cantiere opere civili'
#  'Manager/Direttore Tecnico di Cantiere' 'INGEGNERE MECCANICO'
#  'Ingegnere Civile, Architetto, Geometra'
#  'PROPOSAL ENGINEER / PROJECT ENGINEER - Remote Working'
#  'Stage Addetto/A Data Engineer' 'Direttore Tecnico CTO'
#  'RICERCA GEOMETRA/ARCHITETTO/INGEGNERE con esperienza-CANTIERI EDILI'
#  'Tirocinio formativo società di ingegneria'
#  'PROGETTISTA FIRMWARE / ELECTRONIC ENGINEER'
#  'Junior Hardware Designer Engineer'
#  'R&D ELECTRIC ENGINEER / PROGETTISTA ELETTRICO' 'Chimico'
#  'Impiegato tecnico commerciale' "addetto gare d'appalto"
#  'Pianificatore della Produzione Junior' 'geometra capo cantiere'
#  'PROGETTISTA/INGEGNERE MECCANICO' 'DataOps Engineer' 'PROCESS ENGINEER'
#  'SG - Tirocinio per Adulti come "BUYER"' 'Process engineer'
#  'PROCESS MAPPING AND IMPROVEMENT SPECIALIST - SPECIALISTA ORGANIZZAZIONE'
#  'INGEGNERE ENERGETICO' 'INGEGNERE DI PROCESSO' 'Clean room engineer'
#  'ENERGY ENGINEER - Impianti Elettrici/Fotovoltaici'
#  'ASSET CONSTRUCTION AND MAINTENANCE DIRECTOR - Alberghiero'
#  'Responsabile di cantiere impianti' 'Solution Engineer'
#  'AFTER MARKET ENGINEER' 'Pcb Designer Engineer'
#  'Data Analyst & Reporting – SECO spa' 'Senior Hardware Design Engineer'
#  'PROGETTISTA ELETTRONICO JUNIOR' 'Labview Developer Senior - 019991'
#  'Progettista e Supporto Tecnico Cantieri'
#  'PROGETTISTA ELETTRO-STRUMENTALE'
#  'PROJECT ENGINEER - Sistemi Fire&Gas e Automazione' 'PROGRAMMATORE PLC'
#  'CONSULENTE VALUTAZIONE INDUSTRIALI' 'Ingegnere tecnico di produzione'
#  'JOB COORDINATOR (SETTORE VALVOLE OIL&GAS)' 'DIRETTORE OPERATIONS' nan
#  'Test engineer veicolo per Komatsu spa' 'stage data analyst']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_IT, specializations_DE,specializations_FR, specializations_CA, specializations_GR, specializations_SL],
        [data_terms_IT, data_terms_DE, specializations_FR, data_terms_CA,data_terms_GR, data_terms_SL]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 15 :
# ['IT Data Engineer' 'Data Engineer' 'Data Engineer / ETL Developer'
#  'Data Engineer (hybrid-remote)' 'DATA ARCHITECT/FULL STACK DEVELOPER'
#  'ingegnere o architetto per settore rinnovabili ed efficienza energetica'
#  'Ingegnere/Architetto - energie rinnovabili'
#  'Junior Data & Analytics Engineer - parzialmente remoto' 'DATA ENGINEER'
#  'Junior Data Engineer' 'Consultant ambito PMO'
#  'architetto bim specialist' 'Manager/Direttore Tecnico di Cantiere'
#  'Stage Addetto/A Data Engineer' 'DataOps Engineer']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.14 Luxembourg

# %%
selector = 'Luxembourg'

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 118 :
# ['DATA ENGINEER' '2023 Data Engineer Internship' 'Data Engineer'
#  'IT Support Engineer' 'Software Engineer Data' 'MS Engineer VMware'
#  'Process Engineer (m/f)' 'DATA ENGINEER H/F'
#  'Senior Data Engineer (f/m/d)'
#  'Data Scientist ou Data Analytics Engineer (m/f) (réf. E00024412) (réf. F00024413)'
#  'Data Engineer (H/F)' 'Senior Software-Defined Data Center Engineer'
#  'Data Architect/Senior Data Engineer (m/f/n)'
#  '2023 Software Development Engineer Internship'
#  'Unified Communications Engineer' 'Materials Engineer'
#  'Unified Communications Engineer (Microsoft)'
#  'Business Intelligence Engineer, EU Production Planning Central Team'
#  'Mechanical Engineer with an interest in Design' 'Data Engineer (m/f/gn)'
#  'DATA ENGINEER (F/M)' 'Internship - Development Process Engineer (m/f/d)'
#  'Analytics Engineer (m/f/d)' 'Senior Data Engineer (F/M)'
#  'Quality Engineer' '2023 Business Intelligence Engineer Internship'
#  'Internship as control systems engineer'
#  'AV Support Engineer, IT Services' 'Data Development Engineer'
#  'Data Centre Engineer' 'Service Delivery Support Engineer (L2)'
#  'Product Development Engineer'
#  'IM-2313 DATA-DRIVEN OPTIMIZATION OF CHARGED PARTICLE OPTICS INTERNSHIP'
#  'APPLICATION SUPPORT ENGINEER' 'Data Scientist' 'AZURE DATA ENGINEER'
#  'IT System Engineer'
#  'Data and Analytics Engineer – New role – build a data factory'
#  'SOC Engineer' 'Application Engineer (IT) / Freelance'
#  'Engineer Back End Nodejs'
#  'IM-2322 POROUS MATERIAL EFFECTIVE PROPERTIES THROUGH FINITE ELEMENT SIMULATION INTERNSHIP'
#  'DevOps Engineer' 'Electronic Design Engineer, Deep Space Avionics'
#  'Computer Vision Engineer (Embedded Devices)'
#  'Lead Application Support Engineer'
#  'Business Intelligence (BI) /Data Analyst (DeFi) - Digital Assets'
#  'Algorithmic Trader - Cryptocurrency' 'Application Engineer - EMEA'
#  'Head of Data Engineering / Lead Database Engineer'
#  'Engineer for Homologation/Type Approval of Vehicles'
#  'SITE RELIABILITY ENGINEER' 'MS Engineer L1' 'Quality Control Engineer'
#  'Senior Quality Control Technician / Engineer'
#  'Senior Quantitative Algorithmic Trader - Stock Market'
#  'Business Intelligence Engineer M/F'
#  'Back End Engineer / FinTech Banking as a Service / Node.js / AWS'
#  'Head of Product Strategy & Development'
#  'IT Network and Security Engineer (m/f/d)'
#  'Business Analyst – Transaction Reporting (Savings, Investments & Client Advice) (m/f) CDI'
#  'Middleware Engineer' 'Cybersecurity Infrastructure Engineer'
#  'ETL/Data Engineer (m/w/d)' 'CTS Plates (144237)'
#  'Software Test Automation Engineer Trainee'
#  'OFFICE 365 / SYSTEM ENGINEER'
#  'EMPLOI: Soldering Engineer / Expert (m/f/d)' 'Alpha Researcher'
#  'Long term IT contracts at the European Institutions'
#  'Solution Engineer - Materials & ICME' 'Software Sales Engineer'
#  'Integration Specialist' 'Lead Informatica MDM Engineer'
#  'Senior Engineer, Ground Systems' 'Head of OTC Trading - Cryptocurrency'
#  'Application Support Officer' 'E-Lab Technician'
#  '(Junior) Specialist, Technical Facility Management (Benelux)'
#  'IM-2319 INCORPORATION OF INTUMESCENT FLAME-RETARDANT ADDITIVES INTO POLYAMIDE INTERNSHIP'
#  'IT Security Engineer' 'Spacecraft Systems Engineer'
#  'Amazon Postdoctoral Scientist , EU ATS Research Science'
#  'Integration Engineer'
#  'II-2311 EXPLAINABLE IMAGE QUALITY ASSESSMENT OF SCIENTIFIC LOW-LIGHT IMAGES INTERNSHIP'
#  'System Engineer (m/f/d) Telecommunications - NOC - Network Technology'
#  'Digital Workplace Senior Engineer'
#  'IE-2312 BIODISCOVERY OF FUNGAL DERIVED BIOACTIVE COMPOUNDS INTERNSHIP'
#  'E-2324 POSTDOCTORAL RESEARCHER IN DATA DRIVEN OPTIMIZATION FOR DISTRIBUTION GRID'
#  '(Senior) Engineer, Software' 'Software Engineer - .NET Core/Angular'
#  'CAMO Engineer- Systems (m/f/x)' 'Microsoft Systems Engineer'
#  'Senior Software Engineer – Data Platform'
#  'Research and Development specialist in embedded telecommunication systems and Artificial Intelligence / Machine Learning'
#  'II-2302 TIME SENSITIVE NETWORKING INTERNSHIP'
#  'II-2309 LUXEMVERSE, THE LUXEMBOURGISH METAVERSE INTERNSHIP'
#  'GCP Data Solution Architect' 'Quality Assurance Engineer'
#  'Lead Application Support Engineer (m/f)'
#  'Software Project Coordinator (m/f)' 'Soldering Engineer/Expert (f/m/d)'
#  'Planning Engineer (M/F/X) 1220'
#  'Problem Management Analyst (team Service Management) (M/F)'
#  'Windows System Engineer - LUXEMBOURG M/W' 'Commodities Analyst'
#  'Senior Solution Engineer (m/f)' 'Cloud Solutions Architect (f/m/d)'
#  'System and Network Engineer (M/F)'
#  'Corporate R&D & Industrialization Engineer (m/f)'
#  'Backend Software Engineer' 'LowCode-NoCode Developer (m/f/x)'
#  'Wireless Embedded Software Engineer'
#  'Software Engineers Data with ETL specialization – FR/EN (F/M)'
#  'IT Infrastructure & Service Delivery Officer' 'Core Network Engineer'
#  'IM-2304 INNOVATIVE POLYMERS FOR ION EXCHANGE MEMBRANES INTERNSHIP'
#  'Business Analyst LuxairCARGO - Operation Export']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_DE, specializations_FR],
        [data_terms_DE, data_terms_FR]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 28 :
# ['DATA ENGINEER' '2023 Data Engineer Internship' 'Data Engineer'
#  'Software Engineer Data' 'DATA ENGINEER H/F'
#  'Senior Data Engineer (f/m/d)'
#  'Data Scientist ou Data Analytics Engineer (m/f) (réf. E00024412) (réf. F00024413)'
#  'Data Engineer (H/F)' 'Senior Software-Defined Data Center Engineer'
#  'Data Architect/Senior Data Engineer (m/f/n)'
#  'Business Intelligence Engineer, EU Production Planning Central Team'
#  'Data Engineer (m/f/gn)' 'DATA ENGINEER (F/M)'
#  'Analytics Engineer (m/f/d)' 'Senior Data Engineer (F/M)'
#  '2023 Business Intelligence Engineer Internship'
#  'Data Development Engineer' 'Data Centre Engineer' 'AZURE DATA ENGINEER'
#  'Data and Analytics Engineer – New role – build a data factory'
#  'Head of Data Engineering / Lead Database Engineer'
#  'SITE RELIABILITY ENGINEER' 'Business Intelligence Engineer M/F'
#  'ETL/Data Engineer (m/w/d)' 'Senior Software Engineer – Data Platform'
#  'GCP Data Solution Architect' 'Cloud Solutions Architect (f/m/d)'
#  'Software Engineers Data with ETL specialization – FR/EN (F/M)']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.12 Netherlands

# %%
selector = 'Netherlands'

specializations_FRI = ["Ynżenier", "Ynženiering", "Konsultant", "arkitekt", "SPESJALIST", "Manager", "Ûntwikkelers", "Arktitektuer", "Administrator"]

data_terms_FRI = ["Data", "ETL", "Cloud", "Analytysk", "Analitika", "BI", "Bisykens Intelligence", "Bisykens Analytics", "Database", "Pipeline", "Metadata", "Monitoring", "Datacenter"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 158 :
# ['Engineer Industriële Automatisering' 'Senior AWS Cloud Engineer'
#  'Backend Software Engineer C# .NET' 'ILS Engineer' 'Growth Engineer'
#  'Data Engineer' 'Engineer elektrotechniek' 'C/C++ Software Engineer'
#  'Vacature Engineer Industriële Automatisering'
#  'Software Engineer Industriële Automatisering'
#  'Application Engineer - portal beheerder' 'Mechanical Engineer'
#  'Software Engineer' 'Data Engineering stagiair(e)'
#  'Data Engineer Nivel Zorgregistraties Eerste Lijn'
#  'Medior/Senior Embedded Systems Engineer' 'INFORMATIE / DATA ANALIST'
#  'Werkvoorbereider machinebouw' 'Product Engineer'
#  'Engineer infrastructuur Binnenkabels' 'DevOps Engineer'
#  'Analist cost engineer' 'Analytics Engineer'
#  'Global Performance Paid Social Specialist' 'Desktop Support Technician'
#  'Supply Chain Engineer' 'QHSE Manager'
#  'Operationeel/Technisch netwerk monitoring specialist'
#  'Parttime PowerBI Developer (16-32 uur)' 'IT Support Engineer'
#  'Application Engineer' 'Control Systems Engineer'
#  'IT traineeship, open voor alle studieachtergronden' 'Service Engineer'
#  'IT-coördinator' 'Business Analist' 'Full Stack Software Developer'
#  'Engineer' 'Senior DevOps-engineer Mulesoft' 'Product Design Engineer'
#  'DevOps Engineer Applicatiebeheer (NL)' 'Senior Database Specialist'
#  'Security Engineer' 'Rubber Characterization - Thesis Project'
#  'Senior Software Engineer (C++/C#)' 'Packaging Engineer'
#  'Ingenieur Elektrisch' 'lead engineer cloud & big data'
#  'system engineer packaging' 'coördinator - Digital Intrusion Team'
#  'ICT Service Engineer op locatie' 'Full Stack Engineer'
#  'Embedded Software Engineer'
#  'kwaliteitsmedewerker - Digital Intrusion Team' 'Api Engineer'
#  'ontwikkelaar/tester - Digital Intrusion Team'
#  '(Dutch Speaking) Executive Personal Assistant' 'cybersecurity engineer'
#  'Linux infrastructuur engineer' 'Software Support Engineer - EMEA'
#  'Security Specialist' 'security analist - Digital Intrusion Team'
#  'fullstack developer' 'legal hacker - Digital Intrusion Team'
#  'DevOps engineer' 'Lead IT Operations met auto van de zaak!'
#  'Data Engineer traineeship' 'netwerkspecialist Speciaal Beheer Team'
#  'Trainee CAD, GIS en Geo-ICT'
#  'vulnerability reseacher - Digital Intrusion Team'
#  'Medewerker Engineering' 'Engineer Ondergrondse Infratechniek'
#  'ICT informatieanalist' 'Kwaliteitsmedewerker'
#  'Energy Finance Business Partner Europe'
#  'senior ICT-beheerder - Speciaal Beheerteam' 'Full Stack Developer'
#  'Data Science traineeship' 'Test Engineer Product Development'
#  'senior Windows specialist - Speciaal Beheer Team'
#  'technisch beheerder operations control room'
#  'Software Engineer Product Development' 'Quantity Surveyor'
#  'Duaal leertraject hbo ICT (regulier en versneld)'
#  'solution architect oracle linux' 'Senior Software Developer'
#  'Senior Sales Person' 'Solutions Engineer – C&C CoE'
#  'Portuguese speaking 1st Line IT Sales/Support Engineer'
#  'Starter ICT - Riante oplopende €300 bonus per maand'
#  'Manager IT Operations (Wasco)' 'Helicopter Engineer AW-139'
#  'Junior IT support engineer' 'Logistic Engineer' 'Medewerker logistiek'
#  'Cloud Engineer' 'Senior Mechanical Engineer'
#  'Data Modeling Engineer Freelance'
#  'Identity Infrastructure Administrator' 'Full Stack Software Engineer'
#  'Azure Cloud Engineer bij Movir' 'Junior Servicedesk Engineer'
#  'Data engineer'
#  'Engineering Manager NN Customer & Commerce – CIAM and API platform'
#  'Full Stack Engineer at NN Bank' 'Senior Netwerk Engineer'
#  'Engineer DevOps and SRE practices' 'Junior System Engineer'
#  'Data Center Technician Apprentice, September 2023 Start'
#  'Engineering Manager NN Customer & Commerce – Salesforce Team'
#  'DevOps Engineer Regulatory Reporting' 'Devops Engineer'
#  'Oracle DBA Consultant' 'OPS Engineer Global Data Centre'
#  'Junior Data Support' 'Junior Big Data Engineer'
#  'Consultant Data Engineering' 'ICT trainee - Java developer'
#  'Senior Data Engineer Klantinteractie' 'Junior data engineer'
#  'Data Engineer Business Intelligence' 'Logistics Engineer'
#  'Junior Data Engineer - YEPP' 'Data Engineer (junior)'
#  'Data Engineer (Amsterdam)' 'Junior Data Maverick'
#  '(Junior) Data Engineer' 'Hardware/embedded Test Engineer'
#  'Senior Data Engineer - PySpark, AWS' 'Engineer Data Publishing'
#  'SENIOR AUTHORISED PERSON'
#  'Data Engineer(Netherlands, Valid work Permit)'
#  'Data Engineer - DataSense' 'Data Engineer DataStage'
#  'Junior Data Engineer' 'Cloud Data Engineer - Agiliz'
#  'Azure data-engineer' 'Robotics Engineer (All levels)'
#  'Data engineer toezicht, bezwaar en klantinteractie'
#  'Data Processing Engineer' 'Systeem Data Engineer'
#  'Data warehouse Engineer' 'Data analist (PowerBI / Python / SQL)'
#  'Trainee Data Engineer Consultant' 'ICT trainee - DevOps engineer'
#  'Junior Data Scientist / Scientific Software Developer'
#  'Data Engineer Product Development (ENG)' 'Azure Data Engineer'
#  'Data Center Engineer' 'Data Science Engineer' 'Big Data Engineer'
#  'Data Analytics Engineer' 'ICT trainee - .NET developer'
#  'Cost Data Engineer' 'Traineeship Analytics - October 2023'
#  'Senior Front-end developer' 'Support Engineer'
#  'Junior Datacenter Facility Technician (startersfunctie)']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_NL, specializations_FRI],
        [data_terms_NL, data_terms_FRI]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 46 :
# ['Senior AWS Cloud Engineer' 'Data Engineer'
#  'Data Engineering stagiair(e)'
#  'Data Engineer Nivel Zorgregistraties Eerste Lijn'
#  'Engineer infrastructuur Binnenkabels' 'Analytics Engineer'
#  'Operationeel/Technisch netwerk monitoring specialist'
#  'Parttime PowerBI Developer (16-32 uur)' 'Senior Database Specialist'
#  'lead engineer cloud & big data' 'Data Engineer traineeship'
#  'Cloud Engineer' 'Data Modeling Engineer Freelance'
#  'Azure Cloud Engineer bij Movir' 'Data engineer'
#  'OPS Engineer Global Data Centre' 'Junior Big Data Engineer'
#  'Consultant Data Engineering' 'Senior Data Engineer Klantinteractie'
#  'Junior data engineer' 'Data Engineer Business Intelligence'
#  'Junior Data Engineer - YEPP' 'Data Engineer (junior)'
#  'Data Engineer (Amsterdam)' '(Junior) Data Engineer'
#  'Senior Data Engineer - PySpark, AWS' 'Engineer Data Publishing'
#  'Data Engineer(Netherlands, Valid work Permit)'
#  'Data Engineer - DataSense' 'Data Engineer DataStage'
#  'Junior Data Engineer' 'Cloud Data Engineer - Agiliz'
#  'Azure data-engineer'
#  'Data engineer toezicht, bezwaar en klantinteractie'
#  'Data Processing Engineer' 'Systeem Data Engineer'
#  'Data warehouse Engineer' 'Trainee Data Engineer Consultant'
#  'Junior Data Scientist / Scientific Software Developer'
#  'Data Engineer Product Development (ENG)' 'Azure Data Engineer'
#  'Data Center Engineer' 'Data Science Engineer' 'Big Data Engineer'
#  'Data Analytics Engineer' 'Cost Data Engineer']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.13 Norway

# %%
selector = 'Norway'

specializations_NO = ["Ingeniør", "Konsulent", "arkitekt", "SPECIALIST", "Manager", "Utvikler", "Arkitektur", "Administrator"]
data_terms_NO = ["Data", "ETL", "Sky", "Analytisk", "Analytics", "BI", "Forretningsinnsikt", "Forretningsanalyse", "Database", "Pipeline", "Metadata", "Overvåking", "Databehandlingssenter"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 278 :
# [nan 'Contracts Officer (Based in Germany)'
#  'Cloud Services Engineer (Based in Germany)' 'Data Engineer'
#  'Data Engineer - Google Cloud' 'Data Engineer (m/f/d)'
#  'Sommerjobb for data scientists / data engineers — Oslo'
#  'EICT package engineer' 'Løsningsarkitekt Analytics / Data Engineer'
#  'Data Engineer – Java Developer' 'Customer Support Engineer (All Levels)'
#  'Mechanical Package Engineer'
#  'Data Engineer | NorgesGruppen | Skøyen, Oslo' 'DATA ENGINEER'
#  'Senior Full Stack Engineer GIS (remote)' 'Drilling Engineer'
#  'Software Engineer (Oslo) - Experian Marketing Services'
#  'We are looking for a Data Engineer' 'Field Service Engineer (m/f/d)'
#  'Data Engineer med erfaring fra Azure?' 'Project Engineer'
#  'Azure Data Engineer with DataBricks - Oslo'
#  'Forward-deployed Data Engineer' 'Senior Completion Engineer'
#  'Software Engineer - Frontend' 'Data Engineer - Oslo'
#  'Elsker du data og analyser? Vi også.' 'Operational Technology Engineer'
#  'Principal Software Engineer'
#  'Data Engineers, Scientists, Analysts - Oslo' 'Data/ML Engineer'
#  'Infrastructure Engineer | SWIFT' 'Field Support Engineer'
#  'Process Engineer' 'Senior Big Data Engineer'
#  'Technical Sales Engineer - Summer internship (Norway)'
#  'Data Scientist Biodiversity Informatics'
#  'Riverty is looking for a new Data Engineering Lead'
#  'Data Engineer (Azure) - Oslo' 'Software Support Engineer'
#  'Integration Engineer - Cloud Solutions to Ericsson in Fornebu Oslo.'
#  'Senior Software Engineer' 'MAC Engineer (Freelancer)'
#  'Data Engineer - ETL - Finance Industry' 'Field Engineer Norway'
#  'Machine Learning / Software Engineer' '(Senior) Data Engineer - Azure'
#  'IT Support Engineer – Oslo / Sandefjord' 'System Engineer Network'
#  'Senior Cloud Security Engineer | Völur | Oslo'
#  'ICT Engineer / ICT Technician'
#  'System Engineer Storage and Data Protection'
#  'Specialist Engineer - Survey' 'Machine-Learning Automation Engineer'
#  'Data Scientist' 'Head of Data & Analytics - Oslo'
#  'Software Engineer - App Stores Backend (Remote)'
#  'Technologist – Process Engineer' 'Field Support Engineer DC Oslo'
#  'Application Engineer' 'Machine Learning Engineer'
#  'Join us in creating the best user journey from cart to delivery!'
#  'Lead Partner Technology Strategist - Norway'
#  'Applications Engineering Intern' 'Software Engineer - Data Platform'
#  'Technologist – Simulation/digitalization' 'Quality Engineer'
#  'DevOps Engineer' 'Forward-deployed Lead Data Engineer'
#  'AI Security Engineer' 'IT Operations Cloud Engineer'
#  'Senior Software Engineer - Sandefjord' 'Technical Support Engineer'
#  'AI/HPC System Engineer' 'Network Consulting Engineer'
#  'IT Support Technician' 'Lead Controls Engineer | Shearwater | Oslo'
#  'Senior Process Engineer – Cell Assembly & Formation (Norway)'
#  'WARRANTY ENGINEER - OSLO TRAM'
#  'Graduate Cloud Native Platform Engineer - Norway'
#  'Senior DevOps Engineer'
#  'Golang System Software Engineer - Containers / Virtualisation'
#  'Integration Engineer - Cloud Solutions' 'Analytics Engineer'
#  'Graduate Product Engineer/Designer'
#  'Integrated Operations Specialist Engineer'
#  'Senior Software Engineer - Digital Workplace'
#  'Principal Software Engineer - Oslo' 'Machine Learning Ops Engineer'
#  'Senior Data Engineer'
#  'Customer Success Manager - Enterprise Data Solutions'
#  'Software Engineer - Launchpad'
#  'Software Engineer - Micro/Private/Bare-Metal Cloud'
#  'Go Software Engineer, Commercial Systems' 'ASIC Engineer, Design'
#  'NORDIC AVANADE TRAINEE PROGRAM 2023 – Software Engineering – Avanade Norway'
#  'Senior Engineer Telecom' 'Lead Software Engineer, Global Bill Pay'
#  'Backend Software Engineer' 'Software Engineer'
#  'Senior Software Engineer (Oslo) - Experian Marketing Services'
#  'Cloud Engineer' 'AME/Skilled Worker' 'Senior Software Engineer - Telco'
#  'Senior Systems Engineer (Windows)' 'Senior Cloud Engineer'
#  'System Engineer - Dynamic Positioning' 'Embedded Software Engineer'
#  'Cyber Security Control System Engineer'
#  'Project Engineer, Integrated Project Support'
#  'Graduate Subsea System Engineer' 'Senior Backend Engineer'
#  'Senior Mechanical Engineer - Rotating Equipment'
#  'Senior Engineer Telecommunication' 'Senior Frontend Engineer'
#  'Control System Engineer (Stavanger)'
#  'Utviklere med datavarehuserfaring — Oslo og Trondheim'
#  'Senior Software Engineer - Java' 'Software Engineer - People Manager'
#  'Dataingeniør' 'ASIC Engineer, Design Verification'
#  'Senior Eletrical Engineer' 'Senior Engineer SURF Asset Integrity'
#  'Senior Hydrodynamic Engineer'
#  'Software & GUI-Engineer | Eidsvoll Electronics | Eidsvoll...'
#  'Critical Environment Program Manager (CEFSE)' 'Software Engineer - MAAS'
#  'CloudOps Engineer' 'Sr. Technical Delivery Engineer'
#  'Senior Systems Engineer' 'Quality Assurance Engineer'
#  'Senior Drilling Engineer' 'Senior/Principal Software Engineer'
#  'Senior DevOps Engineer for exciting AI company'
#  '(Senior) Robotics Field Service Engineer'
#  'Data Engineer til et viktig oppdrag hos en tung statlig...'
#  'We are looking for Power BI experts in Oslo!'
#  'Validation/Characterization Engineering Intern' 'Test Engineer'
#  'Senior Digital Design Engineer' 'HVAC Technician | AIDA Cruises'
#  'Linux System Engineer - QA, Tooling, Automation' 'Automation Engineer'
#  'Client Relationship & Technical Lead'
#  'Senior Observability Platform Developer - Python/Go'
#  'Senior Maintenance & Operability Engineer'
#  'Maritime Autonomous Vessel Engineer' 'Full Stack Software Engineer'
#  'Embedded & Desktop Linux Software Engineer - Optimisation'
#  'Data Engineer som vil være med å bygge opp vår satsning innen Data og Machine Learning!'
#  'Norconsult satser ytterligere på digitalisering; Nå vil vi satse på deg som er interessert i maskinlæring og data science!'
#  'Senior Process Engineer – Cell Manufacturing (Norway)'
#  'Senior Solution Engineer'
#  'Senior Quality Assurance Engineer – Automation'
#  'Senior Instrument Engineer' 'Saving more lives together'
#  'Mechanical Construction Manager - NORWAY' 'Utvikler AI/ML'
#  'Field Service Engineer - Industrial Control & Safety (SAS) systems'
#  'Core Network Engineer'
#  'Engineer/Senior Engineer Drilling And Well Operations'
#  'Test Automation Engineer' 'Project Manager / Solution Consultant'
#  'Subsea Ingeniør' 'Controls Engineer (Stavanger)'
#  'Er du en rev på Azure?'
#  'ETRM/CTRM Software Developer (MS SQL and C#.Net)' 'Completion Engineer'
#  'Database Reliability Engineer - ElasticSearch'
#  'Drilling Equipment Integrity Engineer'
#  'Critical Services Day Technician / Critical Facilities Day Technician - Data Center'
#  'Aerospace Advisor - Manufacturing / Quality Engineer'
#  'On behalf of one of our clients, we are looking for Drilling Equipment Integrity Engineer'
#  'Join OMV Norge AS for your new adventure'
#  'Vil du jobbe som IT utvikler hos oss?'
#  'Project Engineer, Product Life Support'
#  'Embedded Software Engineer, Industrial Field Protocols'
#  'Software Developer Full-Stack' 'Hydrodynamic Engineer'
#  'Database Reliability Engineer (DBRE) - golang'
#  'Data Center Services Manager / Critical Facility Services Manager'
#  'Systems (Presales) Engineer' 'Senior Automation Engineer'
#  'Principle Engineer Automation' '2. Engineer | Carnival Cruise Line'
#  'HVAC Engineer (Technician) | Costa' 'Welding Engineer'
#  'Senior SAS Engineer' 'Engineer - Python - Bergen'
#  'Managed Services Pre-Sales Engineer'
#  'Technologist - Simulation/Digitalization'
#  'Bli med å bygge vår videre satsing innen Business Analytics'
#  'Senior Instrument Engineer, SAS' 'Business Intelligence - Bergen'
#  'Subsea Lead Engineer' 'SALES ENGINEER/MANAGER'
#  'Senior Engineer/ Senior Specialist Engineer'
#  'Capacity Manager - Data Center Mobilization / Data Center Capacity Manager'
#  'Piping Field Engineer' 'Principle Engineer Electrical'
#  'Business Intelligence Consultant' 'Lead Software Engineer'
#  'Senior Software Engineer - Embedded & Desktop Linux Optimisation'
#  'Machine Learning Engineer - Oslo' 'Senior Piping Designer Engineer'
#  'Electronics/ElectricalTechnician'
#  'Har du erfaring innen DFO/LCI og dokumentkontroll?'
#  'Senior Specialist Material Engineer'
#  'Data Center Technician / Critical Services Technician - Data Center (all genders)'
#  'Junior Developer - Bergen' 'Data Architect - Oslo'
#  'Data Center Manager / Critical Facility Services Manager (all genders)'
#  'Surveying Engineer / Landmåler'
#  "Want to play a key role in developing one of Norway's most used Apps?"
#  'Senior Cloud Security Engineer' 'Piping Engineer MTO'
#  'Senior Electrical Engineer' 'DevOps/CloudOps Engineer'
#  'Senior Software Architect, Commercial Systems'
#  'Vi du jobbe som utvikler hos oss' 'Data Engineering Manager - Oslo'
#  'Completion Engineer - 24497' 'Senior Package Responsible Engineer'
#  'Senior Instrument Engineer - Metering' 'Software Developer - Bergen'
#  'On behalf of one of our clients, we are looking for Principal Engineer Electrical - Systems'
#  'Rental Coordinator / Tool Pool Coordinator'
#  'Vil du være med på å utvikle vedlikeholdsstrategien til Nordens største hurtigladenettverk for elbil?'
#  'Azure Data Architect' 'Principal Engineer Electrical - Systems'
#  'Senior Salesforce Engineer, Commercial Systems'
#  'Wind CMS/Drivetrain Specialist' 'Senior Front-end Engineer'
#  'Critical Services Shift Technician'
#  'Critical Services Shift Technician / Critical Facilities Shift Technician - Data Center'
#  'Critical Services Day Technician'
#  'Senior Web Developer - Workplace Engineering'
#  'Developer for a Modern Data Platform - Oslo' 'BI Developer - Oslo'
#  'Critical Services Day Lead' 'Global Head of Finance Services Sales'
#  'Vil du være med å skape et tryggere Norge - ved hjelp av tekniske verktøy? PST søker teknologer og analytikere!'
#  'Critical Services Day Lead / Critical Facilities Day Lead / Teamleader Critical Services - Data Center'
#  'Lead DevOps' 'Senior EIT Area Engineer'
#  'Spennende nøkkelrolle med ansvar for implementering og dokumentasjon av produktoppdatering og forbedringer'
#  '(Remote)MBD Principal Engineer' 'Lead Electrical Engineer'
#  'Electrical Engineer' 'Lead Software Developer - Oslo'
#  'Senior Weight Engineer' 'Instrument - 24539'
#  'Senior Eletrical Engineer - 24685' 'Senior SAS Engineer - 24568'
#  'UX Engineer til ABAX Norge'
#  'Senior Process Engineer – Powder & Slurry (Norway)'
#  'Site Reliability Engineer'
#  'We are looking for a Principal Electrical Engineer.'
#  'Senior Fullstack Engineer' 'Senior Engineer Telecom - Offshore Wind'
#  'Principal Engineer Electrical – Systems, Required Location: Asker - 24829'
#  'Join us and be a catalyst for change by bringing unique perspectives to the table!'
#  'Senior ML Engineer' 'System Integration consultant'
#  'Engineering for Procurement Engineer - 24717'
#  'Senior Engineer Electrical' 'Software Engineer, Commercial Systems'
#  'GSI Partner Sales Director' 'OpenGL / C++ Video Engineer'
#  'OEM Partner Sales Director' 'Senior Software Engineer - MAAS'
#  'Senior Eng Automation - 24506'
#  'Mechanical engineer (static equipment) - 24731'
#  'Chief Cloud Architect som vil være med å bygge opp vår skysatsing?'
#  'Senior Account Executive' 'Business Intelligence Manager - Oslo'
#  'Piping Engineer Work Orders - 24764'
#  'Senior Engineer Quantity Measurement (Qty surveyor)']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_NL, specializations_FRI],
        [data_terms_NL, data_terms_FRI]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 59 :
# ['Cloud Services Engineer (Based in Germany)' 'Data Engineer'
#  'Data Engineer - Google Cloud' 'Data Engineer (m/f/d)'
#  'Sommerjobb for data scientists / data engineers — Oslo'
#  'Løsningsarkitekt Analytics / Data Engineer'
#  'Data Engineer – Java Developer'
#  'Data Engineer | NorgesGruppen | Skøyen, Oslo' 'DATA ENGINEER'
#  'We are looking for a Data Engineer'
#  'Data Engineer med erfaring fra Azure?'
#  'Azure Data Engineer with DataBricks - Oslo'
#  'Forward-deployed Data Engineer' 'Data Engineer - Oslo'
#  'Data Engineers, Scientists, Analysts - Oslo' 'Data/ML Engineer'
#  'Senior Big Data Engineer'
#  'Riverty is looking for a new Data Engineering Lead'
#  'Data Engineer (Azure) - Oslo'
#  'Integration Engineer - Cloud Solutions to Ericsson in Fornebu Oslo.'
#  'Data Engineer - ETL - Finance Industry' '(Senior) Data Engineer - Azure'
#  'Senior Cloud Security Engineer | Völur | Oslo'
#  'System Engineer Storage and Data Protection'
#  'Head of Data & Analytics - Oslo' 'Software Engineer - Data Platform'
#  'Forward-deployed Lead Data Engineer' 'IT Operations Cloud Engineer'
#  'Graduate Cloud Native Platform Engineer - Norway'
#  'Integration Engineer - Cloud Solutions' 'Analytics Engineer'
#  'Senior Data Engineer'
#  'Customer Success Manager - Enterprise Data Solutions'
#  'Software Engineer - Micro/Private/Bare-Metal Cloud'
#  'Lead Software Engineer, Global Bill Pay' 'Cloud Engineer'
#  'Senior Cloud Engineer' 'CloudOps Engineer'
#  'Data Engineer til et viktig oppdrag hos en tung statlig...'
#  'Senior Observability Platform Developer - Python/Go'
#  'Senior Maintenance & Operability Engineer'
#  'Data Engineer som vil være med å bygge opp vår satsning innen Data og Machine Learning!'
#  'Database Reliability Engineer - ElasticSearch'
#  'Database Reliability Engineer (DBRE) - golang'
#  'Data Center Services Manager / Critical Facility Services Manager'
#  'Capacity Manager - Data Center Mobilization / Data Center Capacity Manager'
#  'Business Intelligence Consultant' 'Data Architect - Oslo'
#  'Data Center Manager / Critical Facility Services Manager (all genders)'
#  'Senior Cloud Security Engineer' 'DevOps/CloudOps Engineer'
#  'Data Engineering Manager - Oslo' 'Azure Data Architect'
#  'Developer for a Modern Data Platform - Oslo' 'BI Developer - Oslo'
#  'Critical Services Day Lead / Critical Facilities Day Lead / Teamleader Critical Services - Data Center'
#  'Site Reliability Engineer'
#  'Chief Cloud Architect som vil være med å bygge opp vår skysatsing?'
#  'Business Intelligence Manager - Oslo']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.14 Poland

# %%
selector = 'Poland'

specializations_PL = ["Inżynier", "Konsultant", "Architekt", "Specjalista", "Manager", "Programista", "Administrator"]

data_terms_PL = ["Dane", "ETL", "Chmura", "Analityczny", "Analityka", "BI", "Business Intelligence", "Analityka Biznesowa", "Bazy Danych", "Pipeline", "Metadane", "Monitorowanie", "Centrum Danych"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 102 :
# ['Technical Reporting & Compliance Lead'
#  'Controls Engineer Senior Associate' 'Electro Mechanical Design Engineer'
#  'Cloud Services Engineer (Based in Germany)'
#  'Contracts Officer (Based in Germany)'
#  'Senior Technical Support Engineer (PL/SQL and Unix)'
#  'Software QA Test Engineer'
#  'Software Engineer Intern - Frontend/Fullstack'
#  'UI Engineer (L4/L5) - Content Engineering'
#  'Crypto Data Engineer Intern (Remote)'
#  'Junior Data Engineer - Data & Analytics' 'Software Engineer Intern'
#  'Intern Data Engineer' 'Scientific Research Intern'
#  'Automation Project Engineer'
#  'Remote Customer Service Representative - English Speaking'
#  'Junior data engineer (Talent Program)' 'AI Engineer/Data Engineer'
#  'Data/Machine Learning Engineer' 'Junior Cloud Data Platform Engineer'
#  'Data Engineer - QuantumBlack'
#  'Data Scientist - Machine Learning Engineer'
#  'Junior/Mid Data Engineer (Biotech)' 'Data Engineer (DWH) (m/f/d)'
#  'Data Engineer in Technology Consulting' 'Summer Internship Program'
#  'BI Data Engineer' 'Data Engineer'
#  'Intern - Quantitative Analyst or Data Engineer at RiskHub Warsaw (Risk Hub Summer Internship Programme)'
#  'Staff Data Visualization Engineer' 'Data Engineer, Analytics'
#  'Reservoir Engineer - Junior Data Analyst' 'Data Engineer Intern'
#  'Big Data Summit 2023' 'Data Scientist / Machine Learning Engineer'
#  'NLP Intern' 'DATA ENGINEER'
#  'Junior Data Engineer - Data & Analytics Engineering Development Program'
#  'Data Analyst/Engineer Internship' 'Site Engineer Poland'
#  'Intern - Machine Learning' 'Associate Software Engineer'
#  'Machine Learning Software Engineer / Data Scientist'
#  '2023 Software Development Engineer Internship'
#  'Junior DWH Data Engineer (get the DWH skill)'
#  'Senior Electrical Service Engineer'
#  'Data Engineer for Machine Learning in Computer Vision (Robotics)'
#  'Virtual Desktop Engineer' 'Software Intern'
#  'Mechanical Engineer Internship' 'Software Intern (summer internship)'
#  'Junior Data Analyst' 'Associate Software Engineer (DevOps)'
#  'Threat Detection Engineer' 'Technical Writer & Copywriter'
#  'Forward-deployed Data Engineer' nan 'Data Infrastructure Engineer'
#  'Data Engineer AWS' 'D&I Data Engineer'
#  'Principal Backend Software Engineer - Data Center Platform team'
#  'Big Data Engineer (Retailer)' 'Process Data Engineer - Wells'
#  'Celonis & Salesforce Data Analyst' 'Data engineer'
#  'Data Analysis Engineer'
#  'Data Platform Engineer - Data Analytics Platform'
#  'JUNIOR INTEGRATION & DATA ENGINEER' 'Data Platform Engineer - Datalake'
#  'Senior Machine Learning Engineer/Data Scientist'
#  'Junior Backend Engineer' 'AWS Data Engineer' 'Data Engineer Oracle'
#  'Full Stack Developer' 'Cyber Security Data Engineer (Data Scientist)'
#  'Data Scientist' 'Intermediate Data Engineer'
#  'Gas Turbine Mechanical-Design Engineer' 'Data Analytics Engineer'
#  'Machine Learning Engineer'
#  'APPLICATION SUPPORT AND MAINTENANCE SERVICE AGENT'
#  'Machine Learning Engineer/Data Engineer (m/f/d)'
#  'Data Scientist - QuantumBlack' 'Junior Account Manager'
#  'Data Engineer (REGULAR)' 'Machine Learning Ops Engineer'
#  'RF Design Engineer Intern' 'Intern Python Software Engineer'
#  'Junior Database Engineer' 'Data Engineer (Power BI Developer)'
#  'Azure Data Engineer' 'Junior Quantitative Developer'
#  'Senior Data Engineer' 'Junior Mechanical Engineer (MFC / Data Centres)'
#  'Python Data Engineer' 'Junior Researcher'
#  'Software Developer Summer Intern' 'Head of Services&Solutions'
#  'Big Data Engineer (Scala, Spark)' 'Junior Localization Engineer'
#  'Network Junior Engineer' 'Data Engineer (BI)']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_NL, specializations_FRI],
        [data_terms_NL, data_terms_FRI]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 54 :
# ['Cloud Services Engineer (Based in Germany)'
#  'Crypto Data Engineer Intern (Remote)'
#  'Junior Data Engineer - Data & Analytics' 'Intern Data Engineer'
#  'Junior data engineer (Talent Program)' 'AI Engineer/Data Engineer'
#  'Data/Machine Learning Engineer' 'Junior Cloud Data Platform Engineer'
#  'Data Engineer - QuantumBlack'
#  'Data Scientist - Machine Learning Engineer'
#  'Junior/Mid Data Engineer (Biotech)' 'Data Engineer (DWH) (m/f/d)'
#  'Data Engineer in Technology Consulting' 'BI Data Engineer'
#  'Data Engineer'
#  'Intern - Quantitative Analyst or Data Engineer at RiskHub Warsaw (Risk Hub Summer Internship Programme)'
#  'Staff Data Visualization Engineer' 'Data Engineer, Analytics'
#  'Reservoir Engineer - Junior Data Analyst' 'Data Engineer Intern'
#  'Data Scientist / Machine Learning Engineer' 'DATA ENGINEER'
#  'Junior Data Engineer - Data & Analytics Engineering Development Program'
#  'Data Analyst/Engineer Internship'
#  'Machine Learning Software Engineer / Data Scientist'
#  'Junior DWH Data Engineer (get the DWH skill)'
#  'Data Engineer for Machine Learning in Computer Vision (Robotics)'
#  'Forward-deployed Data Engineer' 'Data Infrastructure Engineer'
#  'Data Engineer AWS' 'D&I Data Engineer'
#  'Principal Backend Software Engineer - Data Center Platform team'
#  'Big Data Engineer (Retailer)' 'Process Data Engineer - Wells'
#  'Data engineer' 'Data Analysis Engineer'
#  'Data Platform Engineer - Data Analytics Platform'
#  'JUNIOR INTEGRATION & DATA ENGINEER' 'Data Platform Engineer - Datalake'
#  'Senior Machine Learning Engineer/Data Scientist' 'AWS Data Engineer'
#  'Data Engineer Oracle' 'Cyber Security Data Engineer (Data Scientist)'
#  'Intermediate Data Engineer' 'Data Analytics Engineer'
#  'Machine Learning Engineer/Data Engineer (m/f/d)'
#  'Data Engineer (REGULAR)' 'Junior Database Engineer'
#  'Data Engineer (Power BI Developer)' 'Azure Data Engineer'
#  'Senior Data Engineer' 'Python Data Engineer'
#  'Big Data Engineer (Scala, Spark)' 'Data Engineer (BI)']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.15 Portugal

# %%
selector = 'Portugal'

specializations_PTG= ["Engenheiro", "Consultor", "Arquiteto", "Especialista", "Gerente", "Desenvolvedor", "Arquitetura", "Administrador"]

data_terms_PTG = ["Dados", "ETL", "Nuvem", "Analítico", "Análise", "BI", "Inteligência de Negócios", "Análise de Negócios", "Banco de Dados", "Pipeline", "Metadados", "Monitoramento", "Centro de Dados"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 127 :
# ['Full Stack Developer' 'SQL Engineer' 'Ingestion Data Engineer (f/m/d)'
#  'Software Integration Engineers' 'Ingestion Senior Data Engineer (f/m/d)'
#  'Data Engineer' 'Data Engineer Trainee (m/f/d)' 'Senior Data Engineer'
#  'Data Pipeline Engineer' 'Data Engineer - Junior' nan 'DATA ENGINEER'
#  'Release & Code Analyst' 'Data Engineer - Banking Sector'
#  'Associate Data Engineer (M/F/D)' 'Crypto Data Engineer (Remote)'
#  'Lead Data Engineer' 'SQL Data Engineer' 'Project Engineer [Remote]'
#  'Data Scientist (100% remote working)'
#  'Google Cloud Platform Data Engineer'
#  'Data Engineer – Innovation Program' 'Senior Data Engineer (Lisbon)'
#  'Data Engineer - (Viator)' 'Data Engineer (all genders)'
#  'On-Prem Data Engineer' 'Data Engineer | AWS' 'Data Engineer- Lisboa'
#  'Senior Software Engineer (SAP PLM)'
#  'Data Scientist e Machine Learning Engineer' 'Azure Data Engineer'
#  'Data Engineer: Synapse SQL (m/f)' 'Data Engineer II'
#  'Staff Data Engineer (m/f/d)' 'Data Engineer (M/F) – Lisboa'
#  'Data Engineer | Cloud & Big Data' 'Data Software Engineer - Senior'
#  'Big Data Engineer' 'Full-Stack Engineer' 'Data Engineer / BI Developer'
#  'Senior Software Engineer -4'
#  'Full Stack Engineer - Contractor (Remote-EU)'
#  'Data Engineer (Spark/Databricks)' 'Azure Senior Data Engineer'
#  'Senior Data Engineer (all genders)'
#  'Data Engineer - LatAm, Western or Eastern Europe'
#  'Senior Big Data Engineer (m/f/*)'
#  'Data Engineer - Customer Service Data Platform'
#  'Senior Data Engineer (m/f/d)' 'Senior Software Engineer'
#  'Senior Software Engineer - Finalta' 'Data Analyst (m/f/d)'
#  'Senior Data Engineer (M/F)' 'Cloud Data Engineer (f/m/d)'
#  'Data Engineer (m/f)' 'Sr Data Engineer' 'Full-Stack Developer'
#  'Data-Engineer' 'GDC Process Mining Data Engineer (m/f/d)'
#  'DATA ENGINEER (M/F)' 'Junior Software Engineer'
#  'Full Stack Software Engineer'
#  'Angular Frontend Engineer - Contractor (Remote-EU)'
#  'Frontend Software Developer' 'Security Operations Engineer'
#  'SENIOR DATA ENGINEER' 'Backend Software Developer'
#  'Junior Data Engineer' 'SQL Data Engineer (f/m/d)'
#  'Junior Data Engineer/Analyst' 'Data and Algorithm Development Engineer'
#  'Software Engineer'
#  'Data Engineer: Databricks e Datafactory - Lisboa/Híbrido'
#  'Data Analytics Technology Lead' 'Data Scientist' 'Front End Developer'
#  'Software Engineer III'
#  'Data Engineer - Mid/Senior (Remoto / Híbrido Portugal)'
#  'Hardware Engineer (f/m/d)' 'Environmental Engineer - LCA Expert (m/f/d)'
#  'Full Stack Engineer' 'Data Engineer (m/f/d)' 'Staff Data Engineer'
#  'Aptiv.io - Data Engineer - Remote'
#  'AWS Data Science Operations Engineer (Fresh Graduate)'
#  'Senior Full Stack Engineer' 'Software Engineer - Frontend'
#  'Senior Data Engineer (Portugal)' 'PMDS Data Engineer Service (m/f)'
#  'Full Stack (Node.js + React.js) Engineer'
#  'Data Engineer Manager (Azure) - Europe West Lisbon Tech Hub'
#  'Backend Software Engineer (Remote) – LatAm Team'
#  'Technical Support Engineer (Remote/Hybrid)' 'Software Engineer Manager'
#  'Senior Data Engineer (m/f)' 'DATA ENGINEER - EMEA/REMOTE (Portugal)'
#  'Data Scientist - Artificial Intelligence' 'Senior Developer'
#  'IoT Specialist Data Engineer' 'SQL Data Engineer – Porto (M/F)'
#  'Data Integration Engineer'
#  'Senior Backend Software Engineer - AWS / APIs / Databases / Home Office (m/f/d)'
#  'Full Stack Data Engineer' 'Software Engineer - Backend'
#  'Data Science Mastermind' 'Backend Software Engineer'
#  'Data Analyst/Engineer (m/f) - Porto (Hybrid)'
#  'Software Engineer - App Stores Backend (Remote)'
#  'Senior Back End Software Engineer'
#  'Backend Software Engineer C# / F# (Remote PT)' 'Data Engineer - CARAT'
#  'Senior Software Engineer - Full remote working'
#  'Backend Developer & Operation Engineer'
#  'Senior Data Engineer and Analyst' 'DATA ARCHITECT (M/F)'
#  'IT Operations Professional / DevOps Engineer (m/f/d)'
#  'Machine Learning Engineer (m/f/d)'
#  'Senior Data Engineer (m/f) - hybrid | Porto'
#  'Senior Backend Software Engineer'
#  'IMPLEMENTATION ENGINEER - DATA CENTER AND MULTI CLOUD (M/F/D)'
#  'Junior .NET developer (m/f)'
#  'Test & Commissioning Engineer - Trainee (Porto) M/F'
#  'Software Engineer, Data Architecture' 'Software Engineer (SAP PLM)'
#  'SAP ABAP Software Engineer (m/f/d)'
#  'Junior Data Engineer - Lisbou ou Porto/Híbrido'
#  'Software Developer Trainee']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_NL, specializations_FRI],
        [data_terms_NL, data_terms_FRI]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 75 :
# ['Ingestion Data Engineer (f/m/d)'
#  'Ingestion Senior Data Engineer (f/m/d)' 'Data Engineer'
#  'Data Engineer Trainee (m/f/d)' 'Senior Data Engineer'
#  'Data Pipeline Engineer' 'Data Engineer - Junior' 'DATA ENGINEER'
#  'Data Engineer - Banking Sector' 'Associate Data Engineer (M/F/D)'
#  'Crypto Data Engineer (Remote)' 'Lead Data Engineer' 'SQL Data Engineer'
#  'Google Cloud Platform Data Engineer'
#  'Data Engineer – Innovation Program' 'Senior Data Engineer (Lisbon)'
#  'Data Engineer - (Viator)' 'Data Engineer (all genders)'
#  'On-Prem Data Engineer' 'Data Engineer | AWS' 'Data Engineer- Lisboa'
#  'Data Scientist e Machine Learning Engineer' 'Azure Data Engineer'
#  'Data Engineer: Synapse SQL (m/f)' 'Data Engineer II'
#  'Staff Data Engineer (m/f/d)' 'Data Engineer (M/F) – Lisboa'
#  'Data Engineer | Cloud & Big Data' 'Data Software Engineer - Senior'
#  'Big Data Engineer' 'Data Engineer / BI Developer'
#  'Data Engineer (Spark/Databricks)' 'Azure Senior Data Engineer'
#  'Senior Data Engineer (all genders)'
#  'Data Engineer - LatAm, Western or Eastern Europe'
#  'Senior Big Data Engineer (m/f/*)'
#  'Data Engineer - Customer Service Data Platform'
#  'Senior Data Engineer (m/f/d)' 'Senior Data Engineer (M/F)'
#  'Cloud Data Engineer (f/m/d)' 'Data Engineer (m/f)' 'Sr Data Engineer'
#  'Data-Engineer' 'GDC Process Mining Data Engineer (m/f/d)'
#  'DATA ENGINEER (M/F)' 'SENIOR DATA ENGINEER' 'Junior Data Engineer'
#  'SQL Data Engineer (f/m/d)' 'Junior Data Engineer/Analyst'
#  'Data and Algorithm Development Engineer'
#  'Data Engineer: Databricks e Datafactory - Lisboa/Híbrido'
#  'Data Analytics Technology Lead'
#  'Data Engineer - Mid/Senior (Remoto / Híbrido Portugal)'
#  'Data Engineer (m/f/d)' 'Staff Data Engineer'
#  'Aptiv.io - Data Engineer - Remote'
#  'AWS Data Science Operations Engineer (Fresh Graduate)'
#  'Senior Data Engineer (Portugal)' 'PMDS Data Engineer Service (m/f)'
#  'Data Engineer Manager (Azure) - Europe West Lisbon Tech Hub'
#  'Senior Data Engineer (m/f)' 'DATA ENGINEER - EMEA/REMOTE (Portugal)'
#  'IoT Specialist Data Engineer' 'SQL Data Engineer – Porto (M/F)'
#  'Data Integration Engineer'
#  'Senior Backend Software Engineer - AWS / APIs / Databases / Home Office (m/f/d)'
#  'Full Stack Data Engineer' 'Data Analyst/Engineer (m/f) - Porto (Hybrid)'
#  'Data Engineer - CARAT' 'Senior Data Engineer and Analyst'
#  'DATA ARCHITECT (M/F)' 'Senior Data Engineer (m/f) - hybrid | Porto'
#  'IMPLEMENTATION ENGINEER - DATA CENTER AND MULTI CLOUD (M/F/D)'
#  'Software Engineer, Data Architecture'
#  'Junior Data Engineer - Lisbou ou Porto/Híbrido']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.16 Romania

# %%
selector = 'Romania'

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 107 :
# ['Data Engineer' 'Supplier Quality Engineer Inspector'
#  'Reliability Engineer' 'Automation engineer' 'Sales Support Engineer'
#  'Software QA Test Engineer' 'Lead Quality Assurance Engineer'
#  'Sr. Backend Software Engineer - Python, Go, OpenSearch a.k.a Elasticsearch, MySQL, AWS (Romania)'
#  'Cloud DevOps Lead Engineer' 'Backend Software Engineer (Remote, ROU)'
#  'IT Lead Test Engineer - Edge Computing'
#  'Cloud Services Engineer (Based in Germany)'
#  'Software Development Engineer in Test (Java) - Sandbox | Romania (Remote)'
#  'Backend Software Engineer (Go, AWS, Cassandra) - Cloud Security (Remote or Hybrid, Romania)'
#  'Data Engineer, Analytics' 'Functional Safety Engineer (m/f/d)'
#  'Software Test Engineer' 'OutSystems Software Engineer'
#  'Frontend Engineer - Partner Data' 'Back-End Software Engineer'
#  'Middle Big Data Engineer'
#  'Internship Data & Access Engineer - PokerStars'
#  'Data Engineer (C#, Python, Elastic)' 'PHP Data Engineer' 'Junior Tester'
#  'Software Development Engineer, SDO Privacy, Data Access, SDO Privacy - AEDU team'
#  'Data Solution Engineer' 'Data Engineer (Google Cloud Platform)'
#  'Data Engineer with Python' 'Technical Support Engineer'
#  'Data Engineer on AWS Cloud'
#  'ETL Engineer|Unite Data Management @ ING Hubs Romania'
#  'Data Platform Engineer |Data Analytics Platform @ING Hubs Romania'
#  'Commissioning Engineer - European Projects' 'Senior Data Engineer'
#  'Site Reliability Engineer'
#  'Tableau/Elastic Search/Hadoop ( Data lake) Engineer for...'
#  'Data Center Infrastructure Engineer Level II' 'Sr Big Data Engineer'
#  'Data Engineer-Big Data' 'Data Engineer (Python)' 'Manual QA Tester'
#  'Python Data Engineer' 'Senior Software Engineer, Data Platform'
#  'Automation Engineer' 'Software Engineer (Python) IRC177750'
#  'Senior Software Engineer (Python)'
#  'Data Center Engineer (On Demand Contract)'
#  'Data Lake Dev-Ops Engineer @ING Hubs Romania'
#  'Site Reliability Engineer | Data Analytics Platform @ING Hubs Romania'
#  'Data Engineer IRC177741' 'Python Software Engineer'
#  'Senior Data Engineer (all genders)' 'Market Data QA Engineer'
#  'Staff Software Engineer, Big Data' 'Data Integration Engineer'
#  'Big Data Engineer' 'Data Visualization Engineer (Power BI)'
#  'Data Mart Engineer @ ING Hubs Romania' 'Data Quality Engineer'
#  'Azure Data Engineer'
#  'Internship - Software Engineering - No longer receiving applications'
#  'DevOps Engineer with AWS' 'Data Engineer (F/M)'
#  'Fixed Data Configuration 2nd Line Engineer'
#  'Big Data Engineer (with Scala and Spark)'
#  'Engineer (m/f/x) - Digital Affluent Proposition' 'NFRM Engineer- AVP'
#  'IPB Agile - L2/RM Support Engineer - Data' 'Infrastructure Engineer'
#  'Big Data Engineer - Kafka & Java'
#  'DevOps Engineer - Data Streaming Service @ING Hubs Romania'
#  'Junior QA Engineers' 'AI / ML Engineer'
#  'Touchpoint Software Engineer – Approval & Consent @ING Hubs Romania'
#  'DevOps Engineer @ING Hubs Romania'
#  'Platform Ops Engineer AP Squad @ING Hubs Romania'
#  'ServiceDesk Engineer @ING Hubs Romania'
#  'Ops Engineer – IPA Ops @ING Hubs Romania-3'
#  'Senior Site Reliability Engineer'
#  'BI Platform Engineer @ING HUBS Romania'
#  'Java Touchpoint Software Engineer - Global Authentication Platform @ING Hubs Romania'
#  'Java Software Engineer - Touchpoint Platform OnePAM 2 @ING Hubs Romania'
#  'Ops Engineer - Touchpoint/Eventbus @ING HUBS Romania'
#  'ING International Talent Programme– IT Track @ING Hubs Romania'
#  'Software Frontend Engineer - TPA Global Authentication Platform @ING Hubs Romania'
#  'Java Development Engineer Touchpoint One Platform @ING Hubs Romania'
#  'DevOps Engineer – STW FM Digitalization @ING Hubs Romania'
#  'DevOps Engineer |Data Lake - Core team @ING Hubs Romania'
#  'Chapter Lead Software Engineer - DBNL Data Management @ING Hubs Romania'
#  'Senior QA Engineer (All Genders)'
#  'Senior Backend Engineer (All Genders)'
#  'Sr. Data Engineer (Hybrid in Romania Only)'
#  'IT Operations Engineer | Capability Squad Summit @ING Hubs Romania'
#  'Senior Python Software Engineer' 'Senior Software Engineer'
#  'DevOps Engineer – FlexING Ops @ING Hubs Romania'
#  'Java/Kotlin Software Engineer Touchpoint Global Authentication @ING Hubs'
#  'Java Software Engineer Financial Markets IPA MI @ING Hubs Romania'
#  'IT Ops Risk Engineer – Broadway@ING Hubs'
#  'Java Software Engineer Touchpoint Global Authentication @ING Hubs'
#  'Senior Software Engineer - Web Services'
#  'Java Development Engineer H2H @ING Hubs Romania'
#  'Chapter Lead Engineer II @ING Hubs Romania'
#  'Senior Software Engineer - Adobe Experience Platform'
#  'Front-end Engineer OneCMS @ING Hubs Romania' nan]

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_ROM, specializations_HU],
        [data_terms_ROM, data_terms_HU]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 51 :
# ['Data Engineer' 'Reliability Engineer' 'Cloud DevOps Lead Engineer'
#  'Cloud Services Engineer (Based in Germany)'
#  'Backend Software Engineer (Go, AWS, Cassandra) - Cloud Security (Remote or Hybrid, Romania)'
#  'Data Engineer, Analytics' 'Frontend Engineer - Partner Data'
#  'Middle Big Data Engineer'
#  'Internship Data & Access Engineer - PokerStars'
#  'Data Engineer (C#, Python, Elastic)' 'PHP Data Engineer'
#  'Software Development Engineer, SDO Privacy, Data Access, SDO Privacy - AEDU team'
#  'Data Solution Engineer' 'Data Engineer (Google Cloud Platform)'
#  'Data Engineer with Python' 'Data Engineer on AWS Cloud'
#  'ETL Engineer|Unite Data Management @ ING Hubs Romania'
#  'Data Platform Engineer |Data Analytics Platform @ING Hubs Romania'
#  'Senior Data Engineer' 'Site Reliability Engineer'
#  'Tableau/Elastic Search/Hadoop ( Data lake) Engineer for...'
#  'Data Center Infrastructure Engineer Level II' 'Sr Big Data Engineer'
#  'Data Engineer-Big Data' 'Data Engineer (Python)' 'Python Data Engineer'
#  'Senior Software Engineer, Data Platform'
#  'Data Center Engineer (On Demand Contract)'
#  'Data Lake Dev-Ops Engineer @ING Hubs Romania'
#  'Site Reliability Engineer | Data Analytics Platform @ING Hubs Romania'
#  'Data Engineer IRC177741' 'Senior Data Engineer (all genders)'
#  'Market Data QA Engineer' 'Staff Software Engineer, Big Data'
#  'Data Integration Engineer' 'Big Data Engineer'
#  'Data Visualization Engineer (Power BI)'
#  'Data Mart Engineer @ ING Hubs Romania' 'Azure Data Engineer'
#  'Data Engineer (F/M)' 'Fixed Data Configuration 2nd Line Engineer'
#  'Big Data Engineer (with Scala and Spark)'
#  'IPB Agile - L2/RM Support Engineer - Data'
#  'Big Data Engineer - Kafka & Java'
#  'DevOps Engineer - Data Streaming Service @ING Hubs Romania'
#  'Senior Site Reliability Engineer'
#  'BI Platform Engineer @ING HUBS Romania'
#  'DevOps Engineer |Data Lake - Core team @ING Hubs Romania'
#  'Chapter Lead Software Engineer - DBNL Data Management @ING Hubs Romania'
#  'Sr. Data Engineer (Hybrid in Romania Only)'
#  'IT Operations Engineer | Capability Squad Summit @ING Hubs Romania']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.17 Spain

# %%
selector = 'Spain'

specializations_gl = ["Inxeniero", "Enxeñería", "Consultor", "arquitecto", "ESPECIALISTA", "Xestor", "Desenvolvedor", "Arquitectura", "Administrador"]

data_terms_gl = ["Datos", "ETL", "Nube", "Analítica", "Analítica de datos", "BI", "Intelixencia de negocios", "Analítica de negocios", "Base de datos", "Pipeline", "Metadatos", "Monitorización", "Centro de datos"]

specializations_ES = ["Ingeniero", "Consultor", "Arquitecto", "Especialista", "Gerente", "Desarrollador", "Arquitectura", "Administrador"]

data_terms_ES = ["Datos", "ETL", "Nube", "Analítico", "Análisis", "BI", "Inteligencia de Negocios", "Análisis de Negocios", "Base de datos", "Pipeline", "Metadatos", "Monitoreo", "Centro de datos"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 146 :
# ['Project Manager / Engineer Smart Cities & Smart Grids (m/f/x)'
#  'Research Engineer (m/f/x/d)' 'Technical Service Engineer'
#  'Sales & Order Operations Specialist' 'Data DevOps'
#  'Data Engineer, Asturias' 'Customer Support Engineer - Madrid'
#  'Field Service Engineer, Barcelona' 'Data Engineer Intern'
#  'M3 Functional Analyst (Remote Role)' 'Data Engineer AWS, 100% En remoto'
#  'Data Engineer' 'Python Data Engineer (Remote)'
#  'Data Engineer (Shadow Team)' '(Mid) Data Engineer' nan
#  'Data Engineer entry level (20 - 30K)' 'Data Engineer (H/M)'
#  'Data Engineer Junior' 'Data Engineer / 100% Remoto, 100% En remoto'
#  'GDC Process Mining Data Engineer (f/m/d)'
#  'Junior Data Engineer (OF0523)' 'Junior Data Engineer'
#  'Data Engineer - PagoNxt' 'Senior Cloud Engineer, Alicante'
#  'Data Engineer and Analytics'
#  'Consultor/a MuleSoft Remoto, 100% En remoto'
#  'Senior TELCO BSS Architect' 'Data Engineer (Remote)'
#  'Engineering Services Manager' 'Data Engineer exp +2 (30-40K)'
#  'Operations Data Analytics Engineer' 'Data Engineer - Accelerator'
#  'Data Analyst' 'JUNIOR DATA ENGINEER'
#  'Head of Product Data - 100% Remote' 'Senior Data Engineer'
#  'AIRWORTHINESS TECHNICAL ENGINEER FOR OPERATIONAL SUITABILITY DATA (OSD)'
#  'RESEARCH ENGINEER (M/F/X/D)' 'Data Engineer for HR (f/m/d)'
#  'Senior Software Engineer, Microservices (Java)'
#  'Data Engineer - 100% remoto, 100% En remoto' 'Data Engineer DataStage'
#  'Senior Data Engineer (40k-50k)' '.NET Senior Software Engineer'
#  'Construction & Development Intern' 'Senior Data Scientist (m/f/d)'
#  'Lead Data Engineer (Google Cloud, Scala, CI/CD)'
#  'Senior Backend Software Engineer (Java)'
#  'Data Analyst/ Engineer Junior (Beca)' 'Data Scientist'
#  'Senior Frontend Engineer (React)' 'Data Analyst - Operations'
#  'RF Engineer, 100% En remoto'
#  'Data Engineer _ Analytics and Modeling analyst'
#  'Senior Business Intelligence Analyst, 100% En remoto'
#  'Senior Data Engineer (m/f/d)' 'Junior Field Service Engineer (m/f/d)'
#  'DATA SCIENTIST (M/F/X/D)' 'Middle Data Engineer'
#  'Data Engineer/Power BI Developer, Barcelona' 'Data Engineer (m/f/d)'
#  'Construction & Facilities Intern - Barcelona' 'Data Engineer AWS'
#  'Data Engineer Spark - Inglés C1 - Remoto 100% Teletrabajo'
#  'Software Engineer (m/f/d)'
#  'Machine Learning Engineer / IA, 100% En remoto'
#  'Data Engineer Spark - B2C1 - Remoto 100%, 100% En remoto'
#  'Senior Data Scientist' 'Data Engineer Internship'
#  'Software Engineer, Backend (Remote, Spain)'
#  'Software Engineer - App Stores Backend (Remote)'
#  'DATA Engineer (full remote)'
#  'Junior Data Engineer - Finance Data Operations'
#  'Data Machine Learning Teletrabajo, 100% En remoto'
#  'C++ Senior Software Engineer' 'Data engineer' 'CAD Engineer Intern'
#  'Data Engineer PowerCenter, 100% En remoto'
#  'Software Engineer, Global Siri (Client Engineering), Barcelona'
#  'Backend Software & Data Engineer'
#  'Data Engineer/Analista Funcional 100%TT, 100% En remoto'
#  'Data Engineer - SQL (Remote)' 'Software Engineer - Data Platform'
#  'Data Scientist/Machine learning Engineer' 'Data Visualization Engineer'
#  'Data Platform Engineer' '954_Data Engineer'
#  'Java Developer - Data Management Engineer'
#  'Data Engineer for Machine Learning'
#  'Senior Backend Software Engineer Python' 'APPLIED INTELLIGENCE'
#  'Programador Python/Data Engineer (Remoto)' 'Python Engineer (Remote)'
#  'Back End Engineer - RoR/Go'
#  'Big Data Engineer – Data Lake - Openbank (Openhub Valencia)'
#  'Satec se encuentra en búsqueda de un Data Engineer'
#  'Business Intelligence Data Engineer'
#  'Data Engineer / Consultor BI – Power BI'
#  'Software Engineer | Java Developer (Possibility of 100%...'
#  'SOFTWARE DEVELOPMENT ENGINEER INTERSHIP 2022 (Barcelona)'
#  'Backend Senior Software Engineer' 'DATA ENGINEER MID'
#  'Data Engineer (Shared Tech)' 'CONSULTOR BI – DATA ENGINEER'
#  'DATA Engineer / SW Developer' 'Java Software Engineer'
#  'Data Engineer for Cybersecurity and Deep Learning' 'Data Engineer IND'
#  'Cybersecurity Officer (Data Protection and Privacy) ROSTER'
#  'VIE Data Engineer, Cardif - Madrid, H/F' 'Data Engineer, Madrid'
#  'Data Engineer Manager' 'Data Software Engineer con B2 de inglés'
#  'Senior Data Engineer - SCALA'
#  'Interoperability and Tactical Data Links Systems Engineer'
#  'Senior System Engineer - Smart Cities'
#  'Digital Operations & Reporting Specialist - Temporary Contract - Opportunity for Working Remotely Madrid,'
#  'Data Engineer Lead' 'Senior Backend Engineer - Python'
#  'Data Engineer - AZURE' 'Senior Software Engineer (Go)'
#  'IA and Data Engineer (Hybrid)' 'Software Engineer, Python/Go'
#  'Senior Software Engineer, Product Platform'
#  'Industrial engineer. Technical Consultant for Factory Automation with focus PLC/HMI (m/f/d)'
#  'Data Lead'
#  'Software Engineer (C#) for Software Development department - Barcelona'
#  'Lead Software Engineer (d/f/m) - Payroll (Madrid, Barcelona or remote Spain)'
#  'Senior Data Engineer - Data Platform'
#  '2023 Software Development Engineer Internship'
#  'Senior Data Engineer - OSIsoft PI' 'Data Engineer (Junior/Middle)'
#  'IT Project Manager (m/f/d)'
#  'Data Engineer for Language and Translation Technologies (RE2)'
#  'Machine Learning Engineer'
#  'Windchill & A400M PDM backbone technical and functional engineer (m/f)'
#  'Database Developer / Data Engineer | Azure & BI' 'DATA ENGINEER'
#  'SR Data Engineer - SGT&O Madrid or Cantabria'
#  'Software Engineer Data Manager' 'Big Data Engineer (M/H/X)'
#  'Data Software Engineer' 'Customer Solutions Engineer'
#  'Data Engineer junior (H/M)' 'Machine Learning Engineer / Data Scientist']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_ROM, specializations_HU],
        [data_terms_ROM, data_terms_HU]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 88 :
# ['Data Engineer, Asturias' 'Data Engineer Intern'
#  'Data Engineer AWS, 100% En remoto' 'Data Engineer'
#  'Python Data Engineer (Remote)' 'Data Engineer (Shadow Team)'
#  '(Mid) Data Engineer' 'Data Engineer entry level (20 - 30K)'
#  'Data Engineer (H/M)' 'Data Engineer Junior'
#  'Data Engineer / 100% Remoto, 100% En remoto'
#  'GDC Process Mining Data Engineer (f/m/d)'
#  'Junior Data Engineer (OF0523)' 'Junior Data Engineer'
#  'Data Engineer - PagoNxt' 'Senior Cloud Engineer, Alicante'
#  'Data Engineer and Analytics' 'Data Engineer (Remote)'
#  'Data Engineer exp +2 (30-40K)' 'Operations Data Analytics Engineer'
#  'Data Engineer - Accelerator' 'JUNIOR DATA ENGINEER'
#  'Head of Product Data - 100% Remote' 'Senior Data Engineer'
#  'AIRWORTHINESS TECHNICAL ENGINEER FOR OPERATIONAL SUITABILITY DATA (OSD)'
#  'Data Engineer for HR (f/m/d)'
#  'Data Engineer - 100% remoto, 100% En remoto' 'Data Engineer DataStage'
#  'Senior Data Engineer (40k-50k)'
#  'Lead Data Engineer (Google Cloud, Scala, CI/CD)'
#  'Data Analyst/ Engineer Junior (Beca)'
#  'Data Engineer _ Analytics and Modeling analyst'
#  'Senior Data Engineer (m/f/d)' 'Middle Data Engineer'
#  'Data Engineer/Power BI Developer, Barcelona' 'Data Engineer (m/f/d)'
#  'Data Engineer AWS'
#  'Data Engineer Spark - Inglés C1 - Remoto 100% Teletrabajo'
#  'Data Engineer Spark - B2C1 - Remoto 100%, 100% En remoto'
#  'Data Engineer Internship' 'DATA Engineer (full remote)'
#  'Junior Data Engineer - Finance Data Operations' 'Data engineer'
#  'Data Engineer PowerCenter, 100% En remoto'
#  'Backend Software & Data Engineer'
#  'Data Engineer/Analista Funcional 100%TT, 100% En remoto'
#  'Data Engineer - SQL (Remote)' 'Software Engineer - Data Platform'
#  'Data Scientist/Machine learning Engineer' 'Data Visualization Engineer'
#  'Data Platform Engineer' '954_Data Engineer'
#  'Java Developer - Data Management Engineer'
#  'Data Engineer for Machine Learning'
#  'Programador Python/Data Engineer (Remoto)'
#  'Big Data Engineer – Data Lake - Openbank (Openhub Valencia)'
#  'Satec se encuentra en búsqueda de un Data Engineer'
#  'Business Intelligence Data Engineer'
#  'Data Engineer / Consultor BI – Power BI'
#  'Software Engineer | Java Developer (Possibility of 100%...'
#  'DATA ENGINEER MID' 'Data Engineer (Shared Tech)'
#  'CONSULTOR BI – DATA ENGINEER' 'DATA Engineer / SW Developer'
#  'Data Engineer for Cybersecurity and Deep Learning' 'Data Engineer IND'
#  'VIE Data Engineer, Cardif - Madrid, H/F' 'Data Engineer, Madrid'
#  'Data Engineer Manager' 'Data Software Engineer con B2 de inglés'
#  'Senior Data Engineer - SCALA'
#  'Interoperability and Tactical Data Links Systems Engineer'
#  'Data Engineer Lead' 'Data Engineer - AZURE'
#  'IA and Data Engineer (Hybrid)' 'Data Lead'
#  'Senior Data Engineer - Data Platform'
#  'Senior Data Engineer - OSIsoft PI' 'Data Engineer (Junior/Middle)'
#  'Data Engineer for Language and Translation Technologies (RE2)'
#  'Database Developer / Data Engineer | Azure & BI' 'DATA ENGINEER'
#  'SR Data Engineer - SGT&O Madrid or Cantabria'
#  'Software Engineer Data Manager' 'Big Data Engineer (M/H/X)'
#  'Data Software Engineer' 'Data Engineer junior (H/M)'
#  'Machine Learning Engineer / Data Scientist']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.18 Sweden

# %%
selector = 'Sweden'

specializations_SV = ["Ingenjör", "Konsult", "Arkitekt", "Specialist", "Chef", "Utvecklare", "Arkitektur", "Administratör"]

data_terms_SV = ["Data", "ETL", "Moln", "Analys", "Analytik", "BI", "Affärsinriktad Analys", "Business Intelligence", "Databas", "Pipeline", "Metadata", "Övervakning", "Datacenter"]

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 95 :
# ['Data Governance Engineer (m/f/d) 80% Homeoffice' 'Network Data Engineer'
#  'Process Manager (m/f/d) 80% Homeoffice'
#  'Datadriven Sälj- & Verksamhetsplanerare'
#  'Battery Module Safety Engineer'
#  'Data Engineer | Sjunde AP-fonden | Stockholm'
#  'System Engineer within Energy Storage System at Electromobility'
#  'Data Engineer to Avinode!' 'BI & Data Analytics Manager' 'Data Engineer'
#  'Rock mechanical engineer at Zinkgruvan Mining' 'ECG Technical Advisor'
#  nan 'Data/ cloud engineer for a global telecom company!'
#  'IT solution engineer / Cloud engineer till QD'
#  'Data Engineer to Business Intelligence & Analytics...'
#  'Analytics Data Engineer' 'Back-end/Data Software Engineer'
#  'DevOps Engineer to Zebware' 'SIEM Engineer' 'Data Engineer - Stockholm'
#  'Junior Data Engineer' 'Graduate Data Engineer'
#  'Data Engineer (Google Looker) - Fully Remote (LATAM)'
#  'Head of Azure till Bitlog' 'Sustainability Engineer' 'Data Science Lead'
#  'Firmware & Electronics Engineer' 'Customer Experience Engineer'
#  'Firmware & Embedded Software Engineer' 'Backend Engineer'
#  'Software Engineer' 'Fullstack Engineer' 'Software Engineer - Backend'
#  'Backend Engineer - Java/Kotlin' 'Data Engineer sökes till Gränges'
#  'Customer Success Lead' 'Backend engineer with a love for gaming'
#  'Senior Fullstack Engineer' 'Senior Security Engineer'
#  'DevOps Cloud Engineer for AWS' 'Senior/Staff Quality Engineer'
#  'CI/CD Engineer till Tutus Data AB!'
#  'Devops Engineer with Cloud Experience' 'Senior Back-end Engineer - Java'
#  'Senior Network Engineer - WLAN' 'Senior DevOps'
#  'Junior Systemutvecklare till Axis i Lund!' 'Azure AI/Data Engineer'
#  'Data Engineer to Data Platform and Innovation team'
#  'Data Engineer (Engagement team)' 'GCP Data Engineer'
#  'Data Engineer to Vetfamily'
#  'Junior Product Imaging Engineer för Axis Communications i Lund!'
#  'JUNIOR SALES MANAGER, FULL-TIME'
#  'Research data engineer for Chemical biology Consortium Sweden (CBCS)'
#  'IT Support Engineer' 'Principal Data Engineer'
#  'Junior Infrastructure Engineer' 'Data Developer/Engineer'
#  'Senior Data Engineer'
#  '(Senior) Data Engineer(s) - The future of banking with...'
#  'Senior Cloud Software Engineer Azure' 'Data Centre Technician'
#  'Senior Data Governance Engineer (m/f/d)' 'Integration Engineer'
#  'Backend Engineer till TV4' 'Analytics Engineer' 'DevOps / Data engineer'
#  'Data Engineer (7926)' 'Data Engineer – Google Cloud'
#  'Legal & Compliance Specialist / GDPR & informationssäkerhet till Hailey HR'
#  'Junior Information Security Engineer - Sweden - Graduate Program'
#  'Senior Backend Engineer' 'Data centric backend developer (Go)'
#  'DATA ENGINEER' 'Software Engineer - App Stores Backend (Remote)'
#  'Backend Engineer - Identity & Privacy'
#  'Python Developer / Data Engineer' 'Data Engineer / BI Developer'
#  'Lead Data Engineer' 'Data Engineer - Nyfiken på nya utmaningar?'
#  'Software Engineer Graduate - Backend'
#  'Senior Data Engineer/Cloud Architect' 'Data Engineer till Data Edge'
#  'Data Engineer inom Google Cloud' 'AWS Data Engineer - Fully Remote'
#  'Junior Engineer - Java' 'Cloud Engineer - Data & Analytics Platform'
#  'Data & Analytics Manager'
#  'Azure Data Engineer till vårt team i Stockholm'
#  'Data Engineer som vill skapa framtida historia'
#  'Infrastructure Engineer' 'MLOps Engineer'
#  'Senior Software Engineer, Autonomous and data-driven capabilities']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_SV, specializations_FI],
        [data_terms_SV, data_terms_FI]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 54 :
# ['Data Governance Engineer (m/f/d) 80% Homeoffice' 'Network Data Engineer'
#  'Data Engineer | Sjunde AP-fonden | Stockholm'
#  'System Engineer within Energy Storage System at Electromobility'
#  'Data Engineer to Avinode!' 'BI & Data Analytics Manager' 'Data Engineer'
#  'Data/ cloud engineer for a global telecom company!'
#  'IT solution engineer / Cloud engineer till QD'
#  'Data Engineer to Business Intelligence & Analytics...'
#  'Analytics Data Engineer' 'Back-end/Data Software Engineer'
#  'Data Engineer - Stockholm' 'Junior Data Engineer'
#  'Graduate Data Engineer'
#  'Data Engineer (Google Looker) - Fully Remote (LATAM)'
#  'Head of Azure till Bitlog' 'Sustainability Engineer' 'Data Science Lead'
#  'Data Engineer sökes till Gränges' 'DevOps Cloud Engineer for AWS'
#  'CI/CD Engineer till Tutus Data AB!'
#  'Devops Engineer with Cloud Experience' 'Azure AI/Data Engineer'
#  'Data Engineer to Data Platform and Innovation team'
#  'Data Engineer (Engagement team)' 'GCP Data Engineer'
#  'Data Engineer to Vetfamily'
#  'Research data engineer for Chemical biology Consortium Sweden (CBCS)'
#  'Principal Data Engineer' 'Data Developer/Engineer'
#  'Senior Data Engineer'
#  '(Senior) Data Engineer(s) - The future of banking with...'
#  'Senior Cloud Software Engineer Azure'
#  'Senior Data Governance Engineer (m/f/d)' 'Analytics Engineer'
#  'DevOps / Data engineer' 'Data Engineer (7926)'
#  'Data Engineer – Google Cloud' 'Data centric backend developer (Go)'
#  'DATA ENGINEER' 'Python Developer / Data Engineer'
#  'Data Engineer / BI Developer' 'Lead Data Engineer'
#  'Data Engineer - Nyfiken på nya utmaningar?'
#  'Senior Data Engineer/Cloud Architect' 'Data Engineer till Data Edge'
#  'Data Engineer inom Google Cloud' 'AWS Data Engineer - Fully Remote'
#  'Cloud Engineer - Data & Analytics Platform' 'Data & Analytics Manager'
#  'Azure Data Engineer till vårt team i Stockholm'
#  'Data Engineer som vill skapa framtida historia'
#  'Senior Software Engineer, Autonomous and data-driven capabilities']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.19 Switzerland

# %%
selector = 'Switzerland'

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 134 :
# ['Big Data & Platform Engineer 80-100%'
#  'Data Engineer (w/m) | 80% oder mehr' 'System Integration Engineer'
#  'Leiter Data Analytics & Data Science (a)' 'DWH Engineer (a) 80 - 100%'
#  'Junior Data Engineer / Consultant (100%)'
#  'Senior Data Engineer / Consultant (100%)'
#  'Software Systems Engineer - Client Services Technology'
#  'System Engineer im Cloud Bereich'
#  'Platform-Engineer Information Management (w/m/d)'
#  'Software Systems Engineer – Business Support Services Technology'
#  'Data Engineer Messtechnik (m/w/d)' 'IT Cyber Security Engineer'
#  'Data Engineer / Analyst (m/f/d)' 'Azure Data Engineer - Spark'
#  'Data Engineer - DWH Entwicklung (w/m/d) (8581)'
#  'Data Management Engineer (m/f)' 'IT Test Engineer'
#  'Research Software Engineer' 'Manufacturing Engineer - Medical Device'
#  'M365 Engineer (w/m/d) (8666)' 'Data Management Engineer (w/m/d)'
#  'ETL / DWH Engineer (m/w/d)'
#  'Freelance Hardware/ Data Centre Field Engineer'
#  'Internship Organoid Genome Editing'
#  'Data- & Integration Engineer (w/m/d)' 'Senior Power BI Engineer (m/w/d)'
#  'Senior Quality Engineer (m/f/d)'
#  'Managed Service Engineer Data Infrastructure'
#  'Head Software Solutions Competence Center (100%)'
#  'Big Data - (Senior) Data Scientist and Machine Learning Engineer (m/w)'
#  'Big Data-Engineer (m/w) 80-100%' 'Azure Data Engineer'
#  'Data Engineer / Analyst' 'Business Intelligence Data Engineer (d/f/w)'
#  'Platform Engineer (Remote)' 'DevOps Data Engineer 100%'
#  'Mobile Software Engineer Flutter' 'Data Scientist / AI Engineer (w/m/d)'
#  'Research Associate in Microfluidics & Microtechnologies'
#  'Software Engineer Microscopy' 'IT-Trainee'
#  'Product Engineer - ArcGIS JavaScript API' 'Big Data Engineer (m/w/d)'
#  'Data Engineer / Data Scientist'
#  'Development Reliability Engineer (contract)' 'Oligonucleotide Designer'
#  'Intern in Global Manufacturing Sciences and Technology'
#  'System Engineer' 'Solution Architect (Aviation) (m/f/d)'
#  'Project Scheduler (m/f/d)'
#  'Cold Chain Packaging Engineer - temporary for 12 months'
#  'Automation Engineer (m/w/d)'
#  'Global Student Internship in Innovation & Sustainability - Fill Level Calibration without Water Consumption (m/f/d; starting in July 2023 for 3 months, with a possibility of extension)'
#  'PLM Polarion Engineer (50% Home Office)'
#  "Manager de l'équipe Data Engineer"
#  'Internship IHB Operations (Basel, 4 months) (m/f/d)'
#  'Data Analyst / Software Engineer'
#  '(Junior) Data Architect / Data Engineer' 'Data Engineer (m/w/d)'
#  'Senior Data Scientist / Engineer' 'Process / MSAT Engineer'
#  'Engineer/Scientist in electrochemical method development'
#  'Erfahrener Data Scientist'
#  'Data Engineer (Python, AWS, DBT, Snowflake) - Genève (Suisse) (IT) / Freelance'
#  'Belle opportunité pour un/e Data Engineer Junior - Urgent - Banque'
#  'Data Scientist'
#  'Data Engineer/Data Analyst Business Intelligence (m/w/d)'
#  'Cloud & Data Engineer' 'Senior Data Scientist'
#  'Senior Data Science Engineer & Business Intelligence Developer (Power BI) (m/w/d)'
#  'Full Stack Web Application Development Internship (12 months)'
#  'Oligonucleotides Compound Logistics Principal Associate'
#  'Sensor Development Engineer' 'System Engineer StorageGRID'
#  'Data Center Engineer' 'Linux Engineer (m/w/d)'
#  'System Development Engineer'
#  'Scientific Area Lead Computational Pathology'
#  'Information Security Engineer (f/m/x)'
#  'Postdoctoral Fellow, Retinal Organoid Bioengineering (m/f/d)'
#  'Data Science Lead (m/w/d)' 'Data-Scientist'
#  'Junior Data Engineer (m/f/d)' 'Data Engineer'
#  'Machine Learning Engineer / KI Software Developer Public Sector'
#  'ICT System Engineer (m/w/d) Datacenter und Cloud'
#  'Data Infrastructure Engineer (m/w/d)'
#  'Applied Researcher/Data Scientist position in time series / forecasting'
#  'Azure Data Engineer / Developer'
#  'Roche Postdoctoral Fellow (RPF) in Oncology Discovery – Phenotypic CRISPR Library Screens for Cell Therapy'
#  'Electrical System Engineer'
#  'Biotechnologist - Technical Support Laboratory Instruments (m/f/d)'
#  'IT System Engineer - Data Center (m/w/d)'
#  'Data Engineer (Python/Pyspark) - remote'
#  'IT System Engineer - Data Services (m/w/d)'
#  'Data Engineer mit mehrjähriger Erfahrung im SQL Bereich (m/w/d)'
#  'IT Service Desk Agent' 'Software Engineer .NET'
#  'Embedded Software Engineer (f/m/d)' 'FPGA Design Engineer'
#  'Senior Business Analyst for Process Testing'
#  'Senior Software Engineer (Python Backend) (m/w/d) - AI & Business Automation'
#  'Data Engineer für Business Intelligence (m/w/d)'
#  'Application engineer for SAP S/4 HANA EAM'
#  'Cloud Architect / Big Data Engineer / Data Scientist (m/w/d)'
#  'Backend Developer (Node.js)' 'Lead Data Engineer - Zürich (m/w/d)'
#  'Big Data Engineer' 'IT Systems and Network Specialist'
#  'TELEMATIKER/IN (Solution Engineer Data/Voice)'
#  '(Senior) Big Data Software Entwickler (m/w/d) - Bern'
#  'System Engineer / System Specialist' 'Junior System Engineer (m/w/d)'
#  'Senior Data Analyst (m/w/d)' 'Für Freelancer: IT Data Engineer (m/f/d)'
#  'Senior Java Developer' 'Cloud Data Infrastructure Engineer (m/w/d)'
#  'Professional Azure Data Engineer (m/w/d)'
#  'Operational Technology (OT/IOT/Automatisierung) Engineer (w/m/d), 80-100'
#  'IT Engineer - Automatisierung' 'BI Data Engineer'
#  'Software / System Engineer' 'ML - Data Engineer'
#  'Senior Data Scientist (m/w/d)' 'System Cloud Engineer (m/w/d)'
#  'System Engineer (m/w/d)' 'Software Engineer - Frontend/Backend (m/w/d)'
#  'Scientific Data & Machine Learning Engineer in Scientific IT and Data Office'
#  'Senior System Engineer Data Services (m/w/d)'
#  'Software Engineer - Java DW/BI (m/w/d)'
#  'Junior System Engineer ICT (m/w/d)'
#  'Application Owner & Process Engineer SAP PP & QM (80%-100%)'
#  'Engineer – Structural Dynamics Specialist (80-100%)']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_DE, specializations_FR, specializations_IT],
        [data_terms_DE, data_terms_FR, data_terms_IT]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 64 :
# ['Big Data & Platform Engineer 80-100%'
#  'Data Engineer (w/m) | 80% oder mehr'
#  'Junior Data Engineer / Consultant (100%)'
#  'Senior Data Engineer / Consultant (100%)'
#  'System Engineer im Cloud Bereich' 'Data Engineer Messtechnik (m/w/d)'
#  'Data Engineer / Analyst (m/f/d)' 'Azure Data Engineer - Spark'
#  'Data Engineer - DWH Entwicklung (w/m/d) (8581)'
#  'Data Management Engineer (m/f)' 'Data Management Engineer (w/m/d)'
#  'ETL / DWH Engineer (m/w/d)'
#  'Freelance Hardware/ Data Centre Field Engineer'
#  'Data- & Integration Engineer (w/m/d)' 'Senior Power BI Engineer (m/w/d)'
#  'Managed Service Engineer Data Infrastructure'
#  'Big Data - (Senior) Data Scientist and Machine Learning Engineer (m/w)'
#  'Big Data-Engineer (m/w) 80-100%' 'Azure Data Engineer'
#  'Data Engineer / Analyst' 'Business Intelligence Data Engineer (d/f/w)'
#  'DevOps Data Engineer 100%' 'Mobile Software Engineer Flutter'
#  'Data Scientist / AI Engineer (w/m/d)' 'Big Data Engineer (m/w/d)'
#  'Data Engineer / Data Scientist'
#  'Development Reliability Engineer (contract)'
#  "Manager de l'équipe Data Engineer" 'Data Analyst / Software Engineer'
#  '(Junior) Data Architect / Data Engineer' 'Data Engineer (m/w/d)'
#  'Senior Data Scientist / Engineer'
#  'Data Engineer (Python, AWS, DBT, Snowflake) - Genève (Suisse) (IT) / Freelance'
#  'Belle opportunité pour un/e Data Engineer Junior - Urgent - Banque'
#  'Data Engineer/Data Analyst Business Intelligence (m/w/d)'
#  'Cloud & Data Engineer'
#  'Senior Data Science Engineer & Business Intelligence Developer (Power BI) (m/w/d)'
#  'Data Center Engineer'
#  'Postdoctoral Fellow, Retinal Organoid Bioengineering (m/f/d)'
#  'Data Science Lead (m/w/d)' 'Junior Data Engineer (m/f/d)'
#  'Data Engineer' 'ICT System Engineer (m/w/d) Datacenter und Cloud'
#  'Data Infrastructure Engineer (m/w/d)' 'Azure Data Engineer / Developer'
#  'IT System Engineer - Data Center (m/w/d)'
#  'Data Engineer (Python/Pyspark) - remote'
#  'IT System Engineer - Data Services (m/w/d)'
#  'Data Engineer mit mehrjähriger Erfahrung im SQL Bereich (m/w/d)'
#  'Data Engineer für Business Intelligence (m/w/d)'
#  'Cloud Architect / Big Data Engineer / Data Scientist (m/w/d)'
#  'Lead Data Engineer - Zürich (m/w/d)' 'Big Data Engineer'
#  'TELEMATIKER/IN (Solution Engineer Data/Voice)'
#  '(Senior) Big Data Software Entwickler (m/w/d) - Bern'
#  'Für Freelancer: IT Data Engineer (m/f/d)'
#  'Cloud Data Infrastructure Engineer (m/w/d)'
#  'Professional Azure Data Engineer (m/w/d)' 'BI Data Engineer'
#  'ML - Data Engineer' 'System Cloud Engineer (m/w/d)'
#  'Scientific Data & Machine Learning Engineer in Scientific IT and Data Office'
#  'Senior System Engineer Data Services (m/w/d)'
#  'Software Engineer - Java DW/BI (m/w/d)']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.20 Turkey

# %%
dfs[selector] = df

# %%
selector = 'Turkey'

specializations_TR= ["Mühendis", "Danışman", "Mimar", "Uzman", "Yönetici", "Geliştirici", "Mimarlık", "Yönetici"]
data_terms_TR = ["Veri", "ETL", "Bulut", "Analitik", "Analiz", "BI", "İş Zekası", "İş Analizi", "Veritabanı", "Boru Hattı", "Meta Veri", "İzleme", "Veri Merkezi"]

specializations_KU = ["Mûhandis", "Mûhendisî", "Pêşkêşker", "pargîdaniyar", "XWESER", "Manajer", "Pêşgir", "Arkîtektur", "Peywendkar"]
data_terms_KU = ["Zanist", "ETL", "Pirsgirêk", "Analytîk", "Analîz", "BI", "Zanistên Kar", "Analîzên Kar", "Bingehbazî", "Pîpelya", "Meta-Data", "Pêşwazî", "Navenda Zanistê"]

# %%
show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 64 :
# ['Big Data & Platform Engineer 80-100%'
#  'Data Engineer (w/m) | 80% oder mehr'
#  'Junior Data Engineer / Consultant (100%)'
#  'Senior Data Engineer / Consultant (100%)'
#  'System Engineer im Cloud Bereich' 'Data Engineer Messtechnik (m/w/d)'
#  'Data Engineer / Analyst (m/f/d)' 'Azure Data Engineer - Spark'
#  'Data Engineer - DWH Entwicklung (w/m/d) (8581)'
#  'Data Management Engineer (m/f)' 'Data Management Engineer (w/m/d)'
#  'ETL / DWH Engineer (m/w/d)'
#  'Freelance Hardware/ Data Centre Field Engineer'
#  'Data- & Integration Engineer (w/m/d)' 'Senior Power BI Engineer (m/w/d)'
#  'Managed Service Engineer Data Infrastructure'
#  'Big Data - (Senior) Data Scientist and Machine Learning Engineer (m/w)'
#  'Big Data-Engineer (m/w) 80-100%' 'Azure Data Engineer'
#  'Data Engineer / Analyst' 'Business Intelligence Data Engineer (d/f/w)'
#  'DevOps Data Engineer 100%' 'Mobile Software Engineer Flutter'
#  'Data Scientist / AI Engineer (w/m/d)' 'Big Data Engineer (m/w/d)'
#  'Data Engineer / Data Scientist'
#  'Development Reliability Engineer (contract)'
#  "Manager de l'équipe Data Engineer" 'Data Analyst / Software Engineer'
#  '(Junior) Data Architect / Data Engineer' 'Data Engineer (m/w/d)'
#  'Senior Data Scientist / Engineer'
#  'Data Engineer (Python, AWS, DBT, Snowflake) - Genève (Suisse) (IT) / Freelance'
#  'Belle opportunité pour un/e Data Engineer Junior - Urgent - Banque'
#  'Data Engineer/Data Analyst Business Intelligence (m/w/d)'
#  'Cloud & Data Engineer'
#  'Senior Data Science Engineer & Business Intelligence Developer (Power BI) (m/w/d)'
#  'Data Center Engineer'
#  'Postdoctoral Fellow, Retinal Organoid Bioengineering (m/f/d)'
#  'Data Science Lead (m/w/d)' 'Junior Data Engineer (m/f/d)'
#  'Data Engineer' 'ICT System Engineer (m/w/d) Datacenter und Cloud'
#  'Data Infrastructure Engineer (m/w/d)' 'Azure Data Engineer / Developer'
#  'IT System Engineer - Data Center (m/w/d)'
#  'Data Engineer (Python/Pyspark) - remote'
#  'IT System Engineer - Data Services (m/w/d)'
#  'Data Engineer mit mehrjähriger Erfahrung im SQL Bereich (m/w/d)'
#  'Data Engineer für Business Intelligence (m/w/d)'
#  'Cloud Architect / Big Data Engineer / Data Scientist (m/w/d)'
#  'Lead Data Engineer - Zürich (m/w/d)' 'Big Data Engineer'
#  'TELEMATIKER/IN (Solution Engineer Data/Voice)'
#  '(Senior) Big Data Software Entwickler (m/w/d) - Bern'
#  'Für Freelancer: IT Data Engineer (m/f/d)'
#  'Cloud Data Infrastructure Engineer (m/w/d)'
#  'Professional Azure Data Engineer (m/w/d)' 'BI Data Engineer'
#  'ML - Data Engineer' 'System Cloud Engineer (m/w/d)'
#  'Scientific Data & Machine Learning Engineer in Scientific IT and Data Office'
#  'Senior System Engineer Data Services (m/w/d)'
#  'Software Engineer - Java DW/BI (m/w/d)']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_DE, specializations_FR, specializations_IT],
        [data_terms_DE, data_terms_FR, data_terms_IT]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 15 :
# ['Data Engineer' 'Machine Learning Engineer With Data Science Experience'
#  'Software & Big Data Engineer' 'Big Data & AI Engineer'
#  'SENIOR DATA ENGINEER (PYTHON/SCALA, AWS)' 'GCP Data Engineer'
#  'Data Analysis / Data Engineering / Data Science (m/f/d)'
#  'Network Data Solutions Delivery Engineer' 'Senior Data Engineer'
#  'Planning Engineer @Siemens Mobility Türkiye'
#  'Mid / Senior Data Engineer'
#  'Application and Design Engineer @Siemens Mobility Türkiye'
#  'senior data engineer'
#  'Technology Engineer - Site Reliability Engineer(SRE)'
#  'Database Engineer - PostgreSQL']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.21 United_Kingdom

# %%
selector = 'United_Kingdom'

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 54 :
# ['Data Engineer' 'Data Engineer (Junior)' 'Junior Power BI Engineer'
#  'Senior Data Engineer' 'Reporting Data Engineer' 'Azure Data Engineer'
#  'Data Engineer - London' 'BI & Data Engineer'
#  'Python Data Engineer (Remote)' 'Data Engineer Hybrid London'
#  'Data Engineer | UK/Europe | Remote | £50-70K' 'Data Pipeline Engineer'
#  'Microsoft Azure Data engineer' 'Apprentice Data Engineer'
#  'Data Engineer (GIS/Geospatial)' 'Graduate Data Engineer - Bristol'
#  'Experienced Data Engineer' 'MLOPS & Data Engineer (12 Months)'
#  'Placement Student – Clinical Data Engineer'
#  'Data Processor / Data Engineer' 'Junior Data Engineer'
#  'Senior Data Engineer Full Time Permanent' 'Data Cabling Engineer'
#  'Junior SQL Data Engineer' 'Trading Desk - Data Engineer'
#  'Data Software Engineer | Python' 'BI Engineer'
#  'Data Engineer, MS Partner, Redhill Full Time Permanent'
#  'Data Analytics Engineer' 'Data Engineer - Remote' 'Power BI Engineer'
#  'Data Engineer - SQL / ETL / AWS - Remote' 'Data Model Engineer'
#  'Data Platform Engineer' 'On/Offshore IT/Data Comms Support Engineer'
#  'DATA ENGINEER' 'Data Integration Engineer - London'
#  'Data Engineer/ Database Administrator'
#  'Data and Cloud Engineer (Fixed term)'
#  'Quantitative Strategist - Data Platforms'
#  'Associate, Data Scientist / Machine Learning Engineer'
#  'AWS Data Engineer (Contractor)' 'SQL Data Migration Engineer'
#  'Data Specialist - Power BI Developer'
#  'Test Engineer - Customer and Data' 'Lead Data & Analytics Engineer'
#  'Cloud Data Engineer' 'Software Engineer (Data)'
#  'Data Warehouse Engineer' 'Data Engineer & Analytics Developer'
#  'DATA SCIENCE ENGINEER' 'Power BI Developer' 'Data Engineer (AWS)'
#  'Data Analytics Site Reliability Engineer']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title']),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 53 :
# ['Data Engineer' 'Data Engineer (Junior)' 'Junior Power BI Engineer'
#  'Senior Data Engineer' 'Reporting Data Engineer' 'Azure Data Engineer'
#  'Data Engineer - London' 'BI & Data Engineer'
#  'Python Data Engineer (Remote)' 'Data Engineer Hybrid London'
#  'Data Engineer | UK/Europe | Remote | £50-70K' 'Data Pipeline Engineer'
#  'Microsoft Azure Data engineer' 'Apprentice Data Engineer'
#  'Data Engineer (GIS/Geospatial)' 'Graduate Data Engineer - Bristol'
#  'Experienced Data Engineer' 'MLOPS & Data Engineer (12 Months)'
#  'Placement Student – Clinical Data Engineer'
#  'Data Processor / Data Engineer' 'Junior Data Engineer'
#  'Senior Data Engineer Full Time Permanent' 'Data Cabling Engineer'
#  'Junior SQL Data Engineer' 'Trading Desk - Data Engineer'
#  'Data Software Engineer | Python' 'BI Engineer'
#  'Data Engineer, MS Partner, Redhill Full Time Permanent'
#  'Data Analytics Engineer' 'Data Engineer - Remote' 'Power BI Engineer'
#  'Data Engineer - SQL / ETL / AWS - Remote' 'Data Model Engineer'
#  'Data Platform Engineer' 'On/Offshore IT/Data Comms Support Engineer'
#  'DATA ENGINEER' 'Data Integration Engineer - London'
#  'Data Engineer/ Database Administrator'
#  'Data and Cloud Engineer (Fixed term)'
#  'Associate, Data Scientist / Machine Learning Engineer'
#  'AWS Data Engineer (Contractor)' 'SQL Data Migration Engineer'
#  'Data Specialist - Power BI Developer'
#  'Test Engineer - Customer and Data' 'Lead Data & Analytics Engineer'
#  'Cloud Data Engineer' 'Software Engineer (Data)'
#  'Data Warehouse Engineer' 'Data Engineer & Analytics Developer'
#  'DATA SCIENCE ENGINEER' 'Power BI Developer' 'Data Engineer (AWS)'
#  'Data Analytics Site Reliability Engineer']

# %%
dfs[selector] = df

# %% [markdown]
# ##### 7.22 USA 🦅

# %%
selector = 'United_States'

# %%
show_unique_and_its_len(dfs[selector]['Job_title'])
# Out:
# 65 :
# ['Data Engineer' 'Data Engineer - Terraform' 'Snowflake Data Engineer'
#  'Data Engineer (MDM)' 'AWS Data Engineer' 'DATA ENGINEER'
#  'Big Data Engineer' 'Sr. Data Engineer' 'Data Engineer - Flink'
#  'Jr. Data Engineer' 'Data Engineer - Remote' 'Data Engineer (L5)'
#  'Software Data Engineer' 'GCP Data Engineer' 'Senior Data Engineer'
#  'Azure Cloud Data Engineer' 'GCP DATA ENGINEER' 'Data Test Engineer'
#  'Azure Data Engineer' 'Senior Azure Data Bricks Engineer'
#  'Data Analytics Engineer' 'Data Engineer (W2 and onsite)'
#  'Senior Big Data Engineer' 'Data Engineer- Google Cloud'
#  'Data Engineer (ETL & System Administration concentration)'
#  'Data Engineer/Data Analyst' 'Data Engineer/Data Scientist'
#  'ETL Data Engineer' 'Lead Data Engineer'
#  'Sr. Data Engineer with Snowflake' 'Junior Data Engineer'
#  'Senior Data Engineer - Remote' 'Data Engineer Level 3'
#  'Cloud Data Engineer (Azure)' 'Senior Software Engineer, Data'
#  'Technical Support Engineer (L5) - Data Platform, Big Data / Analytics'
#  'Full Stack Data Engineer' 'Data Engineer IC4 - US ONLY'
#  'Data Engineer I' 'Senior Health Data and Interoperability Engineer'
#  'Azure Data Warehouse Engineer' 'Data Logging Engineer'
#  'ETL Engineer/ Data Analyst - Software Engineer III'
#  'Software Engineer III (AI, Data, Python)'
#  'Software/GCP Data Engineer (W2 only)' 'Software Engineer (Data)'
#  'Junior Big Data Engineer - C11' 'Anaplan Data Engineer'
#  'Data Software Engineer' 'Data Engineer (ETL & Data Catalogue Support)'
#  'Data Scientist / Data Engineer' 'Big Data Sytems Engineer(Hadoop)'
#  'Data Engineer - Need locals to CA' 'Data Engineer (ETL)'
#  'Python Data Engineer' 'Data engineer'
#  'Data Engineer - SnowFlake, Azure Data, Terraform'
#  'Senior Data Engineer [ Remote ]' 'Senior Data Engineer, Analytics'
#  'Cloud Data Engineer' 'Software Engineer, Data' 'Data Engineer 925'
#  'Senior Azure Data Engineer' 'Data Engineer ETL'
#  'Big Data Engineer, Senior']

# %%
df = dfs[selector]
filtered_df = df[df.apply(
    lambda row: is_data_engineering_job(
        row['Job_title'],
        [specializations_ES],
        [data_terms_ES]
    ),
    axis=1)
]

show_unique_and_its_len(filtered_df['Job_title'])
# Out:
# 65 :
# ['Data Engineer' 'Data Engineer - Terraform' 'Snowflake Data Engineer'
#  'Data Engineer (MDM)' 'AWS Data Engineer' 'DATA ENGINEER'
#  'Big Data Engineer' 'Sr. Data Engineer' 'Data Engineer - Flink'
#  'Jr. Data Engineer' 'Data Engineer - Remote' 'Data Engineer (L5)'
#  'Software Data Engineer' 'GCP Data Engineer' 'Senior Data Engineer'
#  'Azure Cloud Data Engineer' 'GCP DATA ENGINEER' 'Data Test Engineer'
#  'Azure Data Engineer' 'Senior Azure Data Bricks Engineer'
#  'Data Analytics Engineer' 'Data Engineer (W2 and onsite)'
#  'Senior Big Data Engineer' 'Data Engineer- Google Cloud'
#  'Data Engineer (ETL & System Administration concentration)'
#  'Data Engineer/Data Analyst' 'Data Engineer/Data Scientist'
#  'ETL Data Engineer' 'Lead Data Engineer'
#  'Sr. Data Engineer with Snowflake' 'Junior Data Engineer'
#  'Senior Data Engineer - Remote' 'Data Engineer Level 3'
#  'Cloud Data Engineer (Azure)' 'Senior Software Engineer, Data'
#  'Technical Support Engineer (L5) - Data Platform, Big Data / Analytics'
#  'Full Stack Data Engineer' 'Data Engineer IC4 - US ONLY'
#  'Data Engineer I' 'Senior Health Data and Interoperability Engineer'
#  'Azure Data Warehouse Engineer' 'Data Logging Engineer'
#  'ETL Engineer/ Data Analyst - Software Engineer III'
#  'Software Engineer III (AI, Data, Python)'
#  'Software/GCP Data Engineer (W2 only)' 'Software Engineer (Data)'
#  'Junior Big Data Engineer - C11' 'Anaplan Data Engineer'
#  'Data Software Engineer' 'Data Engineer (ETL & Data Catalogue Support)'
#  'Data Scientist / Data Engineer' 'Big Data Sytems Engineer(Hadoop)'
#  'Data Engineer - Need locals to CA' 'Data Engineer (ETL)'
#  'Python Data Engineer' 'Data engineer'
#  'Data Engineer - SnowFlake, Azure Data, Terraform'
#  'Senior Data Engineer [ Remote ]' 'Senior Data Engineer, Analytics'
#  'Cloud Data Engineer' 'Software Engineer, Data' 'Data Engineer 925'
#  'Senior Azure Data Engineer' 'Data Engineer ETL'
#  'Big Data Engineer, Senior']

# %%
dfs[selector] = df

# %% [markdown]
# ### 8. Add job title seniority

# %%
def get_seniority(job_title:str):

    seniority = {
        'Junior' : ["Jr.", "Junior"],
        'Mid' : ["Mid", "Middle"],
        'Senior': ["Sr.", "Senior"],
        'Lead': "Lead",
        'Principle' : "Principle"
    }
    
    if seniority['Junior'][0] in job_title or seniority['Junior'][1] in job_title :
        return "Junior"
    elif seniority['Mid'][0] in job_title or seniority['Mid'][1] in job_title :
        return "Mid"
    elif seniority['Senior'][0] in job_title or seniority['Senior'][1] in job_title :
        return "Senior"
    elif seniority['Lead'] in job_title:
        return "Lead"
    elif seniority['Principle'] in job_title:
        return "Principle"
    else:
        return np.nan
    
df['Seniority'] = df['Job_title'].apply(get_seniority)

del get_seniority

df['Seniority'].value_counts()

# %% [markdown]
# Add non-standard seniority

# %%
def apply_seniority_level(df, job_title, company_name, seniority_level):
    df['Seniority'] = df.apply(
        lambda row: seniority_level if row['Job_title'] == job_title and row['Company_name'] == company_name else row['Seniority'],
        axis=1
    )

apply_seniority_level(df, "Data Engineer (L5)", "Netflix", "Senior")
apply_seniority_level(df, "Technical Support Engineer (L5) - Data Platform, Big Data / Analytics", "Netflix", "Senior")
apply_seniority_level(df, "Data Engineer Level 3", "Infoorigin Inc", "Mid")
apply_seniority_level(df, "Data Engineer IC4 - US ONLY", "Braintrust", "Lead")
apply_seniority_level(df, "ETL Engineer/ Data Analyst - Software Engineer III", "JPMorgan Chase Bank, N.A.", "Senior")
apply_seniority_level(df, "Software Engineer III (AI, Data, Python)", "JPMorgan Chase Bank, N.A.", "Senior")
apply_seniority_level(df, "Data Engineer 925", "Certec Consulting", "Senior")

del apply_seniority_level

df['Seniority'].value_counts()

# %% [markdown]
# ### 8. Parse salary

# %% [markdown]
# #### 8.1 Employer provided salary

# %%
df['Salary_employer_provided'] = df['Salary'].apply(lambda salary : True if isinstance(salary, str) and "Employer Provided Salary" in salary else False)
df['Salary_employer_provided'].value_counts()

# %% [markdown]
# #### 8.2 Salary per hour

# %%
df['Salary_hourly'] = df['Salary'].apply(lambda salary : True if isinstance(salary, str) and "Per Hour" in salary else False)
df['Salary_hourly'].value_counts()

# %% [markdown]
# #### 8.3 Salary min

# %%
def get_salary_min(salary):

    if isinstance(salary, str):

        pattern_salary = r"(\d+(\.\d+)?K?)"
        match_min: str = re.findall(pattern_salary, salary)[0][0]

        if "K" in match_min:
            match_min = float(match_min.replace("K", ""))
            match_min *= 1000

        return float(match_min)

    else:

        return salary
    
def calculate_yearly_income(hourly_rate):

    hours_per_week = 40
    WEEKS_PER_YEAR = 52
    HOURS_PER_YEAR = WEEKS_PER_YEAR * hours_per_week
    gross_income = hourly_rate * HOURS_PER_YEAR
    return gross_income

df['Salary_min'] = df['Salary'].apply(get_salary_min)
df['Salary_min'] = df.apply(
        lambda row: calculate_yearly_income(row['Salary_min']) if row['Salary_hourly'] == True else row['Salary_min'],
        axis=1
    )

del get_salary_min

df['Salary_min']

# %% [markdown]
# #### 8.4 Salary max

# %%
def get_salary_max(salary):

    if isinstance(salary, str):

        pattern_salary = r"(\d+(\.\d+)?K?)"
        match_max: str = re.findall(pattern_salary, salary)[-1][0]

        if "K" in match_max:
            match_max = float(match_max.replace("K", ""))
            match_max *= 1000

        return float(match_max)

    else:

        return salary

df['Salary_max'] = df['Salary'].apply(get_salary_max)
df['Salary_max'] = df.apply(
        lambda row: calculate_yearly_income(row['Salary_max']) if row['Salary_hourly'] == True else row['Salary_max'],
        axis=1
    )

del get_salary_max

df['Salary_max']

# %%
# Cleanup

del calculate_yearly_income

# %% [markdown]
# #### 8.5 Salary currency

# %%
def get_currency(salary: str):

    if isinstance(salary, str):

        pattern_currency = r"(.+?(?=\d))"

        if "Employer Provided Salary" in salary:
            pattern_currency = r"(\:.+?(?=\d))"

        matched = re.search(pattern_currency, salary)

        currency = matched.group(1).strip().replace(":", "")

        return currency

    else:

        return salary
    
df['Salary_currency'] = df['Salary'].apply(get_currency)
    
del get_currency
    
df['Salary_currency'].value_counts()

# %%
del df['Salary']

# %% [markdown]
# #### 8.6 Salary average

# %%
df['Salary_avg'] = (df['Salary_max']+df['Salary_min'])/2
df['Salary_avg']

# %% [markdown]
# ### 9. Employees

# %%
df['Employees'].value_counts()

# %% [markdown]
# ### 10. Type of ownership

# %%
df['Type_of_ownership'].value_counts()

# %% [markdown]
# ### 11. Sector

# %%
df['Sector'].value_counts()

# %% [markdown]
# ### 12. Industry

# %%
df['Industry'].value_counts()

# %% [markdown]
# ### 13. Company age

# %%
import datetime

year = datetime.date.today().year

df['Company_age'] = df['Founded'].apply(lambda x: x if np.isnan(x) else int(year - x))
df['Company_age'] = df['Company_age']

del df['Founded'], year

df['Company_age'].value_counts()

# %% [markdown]
# ### 14. Job age

# %%
np.sort(df['Job_age'].unique())

# %%
def clean_job_age(job_age):

    if job_age == "24h":
        job_age = "1d"
    elif job_age == "30d+":
        job_age = "31d"

    return int(job_age.replace("d", ""))

df['Job_age'] = df['Job_age'].apply(clean_job_age)

del clean_job_age
df['Job_age'].value_counts()

# %% [markdown]
# ### 15. Revenue

# %%
df['Revenue_USD'].value_counts()

# %% [markdown]
# ### 16. Preview columns so far

# %%
df.dtypes

# %% [markdown]
# ### 17. Change columns order

# %% [markdown]
# ##### 17.1 move salary values

# %%
def move_column__to_index(column_name: str, index: int):
    df.insert(index, column_name, df.pop(column_name))


def move_columns_to_index(column_names: list[str], index: int):
    for col in column_names:
        df.insert(index, col, df.pop(col))
        index += 1

move_columns_to_index([
    'Salary_min', 
    'Salary_max', 
    'Salary_avg', 
    'Salary_currency',
    'Salary_employer_provided', 
    'Salary_hourly'
    ], 3
    )

df.dtypes

# %% [markdown]
# ##### 17.2 Move Seniority

# %%
move_column__to_index('Seniority', 3)
df.dtypes

# %% [markdown]
# ##### 17.3 Move City, State

# %%
move_columns_to_index(['City', 'State'], 11)
df.dtypes

# %% [markdown]
# ##### 17.4 Move Company age

# %%
move_column__to_index('Company_age', 19)
df.dtypes

# %% [markdown]
# ##### 17.5 Move Work/Life_balance

# %%
move_columns_to_index(['Senior_management', 'Work/Life_balance'], 25)
df.dtypes

# %% [markdown]
# ## 18. Technology requirements - parsing the job description

# %% [markdown]
# ##### 19 Git and code repositories

# %%
def check_repo(job_description: str):

    git_platforms = [
        r"Github", 
        r"GitLab", 
        r"Bitbucket", 
        r"SourceForge", 
        r"Launchpad", 
        r"Google Cloud Source Repositories",
        r"AWS CodeCommit",
        r"GitBucket",
        r"Gogs",
        r"Gitea",
        r"Apache Allura",
        r"RhodeCode",
        r"ONEDEV",
        r"Codeberg",
        r"Git" # IMPORTANT, it has to be last!
        ]
    
    for platform in git_platforms:
        if re.search((r"\b" + platform + r"\b"), job_description, re.IGNORECASE):
            return platform
        
    return np.nan
        
df['Git'] = df['Description'].apply(check_repo)

del check_repo

df['Git'].value_counts()

# %%
def make_is_tech(cloud_names: list[str]):

    def is_tech(job_description: str):

        
        for cloud in cloud_names:
            if re.search((r"\b" + cloud + r"\b"), job_description, re.IGNORECASE):
                return True
            
        return False
    
    return is_tech

# %%
def add_is_needed_column_to_df(column_name: str, tech_names: list[str]):

    df[column_name] = df['Description'].apply(make_is_tech(tech_names))

# %% [markdown]
# #### 20. Cloud Platforms

# %% [markdown]
# ##### 20.1 AWS

# %% [markdown]
# Provides on-demand cloud computing platforms and APIs to individuals, companies, and governments, on a metered, pay-as-you-go basis. Often times, clients will use this in combination with autoscaling.

# %%
cloud_names = [
    r"Amazon Web Services", 
    r"AWS",
    ]

column_name = 'AWS'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 20.2 Microsoft Azure

# %% [markdown]
# A cloud computing platform operated by Microsoft that provides access, management, and development of applications and services via around the world-distributed data centers.

# %%
cloud_names = [
    r"Microsoft Azure", 
    r"Azure",
    ]

column_name = 'Microsoft_Azure'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 20.3 GCP

# %% [markdown]
# A suite of cloud computing services that runs on the same infrastructure that Google uses internally for its end-user products, such as Google Search, Gmail, Google Drive, and YouTube.

# %%
cloud_names = [
    r"Google Cloud Platform", 
    r"GCP",
    ]

column_name = 'GPC'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 20.4 Alibaba Cloud

# %% [markdown]
# Alibaba Cloud provides cloud computing services to online businesses and Alibaba's own e-commerce ecosystem.

# %%
cloud_names = [
    r"Alibaba Cloud", 
    r"Aliyun",
    ]

column_name = 'Alibaba_Cloud'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 20.4 Oracle Cloud

# %% [markdown]
# Providing servers, storage, network, applications and services through a global network of Oracle Corporation managed data centers

# %%
cloud_names = [
    r"Oracle Cloud", 
    r"OCI",
    ]

column_name = 'Oracle_Cloud'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 20.5 IBM Cloud

# %% [markdown]
# A set of cloud computing services for business

# %%
cloud_names = [
    r"IBM Cloud", 
    r"Kyndryl",
    r"Bluemix"
    ]

column_name = 'IBM_cloud'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 20.6 Tencent Cloud

# %% [markdown]
# Tencent Cloud provides businesses across the globe with stable and secure industry-leading cloud products and services, leveraging technological advancements such as cloud computing, Big Data, AI, IoT and network security.

# %%
cloud_names = [
    r"Tencent Cloud",
    ]

column_name = 'Tencent_cloud'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 20.8 OVHcloud

# %% [markdown]
# A French cloud computing company which offers VPS, dedicated servers and other web services

# %%
cloud_names = [
    r"OVHcloud",
    r"OVH"
    ]

column_name = 'OVHcloud'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 20.9 DigitalOcean

# %% [markdown]
# A cloud hosting provider that offers cloud computing services and Infrastructure as a Service (IaaS). Known for pricing and scalability

# %%
cloud_names = [
    r"DigitalOcean"
    ]

column_name = 'DigitalOcean_cloud'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 20.10 Linode

# %% [markdown]
# An American cloud hosting provider that focused on providing Linux-based virtual machines, cloud infrastructure, and managed services.

# %%
cloud_names = [
    r"Linode",
    r"Akamai"
    ]

column_name = 'Lincode_cloud'

add_is_needed_column_to_df(column_name, cloud_names)

df[column_name].value_counts()

# %%
del cloud_names

# %% [markdown]
# #### 21. Relational Database Management Systems (RDBMS)

# %% [markdown]
# ##### 21.1 PostgreSQL
# Can be used as a data store for big data solutions.
# Postgres, is a free and open-source relational database management system (RDBMS) emphasizing extensibility and SQL compliance. <br>
# PostgreSQL features transactions with Atomicity, Consistency, Isolation, Durability (ACID) properties, automatically updatable views, materialized views, triggers, foreign keys, and stored procedures. <br> It is designed to handle a range of workloads, from single machines to data warehouses or Web services with many concurrent users.

# %%
tool_names = [
    r"PostgreSQL",
    r"Postgres"
    ]

column_name = 'PostgreSQL'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 21.2 Microsoft SQL Server

# %% [markdown]
# A software product with the primary function of storing and retrieving data as requested by other software applications—which may run either on the same computer or on another computer across a network (including the Internet).

# %%
tool_names = [
    r"Microsoft SQL",
    r"SQL Server"
    ]

column_name = 'Microsoft_SQL_Server'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 21.3 MySQL

# %% [markdown]
# An open-source relational database management system.

# %%
tool_names = [
    r"MySQL"
    ]

column_name = 'MySQL'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 21.4 IBM Db2 warehouse

# %% [markdown]
# A family of data management products, including database servers, developed by IBM. It initially supported the relational model, but was extended to support object–relational features and non-relational structures like JSON and XML.

# %%
tool_names = [
    r"Db2",
    r"IBMDb2"
    ]

column_name = 'IBM_Db2'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 21.5. Oracle PL/SQL

# %% [markdown]
#  A procedural language designed specifically to embrace SQL statements within its syntax. PL/SQL program units are compiled by the Oracle Database server and stored inside the database. And at run-time, both PL/SQL and SQL run within the same server process, bringing optimal efficiency

# %%
tool_names = [
    r"PL/SQL",
    r"PL / SQL",
    r"Procedural Language for SQL"
    ]

column_name = 'Oracle_PL_SQL'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 22. NoSQL Database Management Systems

# %% [markdown]
# ##### 22.1 MongoDB

# %% [markdown]
# A source-available cross-platform document-oriented database program. Classified as a NoSQL database program, MongoDB uses JSON-like documents with optional schemas

# %%
tool_names = [
    r"MongoDB",
    r"Mongo DB",
    ]

column_name = 'MongoDB'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 22.2 Cassandra

# %% [markdown]
# A free and open-source, distributed, wide-column store, NoSQL database management system designed to handle large amounts of data across many commodity servers, providing high availability with no single point of failure

# %%
tool_names = [
    r"Cassandra",
    ]

column_name = 'Cassandra'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 22.3 Amazon DynamoDB

# %% [markdown]
# A proprietary NoSQL database service that supports key–value and document data structures and is offered by Amazon.com as part of the Amazon Web Services portfolio.

# %%
tool_names = [
    r"DynamoDB",
    r"Dynamo DB",
    r"SimpleDB"
    ]

column_name = 'Amazon_DynamoDB'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 22.4 Neo4j

# %% [markdown]
# A graph database management system developed by Neo4j, Inc. Described by its developers as an ACID-compliant transactional database with native graph storage and processing

# %%
tool_names = [
    r"Neo4j"
    ]

column_name = 'Neo4j'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 22.5 Apache Solr

# %% [markdown]
# An open-source enterprise-search platform, written in Java. Its major features include full-text search, hit highlighting, faceted search, real-time indexing, dynamic clustering, database integration, NoSQL features[2] and rich document (e.g., Word, PDF) handling.

# %%
tool_names = [
    r"Solr"
    ]

column_name = 'Apache_Solr'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 22. Data warehousing and Analytics

# %% [markdown]
# ##### 22.1 Amazon Redshift

# %% [markdown]
# A data warehouse product which forms part of the larger cloud-computing platform Amazon Web Services. It is built on top of technology from the massive parallel processing data warehouse company ParAccel, to handle large scale data sets and database migrations.

# %%
tool_names = [
    r"Redshift",
    ]

column_name = 'Amazon_Redshift'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 22.2 Google BigQuery

# %% [markdown]
# A serverless data warehouse that enables scalable analysis over petabytes of data. It is a Platform as a Service that supports querying using ANSI SQL. It also has built-in machine learning capabilities.

# %%
tool_names = [
    r"BigQuery",
    ]

column_name = 'Google_BigQuery'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 22.3 Snowflake

# %% [markdown]
# Snowflake enables data storage, processing, and analytic solutions.

# %%
tool_names = [
    r"Snowflake"
    ]

column_name = 'Snowflake'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 22.4 Oracle Exadata

# %% [markdown]
# Designed to run Oracle Database workloads, such as an OLTP application running simultaneously with Analytics processing. Historically, specialized database computing platforms were designed for a particular workload, such as Data Warehousing, and poor or unusable for other workloads, such as OLTP.

# %%
tool_names = [
    r"Exadata"
    ]

column_name = 'Oracle_Exadata'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 22.5 SAP HANA

# %% [markdown]
# A multi-model database that stores data in its memory instead of keeping it on a disk.

# %%
tool_names = [
    r"HANA"
    ]

column_name = 'SAP_HANA'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 22.6 Teradata

# %% [markdown]
# It is mainly suitable for building large scale data warehousing applications.

# %%
tool_names = [
    r"Teradata"
    ]

column_name = 'Teradata'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 23. Data Integration and Processing

# %% [markdown]
# ##### 23.1 Informatica PowerCenter - Data integration tool

# %% [markdown]
# Used extensively for ETL operations, data quality, data masking, data replication, data virtualization, and master data management services.

# %%
tool_names = [
    r"PowerCenter",
    r"Power Center",
    ]

column_name = 'Informatica_PowerCenter'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 23.2 DataBricks - Data processing and analytics platform

# %% [markdown]
# A unified set of tools for building, deploying, sharing, and maintaining enterprise-grade data solutions at scale.

# %%
tool_names = [
    r"Data Bricks",
    r"Databricks"
    ]

column_name = 'Databricks'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 23.3 Presto - Query engine

# %% [markdown]
#  A distributed query engine for big data using the SQL query language. Its architecture allows users to query data sources such as Hadoop, Cassandra, Kafka, AWS S3, Alluxio, MySQL, MongoDB and Teradata, and allows use of multiple data sources

# %%
tool_names = [
    r"Presto",
    r"PrestoDB",
    r"PrestoSQL"
    ]

column_name = 'Presto'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 24. Stream processing tools

# %% [markdown]
# ##### 24.1 Apache Kafka

# %% [markdown]
# An open-source system, distributed event store and stream-processing platform. The project aims to provide a unified, high-throughput, low-latency platform for handling real-time data feeds.

# %%
tool_names = [
    r"Kafka",
    ]

column_name = 'Apache_Kafka'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 24.2 Apache Flink

# %% [markdown]
# Process data streams at a large scale and to deliver real-time analytical insights about your processed data with your streaming application.

# %%
tool_names = [
    r"Flink",
    ]

column_name = 'Apache_Flink'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 24.3 Dataflow

# %% [markdown]
# Dataflow is a managed service provided by Google Cloud for building and executing data processing pipelines. It enables developers to create scalable and efficient batch and streaming data pipelines using a simple programming model.

# %%
tool_names = [
    r"Dataflow",
    ]

column_name = 'Dataflow'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 25 Workflow orchestration tools

# %% [markdown]
# ##### 25.1 Apache Airflow

# %% [markdown]
# Apache Airflow is an open-source platform used for programmatically creating, scheduling, and monitoring complex workflows or data pipelines. It allows users to define and execute a sequence of tasks or operations, while providing tools for tracking and troubleshooting workflow executions.

# %%
tool_names = [
    r"Airflow",
    ]

column_name = 'Apache_Airflow'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 25.2 Luigi

# %% [markdown]
# Luigi is a Python-based open-source workflow management system that helps to build complex pipelines of batch jobs. It provides a flexible and extensible architecture to create and manage complex data workflows.

# %%
tool_names = [
    r"Luigi",
    ]

column_name = 'Luigi'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 25.3 SSIS

# %% [markdown]
# SQL Server Integration Services (SSIS) is a Microsoft tool used for building data integration and ETL (extract, transform, load) workflows. It allows users to perform a range of tasks such as data extraction, transformation, and loading from various sources to different destinations.

# %%
tool_names = [
    r"SSIS",
    r"SQL Server Integration Services"
    ]

column_name = 'SSIS'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 26. Big Data processing

# %% [markdown]
# ##### 24.1 Apache Hadoop

# %% [markdown]
# Apache Hadoop is an open-source framework that allows for the distributed processing of large data sets across clusters of computers using simple programming models. It provides a distributed file system and supports various distributed computing models, such as MapReduce and Spark, for processing and analyzing large data sets.

# %%
tool_names = [
    r"Hadoop",
    ]

column_name = 'Apache_Hadoop'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 24.2 Apache Hive

# %% [markdown]
# Apache Hive is a data warehouse software that facilitates querying and managing large datasets stored in Hadoop file systems using a SQL-like language called HiveQL. It provides a high-level interface for data analysts and developers to analyze, transform, and summarize data stored in Hadoop Distributed File System (HDFS) and other compatible storage systems.

# %%
tool_names = [
    r"Hive",
    ]

column_name = 'Apache_Hive'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 24.3 Apache Spark

# %% [markdown]
# Apache Spark is a distributed computing framework designed to process large-scale data processing and analysis workloads in parallel. It can be used for batch processing, real-time stream processing, machine learning, and graph processing, among other things.

# %%
tool_names = [
    r"Spark",
    r"PySpark"
    ]

column_name = 'Apache_Spark'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %%
df.dtypes

# %% [markdown]
# #### 25. Linux

# %% [markdown]
# Family of Unix-like operating systems.

# %%
tool_names = [
    r"Linux",
    ]

column_name = 'Linux'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 26. Programming languages

# %% [markdown]
# ##### 26.1 Python

# %% [markdown]
# Python is a high-level, interpreted programming language used for various purposes such as web development, data analysis, artificial intelligence, and more.

# %%
tool_names = [
    r"Python",
    ]

column_name = 'Python'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 26.2 R

# %% [markdown]
# A programming language and environment for statistical graphics and computing.

# %%
tool_names = [
    r"R",
    r"RStudio"
    ]

column_name = 'R'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 26.3 Scala

# %% [markdown]
# Scala is a high-level, statically typed programming language designed for functional programming and scalable, concurrent applications.

# %%
tool_names = [
    r"Scala"
    ]

column_name = 'Scala'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 26.4 SQL

# %% [markdown]
# A programming language used to manage and manipulate relational databases.

# %%
tool_names = [
    r"SQL",
    r"MySQL",
    r"PostgreSQL",
    r"Postgres",
    r"SQLite",
    r"MariaDB",
    r"IBM DB2",
    r"Oracle Database",
    r"Db2",
    ]

column_name = 'SQL'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 26.5 Java

# %% [markdown]
# Java is a high-level, object-oriented programming language widely used for developing robust and scalable enterprise applications.
#
# In Data Science, Java can be used for developing machine learning models, data analysis, and data processing applications, as well as for building large-scale distributed systems for big data processing and management.

# %%
tool_names = [
    r"Java",
    ]

column_name = 'Java'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 26.6 C++

# %% [markdown]
# A general-purpose programming language designed for systems and application programming, and it is used in Data Science for building high-performance libraries and applications that require intensive computational tasks.

# %%
tool_names = [
    r"C\+\+",
    ]

column_name = 'C++'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 26.7 Go

# %% [markdown]
# A statically typed programming language designed for building simple, efficient, and reliable software, and it can be used in data engineering for building scalable, distributed systems for data processing and analysis.

# %%
tool_names = [
    r"Go language", # Go as separate word is too common in English
    r"Golang",
    ]

column_name = 'Go'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 26.8 Bash

# %% [markdown]
# A shell scripting language used for automating repetitive tasks and managing the operating system, including data processing tasks, in the command-line interface (CLI) on Unix and Unix-like systems.

# %%
tool_names = [
    r"Bash",
    ]

column_name = 'Bash'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 26.9 Powershell

# %% [markdown]
# A task automation and configuration management framework from Microsoft, which can be used in Data Science for automating various data processing tasks on Windows machines in the command-line interface (CLI).

# %%
tool_names = [
    r"PowerShell",
    r"DOS Shell"
    ]

column_name = 'PowerShell'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 26.10 CLI

# %% [markdown]
# CLI stands for Command Line Interface, which is a way to interact with a computer program through text commands, and it is commonly used in Data Science for running scripts, automating tasks, and managing software packages.

# %%
tool_names = [
    r"CLI",
    r"Command Line Interface"
    ]

column_name = 'CLI'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 27. Virtualization Tools

# %% [markdown]
# Business intelligence and data visualization tools used for analyzing and visualizing data.

# %% [markdown]
# ##### 27.1 Tableau

# %%
tool_names = [
    r"Tableau"
    ]

column_name = 'Tableau'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.2 Power BI

# %%
tool_names = [
    r"Power BI"
    ]

column_name = 'Power_BI'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.3 Google Analytics

# %%
tool_names = [
    r"Google Analytics"
    ]

column_name = 'Google_Analytics'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.4 QlikView

# %%
tool_names = [
    r"QlikView",
    r"Qlik"
    ]

column_name = 'QlikView'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.5 Oracle BI server

# %%
tool_names = [
    r"Oracle Business Intelligence Enterprise Edition",
    r"OBIEE",
    r"Oracle BI server",
    ]

column_name = 'Oracle_BI_server'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.6 SAS Analytics

# %%
tool_names = [
    r"SAS Analytics",
    r"Statistical Analysis System",
    ]

column_name = 'SAS_Analytics'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.7 Lumira

# %%
tool_names = [
    r"Lumira",
    ]

column_name = 'Lumira'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.8 IBM Cognos Impromptu

# %%
tool_names = [
    r"Cognos Impromptu",
    ]

column_name = 'Cognos_Impromptu'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.9 MicroStrategy

# %%
tool_names = [
    r"MicroStrategy",
    ]

column_name = 'MicroStrategy'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.10 InsightSquared

# %%
tool_names = [
    r"InsightSquared",
    ]

column_name = 'InsightSquared'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.11 Sisense

# %%
tool_names = [
    r"Sisense",
    ]

column_name = 'Sisense'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.12 Dundas BI

# %%
tool_names = [
    r"Dundas BI",
    ]

column_name = 'Dundas_BI'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.13 Domo

# %%
tool_names = [
    r"Domo",
    ]

column_name = 'Domo'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 27.14 Looker

# %%
tool_names = [
    r"Looker",
    ]

column_name = 'Looker'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 28. Microsoft Excel

# %%
tool_names = [
    r"Excel",
    ]

column_name = 'Excel'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 29. Certifications

# %% [markdown]
# Checking if there is a need for any certification.

# %%
# Coursera, Udemy, Datacamp etc. list
tool_names = [
    r"Certificates",
    r"Certificate",
    r"Data Engineering, Big Data, and Machine Learning on GCP",
    r"Google Professional Data Engineer",
    r"Microsoft Azure Data Engineering",
    r"Data Engineer.+Nanodegree",
    r"DataCamp",
    r"Data Engineering, Big Data, and Machine Learning on GCP",
    r"Python, Bash and SQL Essentials for Data Engineering Specialization",
    r"Data Engineering ETL, Web Scraping, and Automation",
    r"Big Data Engineering with Hadoop and Spark"
    ]

column_name = 'Is_certificate'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# #### 30. Needed education level

# %% [markdown]
# ##### 30.1 BA

# %%
tool_names = [
    r"BA",
    r"Bachelor",
    r"BSc",
    r"Bachelors"
    ]

column_name = 'BA'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 30.2 MS

# %%
tool_names = [
    r"MS",
    r"MSc",
    r"Master",
    r"Masters",
    r"master\'s"
    ]

column_name = 'MS'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ##### 30.3 Phd

# %%
tool_names = [
    r"Phd",
    r"Ph\.D",
    r"DPhil",
    r"Doctor of Philosophy",
    ]

column_name = 'Phd'

add_is_needed_column_to_df(column_name, tool_names)

df[column_name].value_counts()

# %% [markdown]
# ### Overview

# %%
df.shape

# %%
columns_names = df.columns
columns_names

# %%
del columns_names, column_name, tool_names

# %% [markdown]
# ### 31. Final cleanup

# %% [markdown]
# ##### 31.1 Rename columns

# %%
df = df.rename({
    'Company_name': 'Name',
    'Job_title': 'Title',
    'Salary_min': 'Min',
    'Salary_max': 'Max',
    'Salary_avg': 'Avg',
    'Salary_currency': 'Currency',
    'Salary_employer_provided': 'Employer_provided',
    'Salary_hourly': 'Is_hourly',
    'Alibaba_Cloud': 'Alibaba',
    'Oracle_Cloud': 'Oracle',
    'IBM_cloud': 'IBM',
    'Tencent_cloud': 'Tencent',
    'DigitalOcean_cloud': 'DigitalOcean',
    'Lincode_cloud': 'Lincode'
    }, axis=1)

# %% [markdown]
# ##### 31.2 Change columns order

# %%
def move_column__to_index(column_name: str, index: int):
    df.insert(index, column_name, df.pop(column_name))


def move_columns_to_index(column_names: list[str], index: int):
    for col in column_names:
        df.insert(index, col, df.pop(col))
        index += 1

move_columns_to_index([                       
                    'Title',
                    'Description',
                    'Seniority',
                    'City',
                    'State',
                    'Job_age',
                    'Easy_apply',
                    'Min',
                    'Max',
                    'Avg',
                    'Currency',
                    'Employer_provided',
                    'Is_hourly',
                    'Name',
                    'Rating',
                    'Employees',
                    'Type_of_ownership',
                    'Sector',
                    'Industry',
                    'Company_age',
                    'Revenue_USD',
                    'Friend_recommend',
                    'CEO_approval',
                    'Career_opportunities',
                    'Comp_&_benefits',
                    'Senior_management',
                    'Work/Life_balance',
                    'Culture_&_values',
                    'Pros',
                    'Cons',
                    'Benefits_rating',
                    'Benefits_reviews',
                    'BA',
                    'MS',
                    'Phd',
                    'Is_certificate',
                    'Git',
                    'AWS',
                    'Microsoft_Azure',
                    'GPC',
                    'Alibaba',
                    'Oracle',
                    'IBM',
                    'Tencent',
                    'OVHcloud',
                    'DigitalOcean',
                    'Lincode',
                    'PostgreSQL',
                    'Microsoft_SQL_Server',
                    'IBM_Db2',
                    'MySQL',
                    'Oracle_PL_SQL',
                    'MongoDB',
                    'Cassandra',
                    'Amazon_DynamoDB',
                    'Neo4j',
                    'Apache_Solr',
                    'Amazon_Redshift',
                    'Google_BigQuery',
                    'Snowflake',
                    'Oracle_Exadata',
                    'SAP_HANA',
                    'Teradata',
                    'Informatica_PowerCenter',
                    'Databricks',
                    'Presto',
                    'Apache_Kafka',
                    'Apache_Flink',
                    'Dataflow',
                    'Apache_Airflow',
                    'Luigi',
                    'SSIS',
                    'Apache_Hadoop',
                    'Apache_Hive',
                    'Apache_Spark',
                    'Linux',
                    'Python',
                    'R',
                    'Scala',
                    'SQL',
                    'Java',
                    'C++',
                    'Go',
                    'Bash',
                    'PowerShell',
                    'CLI',
                    'Tableau',
                    'Power_BI',
                    'Google_Analytics',
                    'QlikView',
                    'Oracle_BI_server',
                    'SAS_Analytics',
                    'Lumira',
                    'Cognos_Impromptu',
                    'MicroStrategy',
                    'InsightSquared', 
                    'Sisense', 
                    'Dundas_BI',
                    'Domo', 
                    'Looker', 
                    'Excel'
                    ],0
    )

df.dtypes

# %% [markdown]
# ##### 31.3 Add multiindex

# %%
df.columns = pd.MultiIndex.from_tuples([
                                        ('Job_details', 'Title'),
                                        ('Job_details', 'Description'),
                                        ('Job_details', 'Seniority'),
                                        ('Job_details', 'City'),
                                        ('Job_details', 'State'),
                                        ('Job_details', 'Job_age'),
                                        ('Job_details', 'Easy_apply'),
                                        ('Salary', 'Min'),
                                        ('Salary', 'Max'),
                                        ('Salary', 'Avg'),
                                        ('Salary', 'Currency'),
                                        ('Salary', 'Employer_provided'),
                                        ('Salary', 'Is_hourly'),
                                        ('Company_info', 'Name'),
                                        ('Company_info', 'Rating'),
                                        ('Company_info', 'Employees'),
                                        ('Company_info', 'Type_of_ownership'),
                                        ('Company_info', 'Sector'),
                                        ('Company_info', 'Industry'),
                                        ('Company_info', 'Company_age'),
                                        ('Company_info', 'Revenue_USD'),
                                        ('Company_info', 'Friend_recommend'),
                                        ('Company_info', 'CEO_approval'),
                                        ('Company_info', 'Career_opportunities'),
                                        ('Company_info', 'Comp_&_benefits'),
                                        ('Company_info', 'Senior_management'),
                                        ('Company_info', 'Work/Life_balance'),
                                        ('Company_info', 'Culture_&_values'),
                                        ('Company_info', 'Pros'),
                                        ('Company_info', 'Cons'),
                                        ('Company_info', 'Benefits_rating'),
                                        ('Company_info', 'Benefits_reviews'),
                                        ('Education', 'BA'),
                                        ('Education', 'MS'),
                                        ('Education', 'Phd'),
                                        ('Education', 'Is_certificate'),
                                        ('Version_control', 'Git'),
                                        ('Cloud_platforms', 'AWS'),
                                        ('Cloud_platforms', 'Microsoft_Azure'),
                                        ('Cloud_platforms', 'GPC'),
                                        ('Cloud_platforms', 'Alibaba'),
                                        ('Cloud_platforms', 'Oracle'),
                                        ('Cloud_platforms', 'IBM'),
                                        ('Cloud_platforms', 'Tencent'),
                                        ('Cloud_platforms', 'OVHcloud'),
                                        ('Cloud_platforms', 'DigitalOcean'),
                                        ('Cloud_platforms', 'Lincode'),
                                        ('RDBMS', 'PostgreSQL'),
                                        ('RDBMS', 'Microsoft_SQL_Server'),
                                        ('RDBMS', 'IBM_Db2'),
                                        ('RDBMS', 'MySQL'),
                                        ('RDBMS', 'Oracle_PL_SQL'),
                                        ('NOSQL', 'MongoDB'),
                                        ('NOSQL', 'Cassandra'),
                                        ('NOSQL', 'Amazon_DynamoDB'),
                                        ('NOSQL', 'Neo4j'),
                                        ('Search_&_Analytics', 'Apache_Solr'),
                                        ('Search_&_Analytics', 'Amazon_Redshift'),
                                        ('Search_&_Analytics', 'Google_BigQuery'),
                                        ('Search_&_Analytics', 'Snowflake'),
                                        ('Search_&_Analytics', 'Oracle_Exadata'),
                                        ('Search_&_Analytics', 'SAP_HANA'),
                                        ('Search_&_Analytics', 'Teradata'),
                                        ('Data_integration_and_processing', 'Informatica_PowerCenter'),
                                        ('Data_integration_and_processing', 'Databricks'),
                                        ('Data_integration_and_processing', 'Presto'),
                                        ('Stream_processing_tools', 'Apache_Kafka'),
                                        ('Stream_processing_tools', 'Apache_Flink'),
                                        ('Stream_processing_tools', 'Dataflow'),
                                        ('Workflow_orchestration_tools', 'Apache_Airflow'),
                                        ('Workflow_orchestration_tools', 'Luigi'),
                                        ('Workflow_orchestration_tools', 'SSIS'),
                                        ('Big_Data_processing', 'Apache_Hadoop'),
                                        ('Big_Data_processing', 'Apache_Hive'),
                                        ('Big_Data_processing', 'Apache_Spark'),
                                        ('OS', 'Linux'),
                                        ('Programming_languages', 'Python'),
                                        ('Programming_languages', 'R'),
                                        ('Programming_languages', 'Scala'),
                                        ('Programming_languages', 'SQL'),
                                        ('Programming_languages', 'Java'),
                                        ('Programming_languages', 'C++'),
                                        ('Programming_languages', 'Go'),
                                        ('Programming_languages', 'Bash'),
                                        ('Programming_languages', 'PowerShell'),
                                        ('Programming_languages', 'CLI'),
                                        ('Business_Intelligence_Tools', 'Tableau'),
                                        ('Business_Intelligence_Tools', 'Power_BI'),
                                        ('Business_Intelligence_Tools', 'Google_Analytics'),
                                        ('Business_Intelligence_Tools', 'QlikView'),
                                        ('Business_Intelligence_Tools', 'Oracle_BI_server'),
                                        ('Business_Intelligence_Tools', 'SAS_Analytics'),
                                        ('Business_Intelligence_Tools', 'Lumira'),
                                        ('Business_Intelligence_Tools', 'Cognos_Impromptu'),
                                        ('Business_Intelligence_Tools', 'MicroStrategy'),
                                        ('Business_Intelligence_Tools', 'InsightSquared'), 
                                        ('Business_Intelligence_Tools', 'Sisense'), 
                                        ('Business_Intelligence_Tools', 'Dundas_BI'),
                                        ('Business_Intelligence_Tools', 'Domo'), 
                                        ('Business_Intelligence_Tools', 'Looker'), 
                                        ('Business_Intelligence_Tools', 'Excel'),                   
                                        ])

# %%
df['Company_info']['Name'].head()

# %%
df['Business_Intelligence_Tools']['Excel'].head()

# %% [markdown]
# #### 32. Save CSV

# %% [markdown]
# ##### 32.1 Save

# %%
import os
from pathlib import Path
from scraper.config.get import get_config

config = get_config()

local_path = os.path.join(
    config['output_path']['main'],
    config['output_path']['clean'],
    "Data_Engineer"
    )

file_name = "Data_Engineer_United_States_06-03-2023_23-41.csv"
file_path = Path(f"{local_path}/{file_name}")

folder = os.path.dirname(file_path)
if not os.path.exists(folder):
    os.mkdir(folder)


df.to_csv(file_path, index=True)

# %% [markdown]
# ##### 32.2 Check save

# %%
df_check = pd.read_csv(file_path, index_col=0, header=[0, 1])
df_check.head()

# %%
df_check.shape == df.shape
