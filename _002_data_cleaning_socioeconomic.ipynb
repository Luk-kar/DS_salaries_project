# %% [markdown]
# ## Clean data

# %% [markdown]
# Part of the cleaning was done in spreadsheet software. It was just more convenient.

# %% [markdown]
# ## 1. Importing all packages

# %%
# External
import pandas as pd

# %% [markdown]
# ## 2. Euro rates

# %% [markdown]
# ### 2.1 Importing  a CSV file

# %%
file_name = "euro_rates_04_14_2023.csv"
df = pd.read_csv(f"data\RAW\_Socioeconomic data\{file_name}")
df.head()
# Out:
#          Date     USD     JPY     BGN  CYP     CZK     DKK  EEK      GBP  \
# 0  2023-04-20  1.0944  147.46  1.9558  NaN  23.502  7.4524  NaN  0.88153
# 1  2023-04-19  1.0933  147.24  1.9558  NaN  23.475  7.4514  NaN  0.88108
# 2  2023-04-18  1.0972  146.89  1.9558  NaN  23.373  7.4513  NaN  0.88143
# 3  2023-04-17  1.0981  146.97  1.9558  NaN  23.345  7.4520  NaN  0.88373
# 4  2023-04-14  1.1057  146.60  1.9558  NaN  23.341  7.4510  NaN  0.88440
#
#       HUF  ...      INR      KRW      MXN     MYR     NZD     PHP     SGD  \
# 0  377.68  ...  89.9365  1450.34  19.8156  4.8564  1.7763  61.429  1.4599
# 1  376.35  ...  89.8985  1458.87  19.8057  4.8564  1.7668  61.709  1.4615
# 2  371.68  ...  89.9955  1445.35  19.7174  4.8650  1.7637  61.730  1.4614
# 3  371.70  ...  90.0607  1444.13  19.7526  4.8558  1.7717  61.449  1.4615
# 4  373.68  ...  90.3595  1438.43  19.9598  4.8673  1.7588  61.122  1.4665
#
#       THB      ZAR  Unnamed: 42
# 0  37.609  19.8552          NaN
# 1  37.708  19.9808          NaN
# 2  37.623  19.9299          NaN
# 3  37.753  19.8937          NaN
# 4  37.660  19.9352          NaN
#
# [5 rows x 43 columns]

# %%
filtered_df = df[df["Date"].str.contains("2023-04-14")]
df = filtered_df
df
# Out:
#          Date     USD    JPY     BGN  CYP     CZK    DKK  EEK     GBP     HUF  \
# 4  2023-04-14  1.1057  146.6  1.9558  NaN  23.341  7.451  NaN  0.8844  373.68
#
#    ...      INR      KRW      MXN     MYR     NZD     PHP     SGD    THB  \
# 4  ...  90.3595  1438.43  19.9598  4.8673  1.7588  61.122  1.4665  37.66
#
#        ZAR  Unnamed: 42
# 4  19.9352          NaN
#
# [1 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['Date', 'USD', 'JPY', 'BGN', 'CYP', 'CZK', 'DKK', 'EEK', 'GBP', 'HUF',
#        'LTL', 'LVL', 'MTL', 'PLN', 'ROL', 'RON', 'SEK', 'SIT', 'SKK', 'CHF',
#        'ISK', 'NOK', 'HRK', 'RUB', 'TRL', 'TRY', 'AUD', 'BRL', 'CAD', 'CNY',
#        'HKD', 'IDR', 'ILS', 'INR', 'KRW', 'MXN', 'MYR', 'NZD', 'PHP', 'SGD',
#        'THB', 'ZAR', 'Unnamed: 42'],
#       dtype='object')

# %%
df.drop('Date', axis=1, inplace=True)

# %%
df.shape
# Out:
# (1, 42)

# %% [markdown]
# ### 2.2 Reshape

# %%
filtered_df = pd.melt(
    df,
    var_name='Currency',
    value_name='Rate',
    ignore_index=True
)

filtered_df

df = filtered_df

df.set_index('Currency', inplace=True)

df.shape
# Out:
# (42, 1)

# %%
df
# Out:
#                    Rate
# Currency
# USD              1.1057
# JPY            146.6000
# BGN              1.9558
# CYP                 NaN
# CZK             23.3410
# DKK              7.4510
# EEK                 NaN
# GBP              0.8844
# HUF            373.6800
# LTL                 NaN
# LVL                 NaN
# MTL                 NaN
# PLN              4.6435
# ROL                 NaN
# RON              4.9423
# SEK             11.3455
# SIT                 NaN
# SKK                 NaN
# CHF              0.9827
# ISK            149.7000
# NOK             11.4020
# HRK                 NaN
# RUB                 NaN
# TRL                 NaN
# TRY             21.4218
# AUD              1.6309
# BRL              5.4410
# CAD              1.4725
# CNY              7.5761
# HKD              8.6797
# IDR          16291.7900
# ILS              4.0426
# INR             90.3595
# KRW           1438.4300
# MXN             19.9598
# MYR              4.8673
# NZD              1.7588
# PHP             61.1220
# SGD              1.4665
# THB             37.6600
# ZAR             19.9352
# Unnamed: 42         NaN

# %% [markdown]
# ### 2.2 Remove duplicates

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (31, 1)

# %% [markdown]
# ### 2.3 Remove NaNs

# %%
df.dropna(how="all", axis=0, inplace=True)
df.dropna(how="all", axis=1, inplace=True)
df
# Out:
# C:\Users\karol\AppData\Local\Temp\ipykernel_1260\3309432457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(how="all", axis=0, inplace=True)
# C:\Users\karol\AppData\Local\Temp\ipykernel_1260\3309432457.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(how="all", axis=1, inplace=True)
#                 Rate
# Currency
# USD           1.1057
# JPY         146.6000
# BGN           1.9558
# CZK          23.3410
# DKK           7.4510
# GBP           0.8844
# HUF         373.6800
# PLN           4.6435
# RON           4.9423
# SEK          11.3455
# CHF           0.9827
# ISK         149.7000
# NOK          11.4020
# TRY          21.4218
# AUD           1.6309
# BRL           5.4410
# CAD           1.4725
# CNY           7.5761
# HKD           8.6797
# IDR       16291.7900
# ILS           4.0426
# INR          90.3595
# KRW        1438.4300
# MXN          19.9598
# MYR           4.8673
# NZD           1.7588
# PHP          61.1220
# SGD           1.4665
# THB          37.6600
# ZAR          19.9352

# %% [markdown]
# ### 2.4 Convert EURO rate to USD

# %%
usd_rates = df['Rate'] / df.loc['USD']['Rate']

usd_rates.loc['EUR']  = 1 / df.loc['USD']['Rate']

df['Rate'] = usd_rates

df
# Out:
# C:\Users\karol\AppData\Local\Temp\ipykernel_1260\3136887050.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rate'] = usd_rates
#                   Rate
# Currency
# USD           1.000000
# JPY         132.585692
# BGN           1.768834
# CZK          21.109704
# DKK           6.738718
# GBP           0.799855
# HUF         337.957855
# PLN           4.199602
# RON           4.469838
# SEK          10.260921
# CHF           0.888758
# ISK         135.389346
# NOK          10.312020
# TRY          19.373971
# AUD           1.474993
# BRL           4.920865
# CAD           1.331736
# CNY           6.851859
# HKD           7.849959
# IDR       14734.367369
# ILS           3.656145
# INR          81.721534
# KRW        1300.922493
# MXN          18.051732
# MYR           4.402008
# NZD           1.590667
# PHP          55.279009
# SGD           1.326309
# THB          34.059872
# ZAR          18.029484

# %% [markdown]
# ### 2.5 Sort currencies

# %%
df.sort_index(inplace=True)
df
# Out:
# C:\Users\karol\AppData\Local\Temp\ipykernel_1260\1745695067.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_index(inplace=True)
#                   Rate
# Currency
# AUD           1.474993
# BGN           1.768834
# BRL           4.920865
# CAD           1.331736
# CHF           0.888758
# CNY           6.851859
# CZK          21.109704
# DKK           6.738718
# GBP           0.799855
# HKD           7.849959
# HUF         337.957855
# IDR       14734.367369
# ILS           3.656145
# INR          81.721534
# ISK         135.389346
# JPY         132.585692
# KRW        1300.922493
# MXN          18.051732
# MYR           4.402008
# NOK          10.312020
# NZD           1.590667
# PHP          55.279009
# PLN           4.199602
# RON           4.469838
# SEK          10.260921
# SGD           1.326309
# THB          34.059872
# TRY          19.373971
# USD           1.000000
# ZAR          18.029484

# %% [markdown]
# ### 2.5 Save CSV

# %% [markdown]
# ##### 2.5.1 Save

# %%
file_to_save = f"data\clean\_Socioeconomic data\{file_name}"
df.to_csv(file_to_save, index=True)

# %% [markdown]
# ##### 2.5.2 Check save

# %%
df_check = pd.read_csv(file_to_save, index_col=0)

# %%
df_check.shape == df.shape
# Out:
# True

# %%
del df_check, file_to_save, df

# %% [markdown]
# ## 3. Purchasing Power Parities

# %% [markdown]
# ### 3.1 Importing a CSV file

# %%
df = pd.read_csv("data\RAW\_Socioeconomic data\DP_LIVE_04042023094701143.csv")
df.head()

# %%
df.shape

# %% [markdown]
# ### 3.2 Filter max year for each country

# %%
def filter_max_year(df: pd.DataFrame, location_col='LOCATION', year_col='TIME', value_col='Value'):

    max_years = df.groupby(location_col)[year_col].transform("max")

    filtered_df = df[df[year_col] == max_years].reset_index(drop=True)

    filtered_df.rename(columns={'Value': value_col}, inplace=True)

    return filtered_df

df = filter_max_year(df)
df

# %% [markdown]
# ### 3.3 Rename columns

# %%
df.columns = ['Country', 'Year', 'Conversion']
df.set_index('Country', inplace=True)
df.head()

# %% [markdown]
# ### 3.4 Remove duplicates

# %%
df.shape

# %%
df = df.dropna(how="all")
df.shape

# %% [markdown]
# ### 3.5 Remove NaNs

# %%
df = df.dropna(how="all")
df.shape

# %% [markdown]
# ### 3.6 Preview

# %%
df

# %% [markdown]
# ### 3.7 Save CSV

# %% [markdown]
# #### 3.7.1 Save

# %%
file_to_save = "data\clean\_Socioeconomic data\purchasing_power_index.csv"
df.to_csv(file_to_save, index=True)

# %% [markdown]
# #### 3.7.2 Check save

# %%
df_check = pd.read_csv(file_to_save, index_col=0)
df_check.head()

# %%
df_check.shape == df.shape

# %%
del df_check, file_to_save, df
